# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  # attempt 1 with tf.keras.regularizers.l1(0.00005)
  # attempt 2 with tf.keras.regularizers.l1(0.0005)
  # attempt 3 with tf.keras.regularizers.l1(0.005)
  # attempt 4 with tf.keras.regularizers.l1(0.05)
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),

  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/s_model_Aug_NoOptV3.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 2.7273 - accuracy: 0.6332
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 11s 199ms/step - loss: 2.7273 - accuracy: 0.6332 - val_loss: 1.5690 - val_accuracy: 0.6965
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.4635 - accuracy: 0.6288
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 1.4601 - accuracy: 0.6320 - val_loss: 1.2473 - val_accuracy: 0.6965
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2255 - accuracy: 0.6438
# Epoch 3: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 1.2220 - accuracy: 0.6468 - val_loss: 1.0612 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0671 - accuracy: 0.6375
# Epoch 4: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 1.0640 - accuracy: 0.6406 - val_loss: 0.9627 - val_accuracy: 0.6965
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9710 - accuracy: 0.6162
# Epoch 5: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 0.9673 - accuracy: 0.6196 - val_loss: 0.8658 - val_accuracy: 0.6965
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8979 - accuracy: 0.6125
# Epoch 6: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 0.8958 - accuracy: 0.6159 - val_loss: 0.8222 - val_accuracy: 0.6965
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8572 - accuracy: 0.6400
# Epoch 7: val_accuracy improved from 0.69652 to 0.73632, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.8561 - accuracy: 0.6431 - val_loss: 0.8128 - val_accuracy: 0.7363
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7984 - accuracy: 0.6700
# Epoch 8: val_accuracy did not improve from 0.73632
# 26/26 [==============================] - 3s 124ms/step - loss: 0.7970 - accuracy: 0.6729 - val_loss: 0.7485 - val_accuracy: 0.7313
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7531 - accuracy: 0.6662
# Epoch 9: val_accuracy did not improve from 0.73632
# 26/26 [==============================] - 3s 124ms/step - loss: 0.7507 - accuracy: 0.6691 - val_loss: 0.7664 - val_accuracy: 0.7065
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7815 - accuracy: 0.6737
# Epoch 10: val_accuracy improved from 0.73632 to 0.76617, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.7798 - accuracy: 0.6766 - val_loss: 0.6852 - val_accuracy: 0.7662
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7346 - accuracy: 0.6737
# Epoch 11: val_accuracy did not improve from 0.76617
# 26/26 [==============================] - 3s 124ms/step - loss: 0.7322 - accuracy: 0.6766 - val_loss: 0.6446 - val_accuracy: 0.7413
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7080 - accuracy: 0.6975
# Epoch 12: val_accuracy improved from 0.76617 to 0.77612, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.7058 - accuracy: 0.7001 - val_loss: 0.6499 - val_accuracy: 0.7761
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6426 - accuracy: 0.7513
# Epoch 13: val_accuracy improved from 0.77612 to 0.83085, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.6404 - accuracy: 0.7534 - val_loss: 0.5335 - val_accuracy: 0.8308
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6354 - accuracy: 0.7212
# Epoch 14: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 3s 127ms/step - loss: 0.6331 - accuracy: 0.7237 - val_loss: 0.5473 - val_accuracy: 0.8259
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6468 - accuracy: 0.7225
# Epoch 15: val_accuracy improved from 0.83085 to 0.83582, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.6443 - accuracy: 0.7249 - val_loss: 0.5145 - val_accuracy: 0.8358
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5800 - accuracy: 0.7837
# Epoch 16: val_accuracy improved from 0.83582 to 0.85572, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5777 - accuracy: 0.7856 - val_loss: 0.4676 - val_accuracy: 0.8557
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5677 - accuracy: 0.7875
# Epoch 17: val_accuracy did not improve from 0.85572
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5655 - accuracy: 0.7893 - val_loss: 0.4755 - val_accuracy: 0.8358
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5811 - accuracy: 0.7738
# Epoch 18: val_accuracy improved from 0.85572 to 0.86567, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5786 - accuracy: 0.7757 - val_loss: 0.4604 - val_accuracy: 0.8657
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5259 - accuracy: 0.8163
# Epoch 19: val_accuracy improved from 0.86567 to 0.88060, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.5243 - accuracy: 0.8178 - val_loss: 0.4354 - val_accuracy: 0.8806
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5304 - accuracy: 0.8062
# Epoch 20: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5284 - accuracy: 0.8079 - val_loss: 0.4550 - val_accuracy: 0.8806
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5150 - accuracy: 0.8188
# Epoch 21: val_accuracy improved from 0.88060 to 0.89552, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.5139 - accuracy: 0.8203 - val_loss: 0.4612 - val_accuracy: 0.8955
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5443 - accuracy: 0.7750
# Epoch 22: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5426 - accuracy: 0.7770 - val_loss: 0.5443 - val_accuracy: 0.7910
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5527 - accuracy: 0.7887
# Epoch 23: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5499 - accuracy: 0.7906 - val_loss: 0.4423 - val_accuracy: 0.8657
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5591 - accuracy: 0.7763
# Epoch 24: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5568 - accuracy: 0.7782 - val_loss: 0.4317 - val_accuracy: 0.8607
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5182 - accuracy: 0.8000
# Epoch 25: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5157 - accuracy: 0.8017 - val_loss: 0.4109 - val_accuracy: 0.8756
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5416 - accuracy: 0.7738
# Epoch 26: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5393 - accuracy: 0.7757 - val_loss: 0.4471 - val_accuracy: 0.8806
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4954 - accuracy: 0.8138
# Epoch 27: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4934 - accuracy: 0.8154 - val_loss: 0.4671 - val_accuracy: 0.8358
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5241 - accuracy: 0.8225
# Epoch 28: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5214 - accuracy: 0.8240 - val_loss: 0.4123 - val_accuracy: 0.8856
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4983 - accuracy: 0.8188
# Epoch 29: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.4961 - accuracy: 0.8203 - val_loss: 0.4242 - val_accuracy: 0.8706
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5181 - accuracy: 0.8000
# Epoch 30: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.5156 - accuracy: 0.8017 - val_loss: 0.4081 - val_accuracy: 0.8806
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4734 - accuracy: 0.8288
# Epoch 31: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4714 - accuracy: 0.8302 - val_loss: 0.4182 - val_accuracy: 0.8607
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5218 - accuracy: 0.8025
# Epoch 32: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.5195 - accuracy: 0.8042 - val_loss: 0.4195 - val_accuracy: 0.8756
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4772 - accuracy: 0.8313
# Epoch 33: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4752 - accuracy: 0.8327 - val_loss: 0.3961 - val_accuracy: 0.8706
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5061 - accuracy: 0.8150
# Epoch 34: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.5037 - accuracy: 0.8166 - val_loss: 0.3840 - val_accuracy: 0.8955
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4693 - accuracy: 0.8388
# Epoch 35: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4669 - accuracy: 0.8401 - val_loss: 0.3761 - val_accuracy: 0.8905
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5116 - accuracy: 0.8025
# Epoch 36: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.5091 - accuracy: 0.8042 - val_loss: 0.4003 - val_accuracy: 0.8905
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4664 - accuracy: 0.8375
# Epoch 37: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4646 - accuracy: 0.8389 - val_loss: 0.3960 - val_accuracy: 0.8557
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4706 - accuracy: 0.8487
# Epoch 38: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4681 - accuracy: 0.8501 - val_loss: 0.3897 - val_accuracy: 0.8607
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4864 - accuracy: 0.8238
# Epoch 39: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4840 - accuracy: 0.8253 - val_loss: 0.3843 - val_accuracy: 0.8955
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4477 - accuracy: 0.8462
# Epoch 40: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4458 - accuracy: 0.8476 - val_loss: 0.3638 - val_accuracy: 0.8806
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4820 - accuracy: 0.8288
# Epoch 41: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4800 - accuracy: 0.8302 - val_loss: 0.4075 - val_accuracy: 0.8856
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4544 - accuracy: 0.8350
# Epoch 42: val_accuracy improved from 0.89552 to 0.90050, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 4s 137ms/step - loss: 0.4519 - accuracy: 0.8364 - val_loss: 0.3571 - val_accuracy: 0.9005
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4716 - accuracy: 0.8325
# Epoch 43: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4695 - accuracy: 0.8340 - val_loss: 0.4120 - val_accuracy: 0.8706
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4559 - accuracy: 0.8388
# Epoch 44: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4537 - accuracy: 0.8401 - val_loss: 0.3528 - val_accuracy: 0.9005
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4481 - accuracy: 0.8388
# Epoch 45: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4471 - accuracy: 0.8401 - val_loss: 0.4079 - val_accuracy: 0.8806
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4592 - accuracy: 0.8450
# Epoch 46: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 126ms/step - loss: 0.4567 - accuracy: 0.8463 - val_loss: 0.3960 - val_accuracy: 0.8607
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4253 - accuracy: 0.8400
# Epoch 47: val_accuracy improved from 0.90050 to 0.90547, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 4s 136ms/step - loss: 0.4230 - accuracy: 0.8414 - val_loss: 0.3345 - val_accuracy: 0.9055
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4471 - accuracy: 0.8413
# Epoch 48: val_accuracy improved from 0.90547 to 0.91045, saving model to /s_model_Aug_NoOptV3.h5
# 26/26 [==============================] - 4s 136ms/step - loss: 0.4454 - accuracy: 0.8426 - val_loss: 0.3462 - val_accuracy: 0.9104
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4172 - accuracy: 0.8625
# Epoch 49: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 127ms/step - loss: 0.4154 - accuracy: 0.8637 - val_loss: 0.3545 - val_accuracy: 0.8905
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4355 - accuracy: 0.8575
# Epoch 50: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 127ms/step - loss: 0.4333 - accuracy: 0.8587 - val_loss: 0.3383 - val_accuracy: 0.9055
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[138   2]
#  [ 17  44]]
