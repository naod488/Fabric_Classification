# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

norm = 0.00005

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-2c-NoAug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 2.0770 - accuracy: 0.6109
# Epoch 1: val_accuracy improved from -inf to 0.75124, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 97s 2s/step - loss: 2.0770 - accuracy: 0.6109 - val_loss: 1.2989 - val_accuracy: 0.7512
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1925 - accuracy: 0.6750
# Epoch 2: val_accuracy improved from 0.75124 to 0.79104, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 80ms/step - loss: 1.1903 - accuracy: 0.6753 - val_loss: 0.9670 - val_accuracy: 0.7910
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9659 - accuracy: 0.7275
# Epoch 3: val_accuracy improved from 0.79104 to 0.80597, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 80ms/step - loss: 0.9650 - accuracy: 0.7286 - val_loss: 0.8697 - val_accuracy: 0.8060
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7927 - accuracy: 0.7600
# Epoch 4: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 67ms/step - loss: 0.7896 - accuracy: 0.7621 - val_loss: 0.7299 - val_accuracy: 0.7811
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7466 - accuracy: 0.7437
# Epoch 5: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 68ms/step - loss: 0.7445 - accuracy: 0.7447 - val_loss: 0.6900 - val_accuracy: 0.8060
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6480 - accuracy: 0.7675
# Epoch 6: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 67ms/step - loss: 0.6453 - accuracy: 0.7695 - val_loss: 0.9229 - val_accuracy: 0.5920
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6102 - accuracy: 0.7837
# Epoch 7: val_accuracy improved from 0.80597 to 0.83085, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 82ms/step - loss: 0.6076 - accuracy: 0.7856 - val_loss: 0.6096 - val_accuracy: 0.8308
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5380 - accuracy: 0.8350
# Epoch 8: val_accuracy improved from 0.83085 to 0.84080, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 0.5359 - accuracy: 0.8364 - val_loss: 0.5608 - val_accuracy: 0.8408
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4398 - accuracy: 0.9013
# Epoch 9: val_accuracy improved from 0.84080 to 0.93532, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 80ms/step - loss: 0.4380 - accuracy: 0.9021 - val_loss: 0.4445 - val_accuracy: 0.9353
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3375 - accuracy: 0.9638
# Epoch 10: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 67ms/step - loss: 0.3363 - accuracy: 0.9641 - val_loss: 0.4250 - val_accuracy: 0.9154
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3381 - accuracy: 0.9438
# Epoch 11: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 67ms/step - loss: 0.3372 - accuracy: 0.9442 - val_loss: 0.4149 - val_accuracy: 0.9055
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4767 - accuracy: 0.8900
# Epoch 12: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 67ms/step - loss: 0.4750 - accuracy: 0.8910 - val_loss: 0.4673 - val_accuracy: 0.9353
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4099 - accuracy: 0.9400
# Epoch 13: val_accuracy improved from 0.93532 to 0.94030, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 0.4083 - accuracy: 0.9405 - val_loss: 0.3753 - val_accuracy: 0.9403
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3201 - accuracy: 0.9725
# Epoch 14: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 68ms/step - loss: 0.3194 - accuracy: 0.9727 - val_loss: 0.4160 - val_accuracy: 0.9104
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3001 - accuracy: 0.9787
# Epoch 15: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2994 - accuracy: 0.9789 - val_loss: 0.3328 - val_accuracy: 0.9303
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2501 - accuracy: 0.9912
# Epoch 16: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2497 - accuracy: 0.9913 - val_loss: 0.3601 - val_accuracy: 0.9303
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2458 - accuracy: 0.9900
# Epoch 17: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 69ms/step - loss: 0.2456 - accuracy: 0.9901 - val_loss: 0.4827 - val_accuracy: 0.8756
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4069 - accuracy: 0.9513
# Epoch 18: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 68ms/step - loss: 0.4059 - accuracy: 0.9517 - val_loss: 0.6324 - val_accuracy: 0.8358
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2921 - accuracy: 0.9912
# Epoch 19: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2915 - accuracy: 0.9913 - val_loss: 0.3913 - val_accuracy: 0.9254
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2712 - accuracy: 0.9900
# Epoch 20: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2709 - accuracy: 0.9901 - val_loss: 0.6800 - val_accuracy: 0.8209
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4766 - accuracy: 0.9325
# Epoch 21: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.4754 - accuracy: 0.9331 - val_loss: 0.6108 - val_accuracy: 0.8507
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3176 - accuracy: 0.9887
# Epoch 22: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.3173 - accuracy: 0.9888 - val_loss: 0.5423 - val_accuracy: 0.8657
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2807 - accuracy: 0.9812
# Epoch 23: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2801 - accuracy: 0.9814 - val_loss: 0.4447 - val_accuracy: 0.9005
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2438 - accuracy: 0.9887
# Epoch 24: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2435 - accuracy: 0.9888 - val_loss: 0.8030 - val_accuracy: 0.8010
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2767 - accuracy: 0.9800
# Epoch 25: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 68ms/step - loss: 0.2763 - accuracy: 0.9802 - val_loss: 0.7439 - val_accuracy: 0.8060
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2757 - accuracy: 0.9887
# Epoch 26: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2752 - accuracy: 0.9888 - val_loss: 0.5964 - val_accuracy: 0.8408
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2262 - accuracy: 0.9987
# Epoch 27: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2259 - accuracy: 0.9988 - val_loss: 0.4014 - val_accuracy: 0.9204
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1905 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1904 - accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9403
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1715 - accuracy: 1.0000
# Epoch 29: val_accuracy improved from 0.94030 to 0.94527, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-NoAug-fs.h5
# 26/26 [==============================] - 3s 110ms/step - loss: 0.1714 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9453
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1627 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1626 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9453
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1563 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1563 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9453
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1512 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1512 - accuracy: 1.0000 - val_loss: 0.3262 - val_accuracy: 0.9403
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1470 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1470 - accuracy: 1.0000 - val_loss: 0.3274 - val_accuracy: 0.9403
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1430 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 68ms/step - loss: 0.1430 - accuracy: 1.0000 - val_loss: 0.3255 - val_accuracy: 0.9403
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1393 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1393 - accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9353
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1361 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1361 - accuracy: 1.0000 - val_loss: 0.3272 - val_accuracy: 0.9353
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1329 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1329 - accuracy: 1.0000 - val_loss: 0.3266 - val_accuracy: 0.9353
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1303 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1302 - accuracy: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9303
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1277 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1277 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.9204
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1253 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1252 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9154
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1230 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1229 - accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9204
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1208 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 68ms/step - loss: 0.1208 - accuracy: 1.0000 - val_loss: 0.3354 - val_accuracy: 0.9204
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1187 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1187 - accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.9204
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1169 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.9204
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1153 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 68ms/step - loss: 0.1153 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9154
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1135 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1135 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9204
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1115 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 68ms/step - loss: 0.1115 - accuracy: 1.0000 - val_loss: 0.3501 - val_accuracy: 0.9154
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1104 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1104 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9254
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1100 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1100 - accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9303
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1098 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 67ms/step - loss: 0.1098 - accuracy: 1.0000 - val_loss: 0.4843 - val_accuracy: 0.8706
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[137   3]
#  [ 23  38]]
# 0
