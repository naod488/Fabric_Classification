# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  # attempt 1 with tf.keras.regularizers.l1(0.00005)
  # attempt 2 with tf.keras.regularizers.l1(0.0005)
  # attempt 3 with tf.keras.regularizers.l1(0.005)
  # attempt 4 with tf.keras.regularizers.l1(0.05)
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.0005)),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
checkpoint = ModelCheckpoint(filepath = 's_model_NoAug_NoOptv3.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 8.2958 - accuracy: 0.5998
# Epoch 1: val_accuracy improved from -inf to 0.71144, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 10s 221ms/step - loss: 8.2958 - accuracy: 0.5998 - val_loss: 3.4666 - val_accuracy: 0.7114
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.5828 - accuracy: 0.6837
# Epoch 2: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 2s 71ms/step - loss: 2.5763 - accuracy: 0.6840 - val_loss: 1.9215 - val_accuracy: 0.7114
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.6979 - accuracy: 0.7025
# Epoch 3: val_accuracy improved from 0.71144 to 0.74129, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.6948 - accuracy: 0.7026 - val_loss: 1.4991 - val_accuracy: 0.7413
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.4588 - accuracy: 0.7275
# Epoch 4: val_accuracy did not improve from 0.74129
# 26/26 [==============================] - 2s 72ms/step - loss: 1.4564 - accuracy: 0.7286 - val_loss: 1.4715 - val_accuracy: 0.6667
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.4264 - accuracy: 0.7275
# Epoch 5: val_accuracy did not improve from 0.74129
# 26/26 [==============================] - 2s 71ms/step - loss: 1.4242 - accuracy: 0.7286 - val_loss: 1.4104 - val_accuracy: 0.7214
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3732 - accuracy: 0.7437
# Epoch 6: val_accuracy did not improve from 0.74129
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3710 - accuracy: 0.7447 - val_loss: 1.4401 - val_accuracy: 0.6816
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3623 - accuracy: 0.7325
# Epoch 7: val_accuracy improved from 0.74129 to 0.80597, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 82ms/step - loss: 1.3616 - accuracy: 0.7323 - val_loss: 1.2748 - val_accuracy: 0.8060
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3542 - accuracy: 0.7362
# Epoch 8: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3523 - accuracy: 0.7373 - val_loss: 1.2923 - val_accuracy: 0.8010
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3284 - accuracy: 0.7275
# Epoch 9: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3281 - accuracy: 0.7274 - val_loss: 1.2612 - val_accuracy: 0.7910
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3188 - accuracy: 0.7287
# Epoch 10: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 1.3178 - accuracy: 0.7286 - val_loss: 1.2234 - val_accuracy: 0.8060
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3300 - accuracy: 0.7038
# Epoch 11: val_accuracy improved from 0.80597 to 0.83085, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.3280 - accuracy: 0.7051 - val_loss: 1.2219 - val_accuracy: 0.8308
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3027 - accuracy: 0.7613
# Epoch 12: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3015 - accuracy: 0.7608 - val_loss: 1.2086 - val_accuracy: 0.8060
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3161 - accuracy: 0.7125
# Epoch 13: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 72ms/step - loss: 1.3142 - accuracy: 0.7138 - val_loss: 1.2051 - val_accuracy: 0.8109
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3110 - accuracy: 0.7188
# Epoch 14: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.3094 - accuracy: 0.7200 - val_loss: 1.2038 - val_accuracy: 0.8010
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2697 - accuracy: 0.7513
# Epoch 15: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2686 - accuracy: 0.7509 - val_loss: 1.1885 - val_accuracy: 0.8060
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2578 - accuracy: 0.7513
# Epoch 16: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2571 - accuracy: 0.7509 - val_loss: 1.1991 - val_accuracy: 0.7711
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2569 - accuracy: 0.7550
# Epoch 17: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2556 - accuracy: 0.7559 - val_loss: 1.1834 - val_accuracy: 0.8060
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2542 - accuracy: 0.7425
# Epoch 18: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 72ms/step - loss: 1.2533 - accuracy: 0.7423 - val_loss: 1.2119 - val_accuracy: 0.7562
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2601 - accuracy: 0.7337
# Epoch 19: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2588 - accuracy: 0.7336 - val_loss: 1.2262 - val_accuracy: 0.7612
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2535 - accuracy: 0.7538
# Epoch 20: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2527 - accuracy: 0.7534 - val_loss: 1.2440 - val_accuracy: 0.7363
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2589 - accuracy: 0.7462
# Epoch 21: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2578 - accuracy: 0.7460 - val_loss: 1.2190 - val_accuracy: 0.7562
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2465 - accuracy: 0.7613
# Epoch 22: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 71ms/step - loss: 1.2450 - accuracy: 0.7621 - val_loss: 1.1624 - val_accuracy: 0.8109
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2041 - accuracy: 0.7763
# Epoch 23: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 77ms/step - loss: 1.2021 - accuracy: 0.7770 - val_loss: 1.1221 - val_accuracy: 0.8159
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1921 - accuracy: 0.7688
# Epoch 24: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 73ms/step - loss: 1.1900 - accuracy: 0.7708 - val_loss: 1.0984 - val_accuracy: 0.8209
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1633 - accuracy: 0.7788
# Epoch 25: val_accuracy improved from 0.83085 to 0.83582, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 82ms/step - loss: 1.1612 - accuracy: 0.7807 - val_loss: 1.0775 - val_accuracy: 0.8358
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1490 - accuracy: 0.7862
# Epoch 26: val_accuracy improved from 0.83582 to 0.84080, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.1469 - accuracy: 0.7881 - val_loss: 1.0674 - val_accuracy: 0.8408
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1360 - accuracy: 0.7912
# Epoch 27: val_accuracy improved from 0.84080 to 0.84577, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 82ms/step - loss: 1.1340 - accuracy: 0.7931 - val_loss: 1.0641 - val_accuracy: 0.8458
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1247 - accuracy: 0.8062
# Epoch 28: val_accuracy improved from 0.84577 to 0.85075, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.1224 - accuracy: 0.8079 - val_loss: 1.0556 - val_accuracy: 0.8507
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1195 - accuracy: 0.8150
# Epoch 29: val_accuracy improved from 0.85075 to 0.86567, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.1171 - accuracy: 0.8166 - val_loss: 1.0557 - val_accuracy: 0.8657
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1203 - accuracy: 0.8100
# Epoch 30: val_accuracy improved from 0.86567 to 0.87065, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.1187 - accuracy: 0.8116 - val_loss: 1.0672 - val_accuracy: 0.8706
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0850 - accuracy: 0.8300
# Epoch 31: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 71ms/step - loss: 1.0832 - accuracy: 0.8315 - val_loss: 1.0592 - val_accuracy: 0.8607
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1003 - accuracy: 0.8300
# Epoch 32: val_accuracy improved from 0.87065 to 0.87562, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 1.0979 - accuracy: 0.8315 - val_loss: 1.0179 - val_accuracy: 0.8756
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0961 - accuracy: 0.8400
# Epoch 33: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 71ms/step - loss: 1.0943 - accuracy: 0.8414 - val_loss: 1.0539 - val_accuracy: 0.8607
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0437 - accuracy: 0.8587
# Epoch 34: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 72ms/step - loss: 1.0417 - accuracy: 0.8600 - val_loss: 1.0389 - val_accuracy: 0.8756
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0230 - accuracy: 0.8863
# Epoch 35: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 71ms/step - loss: 1.0212 - accuracy: 0.8872 - val_loss: 1.0385 - val_accuracy: 0.8706
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9917 - accuracy: 0.9075
# Epoch 36: val_accuracy improved from 0.87562 to 0.90547, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 0.9904 - accuracy: 0.9083 - val_loss: 0.9794 - val_accuracy: 0.9055
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9578 - accuracy: 0.9262
# Epoch 37: val_accuracy improved from 0.90547 to 0.93035, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 81ms/step - loss: 0.9564 - accuracy: 0.9269 - val_loss: 0.9507 - val_accuracy: 0.9303
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9166 - accuracy: 0.9400
# Epoch 38: val_accuracy improved from 0.93035 to 0.94527, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 2s 82ms/step - loss: 0.9155 - accuracy: 0.9405 - val_loss: 0.9428 - val_accuracy: 0.9453
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9193 - accuracy: 0.9400
# Epoch 39: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.9182 - accuracy: 0.9405 - val_loss: 0.9743 - val_accuracy: 0.9104
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9123 - accuracy: 0.9375
# Epoch 40: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.9116 - accuracy: 0.9380 - val_loss: 1.0389 - val_accuracy: 0.8955
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9644 - accuracy: 0.9212
# Epoch 41: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.9644 - accuracy: 0.9219 - val_loss: 1.1175 - val_accuracy: 0.8507
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9748 - accuracy: 0.9438
# Epoch 42: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.9732 - accuracy: 0.9442 - val_loss: 0.9803 - val_accuracy: 0.8955
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8763 - accuracy: 0.9550
# Epoch 43: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 73ms/step - loss: 0.8751 - accuracy: 0.9554 - val_loss: 0.9617 - val_accuracy: 0.8955
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8449 - accuracy: 0.9650
# Epoch 44: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.8440 - accuracy: 0.9653 - val_loss: 0.9647 - val_accuracy: 0.8905
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8431 - accuracy: 0.9663
# Epoch 45: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.8423 - accuracy: 0.9665 - val_loss: 0.9840 - val_accuracy: 0.9055
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8454 - accuracy: 0.9650
# Epoch 46: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 71ms/step - loss: 0.8448 - accuracy: 0.9653 - val_loss: 1.0935 - val_accuracy: 0.8408
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8393 - accuracy: 0.9762
# Epoch 47: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 71ms/step - loss: 0.8386 - accuracy: 0.9765 - val_loss: 1.0007 - val_accuracy: 0.8756
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8566 - accuracy: 0.9688
# Epoch 48: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 71ms/step - loss: 0.8558 - accuracy: 0.9690 - val_loss: 1.8421 - val_accuracy: 0.6368
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0724 - accuracy: 0.8850
# Epoch 49: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 71ms/step - loss: 1.0732 - accuracy: 0.8848 - val_loss: 1.1339 - val_accuracy: 0.8557
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9903 - accuracy: 0.9450
# Epoch 50: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 2s 72ms/step - loss: 0.9898 - accuracy: 0.9442 - val_loss: 1.2615 - val_accuracy: 0.7711
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[138   2]
#  [ 44  17]]
