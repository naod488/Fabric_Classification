# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(0.5)
    ]
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-2b-Aug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 1.1780 - accuracy: 0.6171
# Epoch 1: val_accuracy improved from -inf to 0.57711, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 26s 888ms/step - loss: 1.1780 - accuracy: 0.6171 - val_loss: 0.6840 - val_accuracy: 0.5771
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6235 - accuracy: 0.6850
# Epoch 2: val_accuracy improved from 0.57711 to 0.70647, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.6237 - accuracy: 0.6840 - val_loss: 0.5558 - val_accuracy: 0.7065
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5881 - accuracy: 0.7038
# Epoch 3: val_accuracy did not improve from 0.70647
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5864 - accuracy: 0.7051 - val_loss: 0.6284 - val_accuracy: 0.6617
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6022 - accuracy: 0.6762
# Epoch 4: val_accuracy improved from 0.70647 to 0.76119, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 83ms/step - loss: 0.6007 - accuracy: 0.6778 - val_loss: 0.5337 - val_accuracy: 0.7612
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6095 - accuracy: 0.7050
# Epoch 5: val_accuracy improved from 0.76119 to 0.78607, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.6087 - accuracy: 0.7051 - val_loss: 0.5121 - val_accuracy: 0.7861
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5942 - accuracy: 0.6988
# Epoch 6: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5946 - accuracy: 0.6976 - val_loss: 0.5673 - val_accuracy: 0.7015
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5996 - accuracy: 0.6600
# Epoch 7: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 72ms/step - loss: 0.5990 - accuracy: 0.6592 - val_loss: 0.5299 - val_accuracy: 0.7114
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5905 - accuracy: 0.7000
# Epoch 8: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5903 - accuracy: 0.6989 - val_loss: 0.5406 - val_accuracy: 0.7015
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5851 - accuracy: 0.6612
# Epoch 9: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.5853 - accuracy: 0.6605 - val_loss: 0.5235 - val_accuracy: 0.7015
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5735 - accuracy: 0.6725
# Epoch 10: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5719 - accuracy: 0.6741 - val_loss: 0.6032 - val_accuracy: 0.6915
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5359 - accuracy: 0.7063
# Epoch 11: val_accuracy improved from 0.78607 to 0.80100, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 3s 102ms/step - loss: 0.5346 - accuracy: 0.7063 - val_loss: 0.4571 - val_accuracy: 0.8010
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5254 - accuracy: 0.7250
# Epoch 12: val_accuracy improved from 0.80100 to 0.82587, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 83ms/step - loss: 0.5234 - accuracy: 0.7249 - val_loss: 0.3766 - val_accuracy: 0.8259
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5619 - accuracy: 0.7175
# Epoch 13: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5607 - accuracy: 0.7162 - val_loss: 0.4751 - val_accuracy: 0.7463
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5011 - accuracy: 0.7625
# Epoch 14: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4990 - accuracy: 0.7633 - val_loss: 0.4579 - val_accuracy: 0.7960
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5491 - accuracy: 0.7250
# Epoch 15: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5475 - accuracy: 0.7261 - val_loss: 0.4479 - val_accuracy: 0.7413
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5417 - accuracy: 0.7362
# Epoch 16: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5403 - accuracy: 0.7361 - val_loss: 0.4301 - val_accuracy: 0.8010
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4801 - accuracy: 0.7788
# Epoch 17: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4773 - accuracy: 0.7807 - val_loss: 0.5345 - val_accuracy: 0.7114
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4457 - accuracy: 0.7925
# Epoch 18: val_accuracy did not improve from 0.82587
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4438 - accuracy: 0.7943 - val_loss: 0.9422 - val_accuracy: 0.6269
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4231 - accuracy: 0.8075
# Epoch 19: val_accuracy improved from 0.82587 to 0.83582, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 3s 103ms/step - loss: 0.4199 - accuracy: 0.8092 - val_loss: 0.4183 - val_accuracy: 0.8358
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4358 - accuracy: 0.8037
# Epoch 20: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4356 - accuracy: 0.8030 - val_loss: 0.4269 - val_accuracy: 0.7960
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4566 - accuracy: 0.8100
# Epoch 21: val_accuracy improved from 0.83582 to 0.86070, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.4543 - accuracy: 0.8116 - val_loss: 0.3675 - val_accuracy: 0.8607
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3948 - accuracy: 0.8175
# Epoch 22: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3922 - accuracy: 0.8191 - val_loss: 0.3850 - val_accuracy: 0.8408
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3585 - accuracy: 0.8450
# Epoch 23: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3558 - accuracy: 0.8463 - val_loss: 0.3731 - val_accuracy: 0.8358
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3722 - accuracy: 0.8400
# Epoch 24: val_accuracy improved from 0.86070 to 0.88060, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 83ms/step - loss: 0.3699 - accuracy: 0.8414 - val_loss: 0.2700 - val_accuracy: 0.8806
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3722 - accuracy: 0.8487
# Epoch 25: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3705 - accuracy: 0.8501 - val_loss: 0.2942 - val_accuracy: 0.8706
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3370 - accuracy: 0.8550
# Epoch 26: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3353 - accuracy: 0.8563 - val_loss: 0.2776 - val_accuracy: 0.8806
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3348 - accuracy: 0.8562
# Epoch 27: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3329 - accuracy: 0.8575 - val_loss: 0.2780 - val_accuracy: 0.8607
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3083 - accuracy: 0.8675
# Epoch 28: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3070 - accuracy: 0.8686 - val_loss: 0.3516 - val_accuracy: 0.8308
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2952 - accuracy: 0.8750
# Epoch 29: val_accuracy improved from 0.88060 to 0.89055, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.2934 - accuracy: 0.8761 - val_loss: 0.2599 - val_accuracy: 0.8905
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2747 - accuracy: 0.8913
# Epoch 30: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2730 - accuracy: 0.8922 - val_loss: 0.3269 - val_accuracy: 0.8557
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2850 - accuracy: 0.8850
# Epoch 31: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2833 - accuracy: 0.8860 - val_loss: 0.2694 - val_accuracy: 0.8905
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2985 - accuracy: 0.8737
# Epoch 32: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2974 - accuracy: 0.8748 - val_loss: 0.2724 - val_accuracy: 0.8856
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2840 - accuracy: 0.8750
# Epoch 33: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2838 - accuracy: 0.8748 - val_loss: 0.3262 - val_accuracy: 0.8756
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2833 - accuracy: 0.8838
# Epoch 34: val_accuracy improved from 0.89055 to 0.92040, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.2813 - accuracy: 0.8848 - val_loss: 0.2335 - val_accuracy: 0.9204
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2575 - accuracy: 0.9000
# Epoch 35: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2563 - accuracy: 0.9009 - val_loss: 0.3151 - val_accuracy: 0.8806
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2574 - accuracy: 0.8938
# Epoch 36: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2557 - accuracy: 0.8947 - val_loss: 0.2369 - val_accuracy: 0.9154
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2418 - accuracy: 0.9087
# Epoch 37: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 72ms/step - loss: 0.2405 - accuracy: 0.9095 - val_loss: 0.2092 - val_accuracy: 0.9204
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2228 - accuracy: 0.9087
# Epoch 38: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2214 - accuracy: 0.9095 - val_loss: 0.2703 - val_accuracy: 0.9005
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2169 - accuracy: 0.9150
# Epoch 39: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2156 - accuracy: 0.9157 - val_loss: 0.2045 - val_accuracy: 0.9204
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2123 - accuracy: 0.9187
# Epoch 40: val_accuracy improved from 0.92040 to 0.92537, saving model to /content/drive/MyDrive/fabric_classification/Model-2b-Aug-fs.h5
# 26/26 [==============================] - 3s 103ms/step - loss: 0.2109 - accuracy: 0.9195 - val_loss: 0.2104 - val_accuracy: 0.9254
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2121 - accuracy: 0.9087
# Epoch 41: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2109 - accuracy: 0.9095 - val_loss: 0.2244 - val_accuracy: 0.8856
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2495 - accuracy: 0.8838
# Epoch 42: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2480 - accuracy: 0.8848 - val_loss: 0.2101 - val_accuracy: 0.9055
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2624 - accuracy: 0.8888
# Epoch 43: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2608 - accuracy: 0.8897 - val_loss: 0.2385 - val_accuracy: 0.8955
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2250 - accuracy: 0.8988
# Epoch 44: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2239 - accuracy: 0.8996 - val_loss: 0.2292 - val_accuracy: 0.9055
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2094 - accuracy: 0.9112
# Epoch 45: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2079 - accuracy: 0.9120 - val_loss: 0.5130 - val_accuracy: 0.8159
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2768 - accuracy: 0.8888
# Epoch 46: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2756 - accuracy: 0.8897 - val_loss: 0.2643 - val_accuracy: 0.9154
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2053 - accuracy: 0.9262
# Epoch 47: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2045 - accuracy: 0.9269 - val_loss: 0.2540 - val_accuracy: 0.8756
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2117 - accuracy: 0.9025
# Epoch 48: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.2116 - accuracy: 0.9021 - val_loss: 0.2045 - val_accuracy: 0.9154
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1743 - accuracy: 0.9325
# Epoch 49: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.1734 - accuracy: 0.9331 - val_loss: 0.2259 - val_accuracy: 0.9154
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1658 - accuracy: 0.9413
# Epoch 50: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 71ms/step - loss: 0.1653 - accuracy: 0.9418 - val_loss: 0.2477 - val_accuracy: 0.9055
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  dropout (Dropout)           (None, 96, 96, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[127  13]
#  [  6  55]]
# 0
