# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-2a-NoAug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 1.0742 - accuracy: 0.6022
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-NoAug-fs.h5
# 26/26 [==============================] - 118s 3s/step - loss: 1.0742 - accuracy: 0.6022 - val_loss: 0.6154 - val_accuracy: 0.6965
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6294 - accuracy: 0.6438
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 121ms/step - loss: 0.6286 - accuracy: 0.6431 - val_loss: 0.5111 - val_accuracy: 0.6965
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5534 - accuracy: 0.7163
# Epoch 3: val_accuracy improved from 0.69652 to 0.86070, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-NoAug-fs.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.5513 - accuracy: 0.7187 - val_loss: 0.4630 - val_accuracy: 0.8607
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4559 - accuracy: 0.7975
# Epoch 4: val_accuracy improved from 0.86070 to 0.91542, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-NoAug-fs.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.4543 - accuracy: 0.7993 - val_loss: 0.4832 - val_accuracy: 0.9154
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2928 - accuracy: 0.9225
# Epoch 5: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 121ms/step - loss: 0.2908 - accuracy: 0.9232 - val_loss: 0.2796 - val_accuracy: 0.8706
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1435 - accuracy: 0.9500
# Epoch 6: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 122ms/step - loss: 0.1424 - accuracy: 0.9504 - val_loss: 0.2708 - val_accuracy: 0.9055
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0548 - accuracy: 0.9900
# Epoch 7: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 122ms/step - loss: 0.0543 - accuracy: 0.9901 - val_loss: 0.4339 - val_accuracy: 0.8408
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0528 - accuracy: 0.9837
# Epoch 8: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0524 - accuracy: 0.9839 - val_loss: 0.6038 - val_accuracy: 0.7562
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0385 - accuracy: 0.9975
# Epoch 9: val_accuracy improved from 0.91542 to 0.95025, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-NoAug-fs.h5
# 26/26 [==============================] - 4s 166ms/step - loss: 0.0382 - accuracy: 0.9975 - val_loss: 0.1693 - val_accuracy: 0.9502
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0280 - accuracy: 0.9950
# Epoch 10: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0278 - accuracy: 0.9950 - val_loss: 0.5906 - val_accuracy: 0.7910
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0360 - accuracy: 0.9925
# Epoch 11: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0356 - accuracy: 0.9926 - val_loss: 0.6377 - val_accuracy: 0.7313
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0418 - accuracy: 0.9950
# Epoch 12: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 122ms/step - loss: 0.0415 - accuracy: 0.9950 - val_loss: 0.2445 - val_accuracy: 0.8955
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0157 - accuracy: 0.9987
# Epoch 13: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0170 - accuracy: 0.9975 - val_loss: 0.3573 - val_accuracy: 0.8657
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 0.9962
# Epoch 14: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0235 - accuracy: 0.9963 - val_loss: 0.3013 - val_accuracy: 0.8806
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 0.9925
# Epoch 15: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0235 - accuracy: 0.9926 - val_loss: 0.6764 - val_accuracy: 0.7562
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0442 - accuracy: 0.9950
# Epoch 16: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0438 - accuracy: 0.9950 - val_loss: 0.2150 - val_accuracy: 0.9254
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0063 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1705 - val_accuracy: 0.9403
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.7709e-04 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 5.7210e-04 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9353
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.6769e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 123ms/step - loss: 3.6451e-04 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9303
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.8563e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 2.8317e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9254
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.3939e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 2.3732e-04 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9303
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.8622e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 1.8461e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9204
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3775e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 1.3656e-04 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9303
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1006e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 1.0911e-04 - accuracy: 1.0000 - val_loss: 0.1753 - val_accuracy: 0.9303
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 7.7698e-05 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 7.7031e-05 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9303
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 7.2959e-05 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 7.2332e-05 - accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9254
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.1483e-05 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 4.1130e-05 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9254
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.0553e-05 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 3.0296e-05 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 0.9254
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.3554e-05 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 2.3359e-05 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9254
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.8398e-05 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 1.8251e-05 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9254
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.4803e-05 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 1.4687e-05 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9303
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.2265e-05 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 1.2173e-05 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9353
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0570e-05 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 126ms/step - loss: 1.0493e-05 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9353
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 9.3101e-06 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 9.2429e-06 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9403
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 8.3660e-06 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 126ms/step - loss: 8.3064e-06 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9403
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 7.6292e-06 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 7.5753e-06 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9403
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 7.0257e-06 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 6.9767e-06 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9403
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4907e-06 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4463e-06 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9403
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.9828e-06 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 5.9435e-06 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9353
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.5035e-06 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 5.4693e-06 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9303
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.0623e-06 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 5.0328e-06 - accuracy: 1.0000 - val_loss: 0.2202 - val_accuracy: 0.9353
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.6635e-06 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 4.6379e-06 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9303
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.2959e-06 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 4.2729e-06 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9303
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.9401e-06 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 3.9186e-06 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9303
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.6005e-06 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 3.5805e-06 - accuracy: 1.0000 - val_loss: 0.2333 - val_accuracy: 0.9254
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.2782e-06 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 3.2597e-06 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9254
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.0009e-06 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 2.9836e-06 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9303
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.7615e-06 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 2.7453e-06 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9303
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.5584e-06 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 2.5434e-06 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9303
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.3824e-06 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 125ms/step - loss: 2.3685e-06 - accuracy: 1.0000 - val_loss: 0.2344 - val_accuracy: 0.9303
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[135   5]
#  [  9  52]]
# 0
