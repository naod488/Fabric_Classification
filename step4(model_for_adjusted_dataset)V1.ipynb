# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.Dropout(0.8),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 2.0390 - accuracy: 0.4830
# Epoch 1: val_accuracy improved from -inf to 0.47441, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 281s 2s/step - loss: 2.0390 - accuracy: 0.4830 - val_loss: 1.5589 - val_accuracy: 0.4744
# Epoch 2/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.5523 - accuracy: 0.5085
# Epoch 2: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 135ms/step - loss: 1.5516 - accuracy: 0.5091 - val_loss: 1.5017 - val_accuracy: 0.4744
# Epoch 3/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.5302 - accuracy: 0.5080
# Epoch 3: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 133ms/step - loss: 1.5292 - accuracy: 0.5085 - val_loss: 1.4729 - val_accuracy: 0.4744
# Epoch 4/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4879 - accuracy: 0.5075
# Epoch 4: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4878 - accuracy: 0.5080 - val_loss: 1.4599 - val_accuracy: 0.4744
# Epoch 5/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4889 - accuracy: 0.5075
# Epoch 5: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 15s 131ms/step - loss: 1.4887 - accuracy: 0.5080 - val_loss: 1.4674 - val_accuracy: 0.4744
# Epoch 6/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4865 - accuracy: 0.5075
# Epoch 6: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4858 - accuracy: 0.5080 - val_loss: 1.4445 - val_accuracy: 0.4744
# Epoch 7/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4749 - accuracy: 0.5075
# Epoch 7: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4743 - accuracy: 0.5080 - val_loss: 1.4644 - val_accuracy: 0.4744
# Epoch 8/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4567 - accuracy: 0.5075
# Epoch 8: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4567 - accuracy: 0.5080 - val_loss: 1.4312 - val_accuracy: 0.4744
# Epoch 9/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4467 - accuracy: 0.5075
# Epoch 9: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4466 - accuracy: 0.5080 - val_loss: 1.4314 - val_accuracy: 0.4744
# Epoch 10/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4521 - accuracy: 0.5118
# Epoch 10: val_accuracy did not improve from 0.47441
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4517 - accuracy: 0.5123 - val_loss: 1.4294 - val_accuracy: 0.4744
# Epoch 11/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4505 - accuracy: 0.5083
# Epoch 11: val_accuracy improved from 0.47441 to 0.47548, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 16s 140ms/step - loss: 1.4500 - accuracy: 0.5088 - val_loss: 1.4237 - val_accuracy: 0.4755
# Epoch 12/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4309 - accuracy: 0.5184
# Epoch 12: val_accuracy improved from 0.47548 to 0.53518, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 18s 150ms/step - loss: 1.4302 - accuracy: 0.5189 - val_loss: 1.3991 - val_accuracy: 0.5352
# Epoch 13/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4285 - accuracy: 0.5219
# Epoch 13: val_accuracy improved from 0.53518 to 0.54904, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 140ms/step - loss: 1.4278 - accuracy: 0.5224 - val_loss: 1.4000 - val_accuracy: 0.5490
# Epoch 14/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4219 - accuracy: 0.5208
# Epoch 14: val_accuracy did not improve from 0.54904
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4215 - accuracy: 0.5213 - val_loss: 1.3917 - val_accuracy: 0.5341
# Epoch 15/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4187 - accuracy: 0.5254
# Epoch 15: val_accuracy did not improve from 0.54904
# 118/118 [==============================] - 16s 132ms/step - loss: 1.4178 - accuracy: 0.5258 - val_loss: 1.4094 - val_accuracy: 0.5011
# Epoch 16/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4189 - accuracy: 0.5270
# Epoch 16: val_accuracy did not improve from 0.54904
# 118/118 [==============================] - 15s 131ms/step - loss: 1.4183 - accuracy: 0.5274 - val_loss: 1.3719 - val_accuracy: 0.5480
# Epoch 17/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4100 - accuracy: 0.5302
# Epoch 17: val_accuracy improved from 0.54904 to 0.55650, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 140ms/step - loss: 1.4092 - accuracy: 0.5306 - val_loss: 1.3514 - val_accuracy: 0.5565
# Epoch 18/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4005 - accuracy: 0.5398
# Epoch 18: val_accuracy did not improve from 0.55650
# 118/118 [==============================] - 15s 131ms/step - loss: 1.4000 - accuracy: 0.5402 - val_loss: 1.3440 - val_accuracy: 0.5565
# Epoch 19/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3819 - accuracy: 0.5446
# Epoch 19: val_accuracy improved from 0.55650 to 0.56716, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 140ms/step - loss: 1.3813 - accuracy: 0.5450 - val_loss: 1.3358 - val_accuracy: 0.5672
# Epoch 20/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3880 - accuracy: 0.5443
# Epoch 20: val_accuracy did not improve from 0.56716
# 118/118 [==============================] - 16s 131ms/step - loss: 1.3871 - accuracy: 0.5448 - val_loss: 1.3329 - val_accuracy: 0.5608
# Epoch 21/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3693 - accuracy: 0.5481
# Epoch 21: val_accuracy improved from 0.56716 to 0.56930, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 1.3686 - accuracy: 0.5485 - val_loss: 1.3213 - val_accuracy: 0.5693
# Epoch 22/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3867 - accuracy: 0.5510
# Epoch 22: val_accuracy did not improve from 0.56930
# 118/118 [==============================] - 16s 132ms/step - loss: 1.3859 - accuracy: 0.5514 - val_loss: 1.3387 - val_accuracy: 0.5533
# Epoch 23/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3740 - accuracy: 0.5596
# Epoch 23: val_accuracy did not improve from 0.56930
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3733 - accuracy: 0.5599 - val_loss: 1.3129 - val_accuracy: 0.5576
# Epoch 24/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3585 - accuracy: 0.5649
# Epoch 24: val_accuracy improved from 0.56930 to 0.57569, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.3577 - accuracy: 0.5653 - val_loss: 1.3058 - val_accuracy: 0.5757
# Epoch 25/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3533 - accuracy: 0.5556
# Epoch 25: val_accuracy did not improve from 0.57569
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3525 - accuracy: 0.5559 - val_loss: 1.3084 - val_accuracy: 0.5693
# Epoch 26/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3529 - accuracy: 0.5558
# Epoch 26: val_accuracy did not improve from 0.57569
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3523 - accuracy: 0.5562 - val_loss: 1.2871 - val_accuracy: 0.5629
# Epoch 27/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3413 - accuracy: 0.5574
# Epoch 27: val_accuracy did not improve from 0.57569
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3405 - accuracy: 0.5578 - val_loss: 1.2971 - val_accuracy: 0.5597
# Epoch 28/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3377 - accuracy: 0.5652
# Epoch 28: val_accuracy improved from 0.57569 to 0.58102, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 140ms/step - loss: 1.3368 - accuracy: 0.5655 - val_loss: 1.2756 - val_accuracy: 0.5810
# Epoch 29/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3317 - accuracy: 0.5710
# Epoch 29: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3306 - accuracy: 0.5714 - val_loss: 1.2695 - val_accuracy: 0.5725
# Epoch 30/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3248 - accuracy: 0.5702
# Epoch 30: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3243 - accuracy: 0.5706 - val_loss: 1.2871 - val_accuracy: 0.5640
# Epoch 31/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3141 - accuracy: 0.5649
# Epoch 31: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3131 - accuracy: 0.5653 - val_loss: 1.2595 - val_accuracy: 0.5704
# Epoch 32/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3297 - accuracy: 0.5620
# Epoch 32: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3288 - accuracy: 0.5623 - val_loss: 1.2592 - val_accuracy: 0.5800
# Epoch 33/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3272 - accuracy: 0.5673
# Epoch 33: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3265 - accuracy: 0.5677 - val_loss: 1.2606 - val_accuracy: 0.5757
# Epoch 34/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3129 - accuracy: 0.5681
# Epoch 34: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3123 - accuracy: 0.5685 - val_loss: 1.2449 - val_accuracy: 0.5725
# Epoch 35/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3242 - accuracy: 0.5609
# Epoch 35: val_accuracy did not improve from 0.58102
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3237 - accuracy: 0.5613 - val_loss: 1.2611 - val_accuracy: 0.5736
# Epoch 36/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2988 - accuracy: 0.5662
# Epoch 36: val_accuracy improved from 0.58102 to 0.58209, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V1.h5
# 118/118 [==============================] - 17s 140ms/step - loss: 1.2982 - accuracy: 0.5666 - val_loss: 1.2404 - val_accuracy: 0.5821
# Epoch 37/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3019 - accuracy: 0.5708
# Epoch 37: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3011 - accuracy: 0.5711 - val_loss: 1.2435 - val_accuracy: 0.5693
# Epoch 38/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3027 - accuracy: 0.5657
# Epoch 38: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3019 - accuracy: 0.5661 - val_loss: 1.2413 - val_accuracy: 0.5736
# Epoch 39/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2968 - accuracy: 0.5670
# Epoch 39: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.2962 - accuracy: 0.5674 - val_loss: 1.2370 - val_accuracy: 0.5650
# Epoch 40/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3017 - accuracy: 0.5614
# Epoch 40: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.3008 - accuracy: 0.5618 - val_loss: 1.2455 - val_accuracy: 0.5693
# Epoch 41/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2814 - accuracy: 0.5708
# Epoch 41: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.2807 - accuracy: 0.5711 - val_loss: 1.2238 - val_accuracy: 0.5714
# Epoch 42/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2920 - accuracy: 0.5660
# Epoch 42: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2915 - accuracy: 0.5663 - val_loss: 1.2367 - val_accuracy: 0.5736
# Epoch 43/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2745 - accuracy: 0.5705
# Epoch 43: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2740 - accuracy: 0.5709 - val_loss: 1.2313 - val_accuracy: 0.5618
# Epoch 44/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2809 - accuracy: 0.5740
# Epoch 44: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2804 - accuracy: 0.5743 - val_loss: 1.2248 - val_accuracy: 0.5704
# Epoch 45/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2723 - accuracy: 0.5700
# Epoch 45: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 131ms/step - loss: 1.2717 - accuracy: 0.5703 - val_loss: 1.2261 - val_accuracy: 0.5725
# Epoch 46/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2758 - accuracy: 0.5767
# Epoch 46: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2751 - accuracy: 0.5770 - val_loss: 1.2303 - val_accuracy: 0.5725
# Epoch 47/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2663 - accuracy: 0.5718
# Epoch 47: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2657 - accuracy: 0.5722 - val_loss: 1.2321 - val_accuracy: 0.5704
# Epoch 48/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2733 - accuracy: 0.5668
# Epoch 48: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2727 - accuracy: 0.5669 - val_loss: 1.2286 - val_accuracy: 0.5736
# Epoch 49/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2675 - accuracy: 0.5724
# Epoch 49: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2670 - accuracy: 0.5727 - val_loss: 1.2092 - val_accuracy: 0.5672
# Epoch 50/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2722 - accuracy: 0.5689
# Epoch 50: val_accuracy did not improve from 0.58209
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2716 - accuracy: 0.5693 - val_loss: 1.2237 - val_accuracy: 0.5554
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 9,457,478
# Trainable params: 9,457,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (938, 6)
# (938,)
# (938,)
# [[423   0   0  22   0   0]
#  [138   0   0   0   0   0]
#  [ 36   0   0   4   0   0]
#  [105   0   0  87   2   0]
#  [  6   0   0  23  11   0]
#  [ 72   0   0   9   0   0]]
