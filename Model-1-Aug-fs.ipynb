# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

print(tf.__version__)
import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
data_dir = pathlib.Path(path)
# Out:
# 2.8.0

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
my_utils.display_augmentation(train_ds, data_augmentation)
# Out:
# 0

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-1-Aug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 18.3825 - accuracy: 0.5527
# Epoch 1: val_accuracy improved from -inf to 0.72139, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 15s 529ms/step - loss: 18.3825 - accuracy: 0.5527 - val_loss: 0.7527 - val_accuracy: 0.7214
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.7586 - accuracy: 0.6555
# Epoch 2: val_accuracy improved from 0.72139 to 0.78109, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 477ms/step - loss: 0.7586 - accuracy: 0.6555 - val_loss: 0.4844 - val_accuracy: 0.7811
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.6964
# Epoch 3: val_accuracy improved from 0.78109 to 0.81095, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 483ms/step - loss: 0.6837 - accuracy: 0.6964 - val_loss: 0.4476 - val_accuracy: 0.8109
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6208 - accuracy: 0.7051
# Epoch 4: val_accuracy did not improve from 0.81095
# 26/26 [==============================] - 3s 121ms/step - loss: 0.6208 - accuracy: 0.7051 - val_loss: 0.4472 - val_accuracy: 0.8109
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.7100
# Epoch 5: val_accuracy improved from 0.81095 to 0.82090, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 464ms/step - loss: 0.5994 - accuracy: 0.7100 - val_loss: 0.4248 - val_accuracy: 0.8209
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5615 - accuracy: 0.7237
# Epoch 6: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.5615 - accuracy: 0.7237 - val_loss: 0.4374 - val_accuracy: 0.8209
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5942 - accuracy: 0.7286
# Epoch 7: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.5942 - accuracy: 0.7286 - val_loss: 0.4472 - val_accuracy: 0.8109
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.7323
# Epoch 8: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.5697 - accuracy: 0.7323 - val_loss: 0.4624 - val_accuracy: 0.7811
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5744 - accuracy: 0.7237
# Epoch 9: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 128ms/step - loss: 0.5744 - accuracy: 0.7237 - val_loss: 0.6435 - val_accuracy: 0.7413
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5484 - accuracy: 0.7348
# Epoch 10: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5484 - accuracy: 0.7348 - val_loss: 0.4692 - val_accuracy: 0.7662
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5165 - accuracy: 0.7633
# Epoch 11: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5165 - accuracy: 0.7633 - val_loss: 0.4289 - val_accuracy: 0.7861
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.7571
# Epoch 12: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 127ms/step - loss: 0.5073 - accuracy: 0.7571 - val_loss: 0.5296 - val_accuracy: 0.7612
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5499 - accuracy: 0.7410
# Epoch 13: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 126ms/step - loss: 0.5499 - accuracy: 0.7410 - val_loss: 0.3711 - val_accuracy: 0.8209
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5889 - accuracy: 0.7311
# Epoch 14: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.5889 - accuracy: 0.7311 - val_loss: 0.4473 - val_accuracy: 0.7662
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.7745
# Epoch 15: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.4679 - accuracy: 0.7745 - val_loss: 0.3738 - val_accuracy: 0.8060
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4420 - accuracy: 0.7869
# Epoch 16: val_accuracy did not improve from 0.82090
# 26/26 [==============================] - 3s 121ms/step - loss: 0.4420 - accuracy: 0.7869 - val_loss: 0.3842 - val_accuracy: 0.8010
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4330 - accuracy: 0.8055
# Epoch 17: val_accuracy improved from 0.82090 to 0.84577, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 13s 522ms/step - loss: 0.4330 - accuracy: 0.8055 - val_loss: 0.3428 - val_accuracy: 0.8458
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4400 - accuracy: 0.8141
# Epoch 18: val_accuracy did not improve from 0.84577
# 26/26 [==============================] - 3s 132ms/step - loss: 0.4400 - accuracy: 0.8141 - val_loss: 0.3392 - val_accuracy: 0.8259
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.7844
# Epoch 19: val_accuracy improved from 0.84577 to 0.86070, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 470ms/step - loss: 0.4574 - accuracy: 0.7844 - val_loss: 0.3432 - val_accuracy: 0.8607
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4268 - accuracy: 0.8129
# Epoch 20: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 122ms/step - loss: 0.4268 - accuracy: 0.8129 - val_loss: 0.3416 - val_accuracy: 0.8557
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8265
# Epoch 21: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 121ms/step - loss: 0.4105 - accuracy: 0.8265 - val_loss: 0.3273 - val_accuracy: 0.8557
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.8389
# Epoch 22: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 127ms/step - loss: 0.3827 - accuracy: 0.8389 - val_loss: 0.3096 - val_accuracy: 0.8557
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3604 - accuracy: 0.8377
# Epoch 23: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 127ms/step - loss: 0.3604 - accuracy: 0.8377 - val_loss: 0.3268 - val_accuracy: 0.8358
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8463
# Epoch 24: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 127ms/step - loss: 0.3641 - accuracy: 0.8463 - val_loss: 0.3326 - val_accuracy: 0.8458
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8451
# Epoch 25: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 128ms/step - loss: 0.3499 - accuracy: 0.8451 - val_loss: 0.3099 - val_accuracy: 0.8557
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8439
# Epoch 26: val_accuracy improved from 0.86070 to 0.86567, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 470ms/step - loss: 0.3613 - accuracy: 0.8439 - val_loss: 0.3510 - val_accuracy: 0.8657
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4186 - accuracy: 0.8228
# Epoch 27: val_accuracy improved from 0.86567 to 0.87065, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 468ms/step - loss: 0.4186 - accuracy: 0.8228 - val_loss: 0.3072 - val_accuracy: 0.8706
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8563
# Epoch 28: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 3s 121ms/step - loss: 0.3551 - accuracy: 0.8563 - val_loss: 0.2929 - val_accuracy: 0.8607
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8563
# Epoch 29: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 3s 122ms/step - loss: 0.3492 - accuracy: 0.8563 - val_loss: 0.3273 - val_accuracy: 0.8458
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8278
# Epoch 30: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 3s 126ms/step - loss: 0.3795 - accuracy: 0.8278 - val_loss: 0.3164 - val_accuracy: 0.8657
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8451
# Epoch 31: val_accuracy improved from 0.87065 to 0.88557, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 481ms/step - loss: 0.3687 - accuracy: 0.8451 - val_loss: 0.2776 - val_accuracy: 0.8856
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8476
# Epoch 32: val_accuracy improved from 0.88557 to 0.89552, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 476ms/step - loss: 0.3346 - accuracy: 0.8476 - val_loss: 0.2589 - val_accuracy: 0.8955
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8662
# Epoch 33: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 123ms/step - loss: 0.3324 - accuracy: 0.8662 - val_loss: 0.3005 - val_accuracy: 0.8905
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.8426
# Epoch 34: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 125ms/step - loss: 0.3624 - accuracy: 0.8426 - val_loss: 0.2883 - val_accuracy: 0.8657
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8587
# Epoch 35: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 128ms/step - loss: 0.3325 - accuracy: 0.8587 - val_loss: 0.3171 - val_accuracy: 0.8408
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.8575
# Epoch 36: val_accuracy improved from 0.89552 to 0.90547, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 467ms/step - loss: 0.3448 - accuracy: 0.8575 - val_loss: 0.2656 - val_accuracy: 0.9055
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8637
# Epoch 37: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 3s 121ms/step - loss: 0.3367 - accuracy: 0.8637 - val_loss: 0.3244 - val_accuracy: 0.8557
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3304 - accuracy: 0.8525
# Epoch 38: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 3s 125ms/step - loss: 0.3304 - accuracy: 0.8525 - val_loss: 0.2762 - val_accuracy: 0.8806
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8748
# Epoch 39: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 3s 126ms/step - loss: 0.3141 - accuracy: 0.8748 - val_loss: 0.2788 - val_accuracy: 0.8856
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8786
# Epoch 40: val_accuracy improved from 0.90547 to 0.91045, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 12s 474ms/step - loss: 0.2869 - accuracy: 0.8786 - val_loss: 0.2608 - val_accuracy: 0.9104
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8773
# Epoch 41: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 130ms/step - loss: 0.2987 - accuracy: 0.8773 - val_loss: 0.3087 - val_accuracy: 0.8657
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8587
# Epoch 42: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 126ms/step - loss: 0.3266 - accuracy: 0.8587 - val_loss: 0.2905 - val_accuracy: 0.8706
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.8810
# Epoch 43: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 128ms/step - loss: 0.2878 - accuracy: 0.8810 - val_loss: 0.2583 - val_accuracy: 0.8557
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3076 - accuracy: 0.8686
# Epoch 44: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 3s 124ms/step - loss: 0.3076 - accuracy: 0.8686 - val_loss: 0.2616 - val_accuracy: 0.8806
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.8711
# Epoch 45: val_accuracy improved from 0.91045 to 0.94527, saving model to /content/drive/MyDrive/fabric_classification/Model-1-Aug-fs.h5
# 26/26 [==============================] - 13s 524ms/step - loss: 0.2796 - accuracy: 0.8711 - val_loss: 0.2201 - val_accuracy: 0.9453
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8823
# Epoch 46: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 128ms/step - loss: 0.2807 - accuracy: 0.8823 - val_loss: 0.2671 - val_accuracy: 0.8706
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8600
# Epoch 47: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 127ms/step - loss: 0.3125 - accuracy: 0.8600 - val_loss: 0.2526 - val_accuracy: 0.9005
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.8699
# Epoch 48: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 126ms/step - loss: 0.2940 - accuracy: 0.8699 - val_loss: 0.2780 - val_accuracy: 0.8557
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.8897
# Epoch 49: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 126ms/step - loss: 0.2731 - accuracy: 0.8897 - val_loss: 0.2098 - val_accuracy: 0.9303
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.8773
# Epoch 50: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2727 - accuracy: 0.8773 - val_loss: 0.2212 - val_accuracy: 0.9353
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 400, 400, 3)       0
#
#  conv2d_1 (Conv2D)           (None, 398, 398, 32)      896
#
#  max_pooling2d_1 (MaxPooling  (None, 199, 199, 32)     0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1267232)           0
#
#  dense_2 (Dense)             (None, 128)               162205824
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 162,206,978
# Trainable params: 162,206,978
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[138   2]
#  [ 11  50]]
# 0
