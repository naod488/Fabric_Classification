# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.Dropout(0.8),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.8),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
checkpoint = ModelCheckpoint(filepath = 's_model_NoAug_NoOptv2.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.9181 - accuracy: 0.5936
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 183s 5s/step - loss: 0.9181 - accuracy: 0.5936 - val_loss: 0.6259 - val_accuracy: 0.6965
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6722 - accuracy: 0.6275
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 122ms/step - loss: 0.6741 - accuracy: 0.6270 - val_loss: 0.6315 - val_accuracy: 0.6965
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6649 - accuracy: 0.6313
# Epoch 3: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 123ms/step - loss: 0.6639 - accuracy: 0.6307 - val_loss: 0.5559 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6430 - accuracy: 0.6538
# Epoch 4: val_accuracy improved from 0.69652 to 0.71144, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.6409 - accuracy: 0.6543 - val_loss: 0.5287 - val_accuracy: 0.7114
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6260 - accuracy: 0.6375
# Epoch 5: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 122ms/step - loss: 0.6255 - accuracy: 0.6369 - val_loss: 0.5933 - val_accuracy: 0.6965
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6153 - accuracy: 0.6300
# Epoch 6: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 122ms/step - loss: 0.6147 - accuracy: 0.6295 - val_loss: 0.5482 - val_accuracy: 0.6965
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5860 - accuracy: 0.6313
# Epoch 7: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5854 - accuracy: 0.6307 - val_loss: 0.5493 - val_accuracy: 0.6965
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5713 - accuracy: 0.6413
# Epoch 8: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5701 - accuracy: 0.6406 - val_loss: 0.5040 - val_accuracy: 0.7065
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5606 - accuracy: 0.6725
# Epoch 9: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5595 - accuracy: 0.6729 - val_loss: 0.5311 - val_accuracy: 0.6965
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5426 - accuracy: 0.7038
# Epoch 10: val_accuracy improved from 0.71144 to 0.76617, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.5414 - accuracy: 0.7051 - val_loss: 0.4946 - val_accuracy: 0.7662
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4714 - accuracy: 0.7525
# Epoch 11: val_accuracy improved from 0.76617 to 0.79602, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.4707 - accuracy: 0.7522 - val_loss: 0.4711 - val_accuracy: 0.7960
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4444 - accuracy: 0.7788
# Epoch 12: val_accuracy did not improve from 0.79602
# 26/26 [==============================] - 3s 123ms/step - loss: 0.4435 - accuracy: 0.7794 - val_loss: 0.4433 - val_accuracy: 0.7910
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4341 - accuracy: 0.8025
# Epoch 13: val_accuracy did not improve from 0.79602
# 26/26 [==============================] - 3s 123ms/step - loss: 0.4332 - accuracy: 0.8030 - val_loss: 0.4881 - val_accuracy: 0.7960
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3842 - accuracy: 0.8263
# Epoch 14: val_accuracy improved from 0.79602 to 0.81095, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.3825 - accuracy: 0.8278 - val_loss: 0.4165 - val_accuracy: 0.8109
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3564 - accuracy: 0.8413
# Epoch 15: val_accuracy did not improve from 0.81095
# 26/26 [==============================] - 3s 123ms/step - loss: 0.3548 - accuracy: 0.8426 - val_loss: 0.4143 - val_accuracy: 0.8060
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3629 - accuracy: 0.8338
# Epoch 16: val_accuracy improved from 0.81095 to 0.81592, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.3611 - accuracy: 0.8352 - val_loss: 0.3892 - val_accuracy: 0.8159
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2784 - accuracy: 0.8750
# Epoch 17: val_accuracy improved from 0.81592 to 0.82587, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 4s 142ms/step - loss: 0.2851 - accuracy: 0.8724 - val_loss: 0.4306 - val_accuracy: 0.8259
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3661 - accuracy: 0.8475
# Epoch 18: val_accuracy improved from 0.82587 to 0.84080, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.3639 - accuracy: 0.8488 - val_loss: 0.4029 - val_accuracy: 0.8408
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3461 - accuracy: 0.8525
# Epoch 19: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 123ms/step - loss: 0.3449 - accuracy: 0.8538 - val_loss: 0.4082 - val_accuracy: 0.8109
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3330 - accuracy: 0.8537
# Epoch 20: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 123ms/step - loss: 0.3338 - accuracy: 0.8538 - val_loss: 0.4560 - val_accuracy: 0.7861
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2930 - accuracy: 0.8825
# Epoch 21: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2911 - accuracy: 0.8835 - val_loss: 0.3769 - val_accuracy: 0.8159
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3125 - accuracy: 0.8675
# Epoch 22: val_accuracy improved from 0.84080 to 0.84577, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.3104 - accuracy: 0.8686 - val_loss: 0.3671 - val_accuracy: 0.8458
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2729 - accuracy: 0.8925
# Epoch 23: val_accuracy improved from 0.84577 to 0.85075, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2723 - accuracy: 0.8922 - val_loss: 0.3588 - val_accuracy: 0.8507
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2665 - accuracy: 0.8813
# Epoch 24: val_accuracy did not improve from 0.85075
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2653 - accuracy: 0.8823 - val_loss: 0.3611 - val_accuracy: 0.8507
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2691 - accuracy: 0.8875
# Epoch 25: val_accuracy did not improve from 0.85075
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2675 - accuracy: 0.8885 - val_loss: 0.3571 - val_accuracy: 0.8358
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2679 - accuracy: 0.8737
# Epoch 26: val_accuracy did not improve from 0.85075
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2659 - accuracy: 0.8748 - val_loss: 0.3640 - val_accuracy: 0.8308
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2282 - accuracy: 0.8888
# Epoch 27: val_accuracy improved from 0.85075 to 0.86070, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2264 - accuracy: 0.8897 - val_loss: 0.3533 - val_accuracy: 0.8607
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2526 - accuracy: 0.8838
# Epoch 28: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2511 - accuracy: 0.8848 - val_loss: 0.3419 - val_accuracy: 0.8507
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2236 - accuracy: 0.9050
# Epoch 29: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2224 - accuracy: 0.9058 - val_loss: 0.3562 - val_accuracy: 0.8408
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2101 - accuracy: 0.9125
# Epoch 30: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2093 - accuracy: 0.9133 - val_loss: 0.3570 - val_accuracy: 0.8308
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2683 - accuracy: 0.8763
# Epoch 31: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 122ms/step - loss: 0.2677 - accuracy: 0.8761 - val_loss: 0.3301 - val_accuracy: 0.8557
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2239 - accuracy: 0.9100
# Epoch 32: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 122ms/step - loss: 0.2223 - accuracy: 0.9108 - val_loss: 0.3464 - val_accuracy: 0.8259
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2084 - accuracy: 0.9162
# Epoch 33: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2075 - accuracy: 0.9170 - val_loss: 0.3477 - val_accuracy: 0.8358
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2172 - accuracy: 0.9087
# Epoch 34: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2156 - accuracy: 0.9095 - val_loss: 0.3474 - val_accuracy: 0.8607
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2163 - accuracy: 0.9087
# Epoch 35: val_accuracy did not improve from 0.86070
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2150 - accuracy: 0.9095 - val_loss: 0.3231 - val_accuracy: 0.8607
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2104 - accuracy: 0.9062
# Epoch 36: val_accuracy improved from 0.86070 to 0.88060, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2089 - accuracy: 0.9071 - val_loss: 0.3136 - val_accuracy: 0.8806
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2126 - accuracy: 0.9150
# Epoch 37: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2119 - accuracy: 0.9157 - val_loss: 0.3080 - val_accuracy: 0.8706
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1813 - accuracy: 0.9287
# Epoch 38: val_accuracy improved from 0.88060 to 0.89055, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.1802 - accuracy: 0.9294 - val_loss: 0.2945 - val_accuracy: 0.8905
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2131 - accuracy: 0.9112
# Epoch 39: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2114 - accuracy: 0.9120 - val_loss: 0.3131 - val_accuracy: 0.8905
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1986 - accuracy: 0.9187
# Epoch 40: val_accuracy improved from 0.89055 to 0.89552, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2003 - accuracy: 0.9170 - val_loss: 0.3001 - val_accuracy: 0.8955
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1846 - accuracy: 0.9275
# Epoch 41: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1838 - accuracy: 0.9281 - val_loss: 0.3010 - val_accuracy: 0.8905
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1754 - accuracy: 0.9337
# Epoch 42: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1740 - accuracy: 0.9343 - val_loss: 0.2971 - val_accuracy: 0.8955
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1751 - accuracy: 0.9262
# Epoch 43: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1739 - accuracy: 0.9269 - val_loss: 0.2770 - val_accuracy: 0.8806
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1750 - accuracy: 0.9300
# Epoch 44: val_accuracy improved from 0.89552 to 0.90050, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.1736 - accuracy: 0.9306 - val_loss: 0.2795 - val_accuracy: 0.9005
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1919 - accuracy: 0.9275
# Epoch 45: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1904 - accuracy: 0.9281 - val_loss: 0.3194 - val_accuracy: 0.8657
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2005 - accuracy: 0.9175
# Epoch 46: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1994 - accuracy: 0.9182 - val_loss: 0.2998 - val_accuracy: 0.8806
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1951 - accuracy: 0.9287
# Epoch 47: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1941 - accuracy: 0.9294 - val_loss: 0.3036 - val_accuracy: 0.8607
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1458 - accuracy: 0.9488
# Epoch 48: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1446 - accuracy: 0.9492 - val_loss: 0.3356 - val_accuracy: 0.8657
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1738 - accuracy: 0.9375
# Epoch 49: val_accuracy improved from 0.90050 to 0.92040, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.1733 - accuracy: 0.9368 - val_loss: 0.2745 - val_accuracy: 0.9204
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1243 - accuracy: 0.9525
# Epoch 50: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1237 - accuracy: 0.9529 - val_loss: 0.2587 - val_accuracy: 0.9104
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  dropout (Dropout)           (None, 96, 96, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[136   4]
#  [ 14  47]]
