# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(0.5)
    ]
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

norm = 0.00005

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-2c-Aug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 2.5765 - accuracy: 0.6183
# Epoch 1: val_accuracy improved from -inf to 0.69154, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 57s 1s/step - loss: 2.5765 - accuracy: 0.6183 - val_loss: 1.5688 - val_accuracy: 0.6915
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3927 - accuracy: 0.6913
# Epoch 2: val_accuracy improved from 0.69154 to 0.78607, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 1.3908 - accuracy: 0.6914 - val_loss: 1.1954 - val_accuracy: 0.7861
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1331 - accuracy: 0.6837
# Epoch 3: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 1.1327 - accuracy: 0.6828 - val_loss: 1.0285 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0225 - accuracy: 0.6463
# Epoch 4: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 1.0218 - accuracy: 0.6456 - val_loss: 0.8961 - val_accuracy: 0.7015
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.9059 - accuracy: 0.6650
# Epoch 5: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.9054 - accuracy: 0.6642 - val_loss: 0.8136 - val_accuracy: 0.7015
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.8437 - accuracy: 0.6650
# Epoch 6: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.8432 - accuracy: 0.6654 - val_loss: 0.7558 - val_accuracy: 0.7761
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7811 - accuracy: 0.6812
# Epoch 7: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.7814 - accuracy: 0.6803 - val_loss: 0.7339 - val_accuracy: 0.7015
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7841 - accuracy: 0.6538
# Epoch 8: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.7838 - accuracy: 0.6530 - val_loss: 0.7044 - val_accuracy: 0.7015
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7510 - accuracy: 0.6550
# Epoch 9: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.7507 - accuracy: 0.6543 - val_loss: 0.6785 - val_accuracy: 0.7065
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.7113 - accuracy: 0.6812
# Epoch 10: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 71ms/step - loss: 0.7103 - accuracy: 0.6815 - val_loss: 0.5875 - val_accuracy: 0.7811
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6851 - accuracy: 0.7125
# Epoch 11: val_accuracy improved from 0.78607 to 0.80100, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 3s 106ms/step - loss: 0.6843 - accuracy: 0.7125 - val_loss: 0.5962 - val_accuracy: 0.8010
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6905 - accuracy: 0.6888
# Epoch 12: val_accuracy did not improve from 0.80100
# 26/26 [==============================] - 2s 72ms/step - loss: 0.6898 - accuracy: 0.6890 - val_loss: 0.6073 - val_accuracy: 0.7910
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6156 - accuracy: 0.7725
# Epoch 13: val_accuracy did not improve from 0.80100
# 26/26 [==============================] - 2s 72ms/step - loss: 0.6134 - accuracy: 0.7745 - val_loss: 0.8161 - val_accuracy: 0.5821
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6142 - accuracy: 0.7325
# Epoch 14: val_accuracy did not improve from 0.80100
# 26/26 [==============================] - 2s 72ms/step - loss: 0.6150 - accuracy: 0.7311 - val_loss: 0.6328 - val_accuracy: 0.7065
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6715 - accuracy: 0.6762
# Epoch 15: val_accuracy did not improve from 0.80100
# 26/26 [==============================] - 2s 71ms/step - loss: 0.6713 - accuracy: 0.6766 - val_loss: 0.6056 - val_accuracy: 0.7761
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5927 - accuracy: 0.7500
# Epoch 16: val_accuracy did not improve from 0.80100
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5914 - accuracy: 0.7522 - val_loss: 0.7029 - val_accuracy: 0.7015
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6330 - accuracy: 0.7262
# Epoch 17: val_accuracy improved from 0.80100 to 0.80597, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 86ms/step - loss: 0.6314 - accuracy: 0.7261 - val_loss: 0.5189 - val_accuracy: 0.8060
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5996 - accuracy: 0.7450
# Epoch 18: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5971 - accuracy: 0.7472 - val_loss: 0.6025 - val_accuracy: 0.7910
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6149 - accuracy: 0.7188
# Epoch 19: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 72ms/step - loss: 0.6155 - accuracy: 0.7175 - val_loss: 0.5958 - val_accuracy: 0.7264
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6130 - accuracy: 0.7337
# Epoch 20: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.6134 - accuracy: 0.7323 - val_loss: 0.6170 - val_accuracy: 0.7065
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6321 - accuracy: 0.7125
# Epoch 21: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.6305 - accuracy: 0.7125 - val_loss: 0.5059 - val_accuracy: 0.8010
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5672 - accuracy: 0.7775
# Epoch 22: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5663 - accuracy: 0.7770 - val_loss: 0.5498 - val_accuracy: 0.7612
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5841 - accuracy: 0.7450
# Epoch 23: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 73ms/step - loss: 0.5844 - accuracy: 0.7447 - val_loss: 0.5486 - val_accuracy: 0.7413
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5652 - accuracy: 0.7513
# Epoch 24: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5653 - accuracy: 0.7509 - val_loss: 0.5385 - val_accuracy: 0.7612
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5789 - accuracy: 0.7525
# Epoch 25: val_accuracy did not improve from 0.80597
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5790 - accuracy: 0.7509 - val_loss: 0.5676 - val_accuracy: 0.7463
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5864 - accuracy: 0.7600
# Epoch 26: val_accuracy improved from 0.80597 to 0.81592, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 3s 108ms/step - loss: 0.5858 - accuracy: 0.7596 - val_loss: 0.5104 - val_accuracy: 0.8159
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5660 - accuracy: 0.7713
# Epoch 27: val_accuracy did not improve from 0.81592
# 26/26 [==============================] - 2s 72ms/step - loss: 0.5665 - accuracy: 0.7695 - val_loss: 0.5790 - val_accuracy: 0.7463
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5793 - accuracy: 0.7550
# Epoch 28: val_accuracy did not improve from 0.81592
# 26/26 [==============================] - 2s 72ms/step - loss: 0.5784 - accuracy: 0.7546 - val_loss: 0.4909 - val_accuracy: 0.8010
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5435 - accuracy: 0.7975
# Epoch 29: val_accuracy improved from 0.81592 to 0.82587, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.5431 - accuracy: 0.7968 - val_loss: 0.4842 - val_accuracy: 0.8259
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5175 - accuracy: 0.8062
# Epoch 30: val_accuracy improved from 0.82587 to 0.84577, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5158 - accuracy: 0.8067 - val_loss: 0.4272 - val_accuracy: 0.8458
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4958 - accuracy: 0.8150
# Epoch 31: val_accuracy improved from 0.84577 to 0.87065, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.4944 - accuracy: 0.8154 - val_loss: 0.4090 - val_accuracy: 0.8706
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4841 - accuracy: 0.8263
# Epoch 32: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4818 - accuracy: 0.8278 - val_loss: 0.3980 - val_accuracy: 0.8607
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4956 - accuracy: 0.8150
# Epoch 33: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4949 - accuracy: 0.8154 - val_loss: 0.4143 - val_accuracy: 0.8706
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4782 - accuracy: 0.8263
# Epoch 34: val_accuracy improved from 0.87065 to 0.88060, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.4765 - accuracy: 0.8265 - val_loss: 0.3748 - val_accuracy: 0.8806
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4779 - accuracy: 0.8238
# Epoch 35: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4766 - accuracy: 0.8240 - val_loss: 0.3926 - val_accuracy: 0.8756
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4772 - accuracy: 0.8275
# Epoch 36: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4768 - accuracy: 0.8278 - val_loss: 0.4446 - val_accuracy: 0.8358
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4909 - accuracy: 0.8112
# Epoch 37: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 72ms/step - loss: 0.4897 - accuracy: 0.8116 - val_loss: 0.4557 - val_accuracy: 0.8109
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5205 - accuracy: 0.8188
# Epoch 38: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.5177 - accuracy: 0.8203 - val_loss: 0.4573 - val_accuracy: 0.8458
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4852 - accuracy: 0.8375
# Epoch 39: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 73ms/step - loss: 0.4825 - accuracy: 0.8389 - val_loss: 0.3707 - val_accuracy: 0.8806
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4486 - accuracy: 0.8475
# Epoch 40: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4480 - accuracy: 0.8476 - val_loss: 0.4032 - val_accuracy: 0.8657
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4489 - accuracy: 0.8363
# Epoch 41: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4488 - accuracy: 0.8364 - val_loss: 0.4497 - val_accuracy: 0.8109
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4723 - accuracy: 0.8200
# Epoch 42: val_accuracy improved from 0.88060 to 0.89552, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 3s 104ms/step - loss: 0.4698 - accuracy: 0.8216 - val_loss: 0.3538 - val_accuracy: 0.8955
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4184 - accuracy: 0.8575
# Epoch 43: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4178 - accuracy: 0.8575 - val_loss: 0.4047 - val_accuracy: 0.8507
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4316 - accuracy: 0.8413
# Epoch 44: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4301 - accuracy: 0.8426 - val_loss: 0.3820 - val_accuracy: 0.8706
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4246 - accuracy: 0.8600
# Epoch 45: val_accuracy did not improve from 0.89552
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4241 - accuracy: 0.8600 - val_loss: 0.3765 - val_accuracy: 0.8905
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4304 - accuracy: 0.8600
# Epoch 46: val_accuracy improved from 0.89552 to 0.91045, saving model to /content/drive/MyDrive/fabric_classification/Model-2c-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.4283 - accuracy: 0.8612 - val_loss: 0.3242 - val_accuracy: 0.9104
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3939 - accuracy: 0.8750
# Epoch 47: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3936 - accuracy: 0.8748 - val_loss: 0.3906 - val_accuracy: 0.8657
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4087 - accuracy: 0.8675
# Epoch 48: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 2s 71ms/step - loss: 0.4071 - accuracy: 0.8686 - val_loss: 0.3492 - val_accuracy: 0.9055
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4000 - accuracy: 0.8650
# Epoch 49: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 2s 71ms/step - loss: 0.3986 - accuracy: 0.8662 - val_loss: 0.3676 - val_accuracy: 0.9005
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3973 - accuracy: 0.8813
# Epoch 50: val_accuracy did not improve from 0.91045
# 26/26 [==============================] - 2s 72ms/step - loss: 0.3957 - accuracy: 0.8823 - val_loss: 0.3460 - val_accuracy: 0.9005
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[135   5]
#  [ 15  46]]
# 0
