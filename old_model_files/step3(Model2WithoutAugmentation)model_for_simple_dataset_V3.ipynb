# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

# attempt 1 with norm = 0.00005
# attempt 2 with norm = 0.0005
# attempt 3 with norm = 0.005
# attempt 4 with norm = 0.05
norm = 0.00005

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
checkpoint = ModelCheckpoint(filepath = 's_model_NoAug_NoOptv3.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 100, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/100
# 26/26 [==============================] - ETA: 0s - loss: 57.9436 - accuracy: 0.6221
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to s_model_NoAug_NoOptv3.h5
# 26/26 [==============================] - 11s 261ms/step - loss: 57.9436 - accuracy: 0.6221 - val_loss: 17.6529 - val_accuracy: 0.6965
# Epoch 2/100
# 25/26 [===========================>..] - ETA: 0s - loss: 12.5559 - accuracy: 0.6300
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 127ms/step - loss: 12.5296 - accuracy: 0.6295 - val_loss: 9.0694 - val_accuracy: 0.6965
# Epoch 3/100
# 25/26 [===========================>..] - ETA: 0s - loss: 8.1724 - accuracy: 0.6300
# Epoch 3: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 8.1651 - accuracy: 0.6295 - val_loss: 7.3713 - val_accuracy: 0.6965
# Epoch 4/100
# 25/26 [===========================>..] - ETA: 0s - loss: 7.1457 - accuracy: 0.6300
# Epoch 4: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 7.1434 - accuracy: 0.6295 - val_loss: 6.8134 - val_accuracy: 0.6965
# Epoch 5/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.7949 - accuracy: 0.6300
# Epoch 5: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 6.7938 - accuracy: 0.6295 - val_loss: 6.7632 - val_accuracy: 0.6965
# Epoch 6/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.6207 - accuracy: 0.6300
# Epoch 6: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 6.6220 - accuracy: 0.6295 - val_loss: 6.5740 - val_accuracy: 0.6965
# Epoch 7/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.5303 - accuracy: 0.6300
# Epoch 7: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 6.5306 - accuracy: 0.6295 - val_loss: 6.4944 - val_accuracy: 0.6965
# Epoch 8/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4816 - accuracy: 0.6300
# Epoch 8: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4807 - accuracy: 0.6295 - val_loss: 6.4603 - val_accuracy: 0.6965
# Epoch 9/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4797 - accuracy: 0.6300
# Epoch 9: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 6.4801 - accuracy: 0.6295 - val_loss: 6.4953 - val_accuracy: 0.6965
# Epoch 10/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4572 - accuracy: 0.6300
# Epoch 10: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4574 - accuracy: 0.6295 - val_loss: 6.4294 - val_accuracy: 0.6965
# Epoch 11/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4495 - accuracy: 0.6300
# Epoch 11: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4493 - accuracy: 0.6295 - val_loss: 6.3844 - val_accuracy: 0.6965
# Epoch 12/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4479 - accuracy: 0.6300
# Epoch 12: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4488 - accuracy: 0.6295 - val_loss: 6.4037 - val_accuracy: 0.6965
# Epoch 13/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4430 - accuracy: 0.6300
# Epoch 13: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4426 - accuracy: 0.6295 - val_loss: 6.4312 - val_accuracy: 0.6965
# Epoch 14/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4367 - accuracy: 0.6300
# Epoch 14: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 128ms/step - loss: 6.4373 - accuracy: 0.6295 - val_loss: 6.5067 - val_accuracy: 0.6965
# Epoch 15/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4465 - accuracy: 0.6300
# Epoch 15: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 127ms/step - loss: 6.4470 - accuracy: 0.6295 - val_loss: 6.4767 - val_accuracy: 0.6965
# Epoch 16/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4475 - accuracy: 0.6300
# Epoch 16: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4480 - accuracy: 0.6295 - val_loss: 6.2571 - val_accuracy: 0.6965
# Epoch 17/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4444 - accuracy: 0.6300
# Epoch 17: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4438 - accuracy: 0.6295 - val_loss: 6.4129 - val_accuracy: 0.6965
# Epoch 18/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4552 - accuracy: 0.6300
# Epoch 18: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4546 - accuracy: 0.6295 - val_loss: 6.3817 - val_accuracy: 0.6965
# Epoch 19/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4421 - accuracy: 0.6300
# Epoch 19: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4423 - accuracy: 0.6295 - val_loss: 6.4227 - val_accuracy: 0.6965
# Epoch 20/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4443 - accuracy: 0.6300
# Epoch 20: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4450 - accuracy: 0.6295 - val_loss: 6.4537 - val_accuracy: 0.6965
# Epoch 21/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4371 - accuracy: 0.6300
# Epoch 21: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4380 - accuracy: 0.6295 - val_loss: 6.5659 - val_accuracy: 0.6965
# Epoch 22/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4380 - accuracy: 0.6300
# Epoch 22: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4379 - accuracy: 0.6295 - val_loss: 6.3516 - val_accuracy: 0.6965
# Epoch 23/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4424 - accuracy: 0.6300
# Epoch 23: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4418 - accuracy: 0.6295 - val_loss: 6.4242 - val_accuracy: 0.6965
# Epoch 24/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4390 - accuracy: 0.6300
# Epoch 24: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4399 - accuracy: 0.6295 - val_loss: 6.4586 - val_accuracy: 0.6965
# Epoch 25/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4481 - accuracy: 0.6300
# Epoch 25: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4480 - accuracy: 0.6295 - val_loss: 6.4140 - val_accuracy: 0.6965
# Epoch 26/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4470 - accuracy: 0.6300
# Epoch 26: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4479 - accuracy: 0.6295 - val_loss: 6.4269 - val_accuracy: 0.6965
# Epoch 27/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4422 - accuracy: 0.6300
# Epoch 27: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4427 - accuracy: 0.6295 - val_loss: 6.3932 - val_accuracy: 0.6965
# Epoch 28/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4475 - accuracy: 0.6300
# Epoch 28: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4468 - accuracy: 0.6295 - val_loss: 6.3169 - val_accuracy: 0.6965
# Epoch 29/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4394 - accuracy: 0.6300
# Epoch 29: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4390 - accuracy: 0.6295 - val_loss: 6.5436 - val_accuracy: 0.6965
# Epoch 30/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4429 - accuracy: 0.6300
# Epoch 30: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4439 - accuracy: 0.6295 - val_loss: 6.4670 - val_accuracy: 0.6965
# Epoch 31/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4552 - accuracy: 0.6300
# Epoch 31: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4554 - accuracy: 0.6295 - val_loss: 6.4428 - val_accuracy: 0.6965
# Epoch 32/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4430 - accuracy: 0.6300
# Epoch 32: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4434 - accuracy: 0.6295 - val_loss: 6.3268 - val_accuracy: 0.6965
# Epoch 33/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4552 - accuracy: 0.6300
# Epoch 33: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4545 - accuracy: 0.6295 - val_loss: 6.3771 - val_accuracy: 0.6965
# Epoch 34/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4489 - accuracy: 0.6300
# Epoch 34: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4491 - accuracy: 0.6295 - val_loss: 6.3527 - val_accuracy: 0.6965
# Epoch 35/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4317 - accuracy: 0.6300
# Epoch 35: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4315 - accuracy: 0.6295 - val_loss: 6.5873 - val_accuracy: 0.6965
# Epoch 36/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4530 - accuracy: 0.6300
# Epoch 36: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4539 - accuracy: 0.6295 - val_loss: 6.4694 - val_accuracy: 0.6965
# Epoch 37/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4260 - accuracy: 0.6300
# Epoch 37: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4272 - accuracy: 0.6295 - val_loss: 6.3632 - val_accuracy: 0.6965
# Epoch 38/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4501 - accuracy: 0.6300
# Epoch 38: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4501 - accuracy: 0.6295 - val_loss: 6.4372 - val_accuracy: 0.6965
# Epoch 39/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4454 - accuracy: 0.6300
# Epoch 39: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4455 - accuracy: 0.6295 - val_loss: 6.4720 - val_accuracy: 0.6965
# Epoch 40/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4444 - accuracy: 0.6300
# Epoch 40: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4443 - accuracy: 0.6295 - val_loss: 6.3912 - val_accuracy: 0.6965
# Epoch 41/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4521 - accuracy: 0.6300
# Epoch 41: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4518 - accuracy: 0.6295 - val_loss: 6.4230 - val_accuracy: 0.6965
# Epoch 42/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4420 - accuracy: 0.6300
# Epoch 42: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4431 - accuracy: 0.6295 - val_loss: 6.4015 - val_accuracy: 0.6965
# Epoch 43/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4527 - accuracy: 0.6300
# Epoch 43: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4518 - accuracy: 0.6295 - val_loss: 6.3606 - val_accuracy: 0.6965
# Epoch 44/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4412 - accuracy: 0.6300
# Epoch 44: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4421 - accuracy: 0.6295 - val_loss: 6.4889 - val_accuracy: 0.6965
# Epoch 45/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4380 - accuracy: 0.6300
# Epoch 45: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4384 - accuracy: 0.6295 - val_loss: 6.5337 - val_accuracy: 0.6965
# Epoch 46/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4616 - accuracy: 0.6300
# Epoch 46: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4617 - accuracy: 0.6295 - val_loss: 6.2598 - val_accuracy: 0.6965
# Epoch 47/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4443 - accuracy: 0.6300
# Epoch 47: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4440 - accuracy: 0.6295 - val_loss: 6.3861 - val_accuracy: 0.6965
# Epoch 48/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4460 - accuracy: 0.6300
# Epoch 48: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4457 - accuracy: 0.6295 - val_loss: 6.3876 - val_accuracy: 0.6965
# Epoch 49/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4529 - accuracy: 0.6300
# Epoch 49: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4530 - accuracy: 0.6295 - val_loss: 6.5690 - val_accuracy: 0.6965
# Epoch 50/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4433 - accuracy: 0.6300
# Epoch 50: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4437 - accuracy: 0.6295 - val_loss: 6.4967 - val_accuracy: 0.6965
# Epoch 51/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4459 - accuracy: 0.6300
# Epoch 51: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4475 - accuracy: 0.6295 - val_loss: 6.4518 - val_accuracy: 0.6965
# Epoch 52/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4359 - accuracy: 0.6300
# Epoch 52: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4363 - accuracy: 0.6295 - val_loss: 6.3580 - val_accuracy: 0.6965
# Epoch 53/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4433 - accuracy: 0.6300
# Epoch 53: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4420 - accuracy: 0.6295 - val_loss: 6.4215 - val_accuracy: 0.6965
# Epoch 54/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4570 - accuracy: 0.6300
# Epoch 54: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4576 - accuracy: 0.6295 - val_loss: 6.4785 - val_accuracy: 0.6965
# Epoch 55/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4463 - accuracy: 0.6300
# Epoch 55: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4467 - accuracy: 0.6295 - val_loss: 6.4411 - val_accuracy: 0.6965
# Epoch 56/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4562 - accuracy: 0.6300
# Epoch 56: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4567 - accuracy: 0.6295 - val_loss: 6.3871 - val_accuracy: 0.6965
# Epoch 57/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4491 - accuracy: 0.6300
# Epoch 57: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4490 - accuracy: 0.6295 - val_loss: 6.3768 - val_accuracy: 0.6965
# Epoch 58/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4446 - accuracy: 0.6300
# Epoch 58: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4444 - accuracy: 0.6295 - val_loss: 6.3378 - val_accuracy: 0.6965
# Epoch 59/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4421 - accuracy: 0.6300
# Epoch 59: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4417 - accuracy: 0.6295 - val_loss: 6.5192 - val_accuracy: 0.6965
# Epoch 60/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4503 - accuracy: 0.6300
# Epoch 60: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4514 - accuracy: 0.6295 - val_loss: 6.4410 - val_accuracy: 0.6965
# Epoch 61/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4472 - accuracy: 0.6300
# Epoch 61: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4472 - accuracy: 0.6295 - val_loss: 6.4022 - val_accuracy: 0.6965
# Epoch 62/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4521 - accuracy: 0.6300
# Epoch 62: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4528 - accuracy: 0.6295 - val_loss: 6.4030 - val_accuracy: 0.6965
# Epoch 63/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4476 - accuracy: 0.6300
# Epoch 63: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4469 - accuracy: 0.6295 - val_loss: 6.4630 - val_accuracy: 0.6965
# Epoch 64/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4505 - accuracy: 0.6300
# Epoch 64: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4505 - accuracy: 0.6295 - val_loss: 6.3663 - val_accuracy: 0.6965
# Epoch 65/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4479 - accuracy: 0.6300
# Epoch 65: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4484 - accuracy: 0.6295 - val_loss: 6.5192 - val_accuracy: 0.6965
# Epoch 66/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4286 - accuracy: 0.6300
# Epoch 66: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4301 - accuracy: 0.6295 - val_loss: 6.5494 - val_accuracy: 0.6965
# Epoch 67/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4547 - accuracy: 0.6300
# Epoch 67: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4547 - accuracy: 0.6295 - val_loss: 6.3778 - val_accuracy: 0.6965
# Epoch 68/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4469 - accuracy: 0.6300
# Epoch 68: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4464 - accuracy: 0.6295 - val_loss: 6.3925 - val_accuracy: 0.6965
# Epoch 69/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4448 - accuracy: 0.6300
# Epoch 69: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4454 - accuracy: 0.6295 - val_loss: 6.4712 - val_accuracy: 0.6965
# Epoch 70/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4540 - accuracy: 0.6300
# Epoch 70: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4536 - accuracy: 0.6295 - val_loss: 6.3874 - val_accuracy: 0.6965
# Epoch 71/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4489 - accuracy: 0.6300
# Epoch 71: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4481 - accuracy: 0.6295 - val_loss: 6.4220 - val_accuracy: 0.6965
# Epoch 72/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4576 - accuracy: 0.6300
# Epoch 72: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4585 - accuracy: 0.6295 - val_loss: 6.3421 - val_accuracy: 0.6965
# Epoch 73/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4410 - accuracy: 0.6300
# Epoch 73: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4409 - accuracy: 0.6295 - val_loss: 6.4222 - val_accuracy: 0.6965
# Epoch 74/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4399 - accuracy: 0.6300
# Epoch 74: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4408 - accuracy: 0.6295 - val_loss: 6.4389 - val_accuracy: 0.6965
# Epoch 75/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4493 - accuracy: 0.6300
# Epoch 75: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4497 - accuracy: 0.6295 - val_loss: 6.5042 - val_accuracy: 0.6965
# Epoch 76/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4483 - accuracy: 0.6300
# Epoch 76: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4488 - accuracy: 0.6295 - val_loss: 6.3310 - val_accuracy: 0.6965
# Epoch 77/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4375 - accuracy: 0.6300
# Epoch 77: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4375 - accuracy: 0.6295 - val_loss: 6.4674 - val_accuracy: 0.6965
# Epoch 78/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4593 - accuracy: 0.6300
# Epoch 78: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4590 - accuracy: 0.6295 - val_loss: 6.3907 - val_accuracy: 0.6965
# Epoch 79/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4442 - accuracy: 0.6300
# Epoch 79: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4449 - accuracy: 0.6295 - val_loss: 6.4261 - val_accuracy: 0.6965
# Epoch 80/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4383 - accuracy: 0.6300
# Epoch 80: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4388 - accuracy: 0.6295 - val_loss: 6.5550 - val_accuracy: 0.6965
# Epoch 81/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4466 - accuracy: 0.6300
# Epoch 81: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4472 - accuracy: 0.6295 - val_loss: 6.4900 - val_accuracy: 0.6965
# Epoch 82/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4425 - accuracy: 0.6300
# Epoch 82: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4428 - accuracy: 0.6295 - val_loss: 6.2969 - val_accuracy: 0.6965
# Epoch 83/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4471 - accuracy: 0.6300
# Epoch 83: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4460 - accuracy: 0.6295 - val_loss: 6.4386 - val_accuracy: 0.6965
# Epoch 84/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4450 - accuracy: 0.6300
# Epoch 84: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4453 - accuracy: 0.6295 - val_loss: 6.4525 - val_accuracy: 0.6965
# Epoch 85/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4569 - accuracy: 0.6300
# Epoch 85: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4561 - accuracy: 0.6295 - val_loss: 6.4531 - val_accuracy: 0.6965
# Epoch 86/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4572 - accuracy: 0.6300
# Epoch 86: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4582 - accuracy: 0.6295 - val_loss: 6.3548 - val_accuracy: 0.6965
# Epoch 87/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4399 - accuracy: 0.6300
# Epoch 87: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4406 - accuracy: 0.6295 - val_loss: 6.3939 - val_accuracy: 0.6965
# Epoch 88/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4502 - accuracy: 0.6300
# Epoch 88: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4496 - accuracy: 0.6295 - val_loss: 6.2663 - val_accuracy: 0.6965
# Epoch 89/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4398 - accuracy: 0.6300
# Epoch 89: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4396 - accuracy: 0.6295 - val_loss: 6.5598 - val_accuracy: 0.6965
# Epoch 90/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4454 - accuracy: 0.6300
# Epoch 90: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 126ms/step - loss: 6.4466 - accuracy: 0.6295 - val_loss: 6.5200 - val_accuracy: 0.6965
# Epoch 91/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4476 - accuracy: 0.6300
# Epoch 91: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4483 - accuracy: 0.6295 - val_loss: 6.4566 - val_accuracy: 0.6965
# Epoch 92/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4422 - accuracy: 0.6300
# Epoch 92: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4424 - accuracy: 0.6295 - val_loss: 6.3896 - val_accuracy: 0.6965
# Epoch 93/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4547 - accuracy: 0.6300
# Epoch 93: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4544 - accuracy: 0.6295 - val_loss: 6.4020 - val_accuracy: 0.6965
# Epoch 94/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4500 - accuracy: 0.6300
# Epoch 94: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4503 - accuracy: 0.6295 - val_loss: 6.4625 - val_accuracy: 0.6965
# Epoch 95/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4287 - accuracy: 0.6300
# Epoch 95: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4287 - accuracy: 0.6295 - val_loss: 6.4933 - val_accuracy: 0.6965
# Epoch 96/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4540 - accuracy: 0.6300
# Epoch 96: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4553 - accuracy: 0.6295 - val_loss: 6.4167 - val_accuracy: 0.6965
# Epoch 97/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4406 - accuracy: 0.6300
# Epoch 97: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4407 - accuracy: 0.6295 - val_loss: 6.3552 - val_accuracy: 0.6965
# Epoch 98/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4422 - accuracy: 0.6300
# Epoch 98: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4418 - accuracy: 0.6295 - val_loss: 6.4448 - val_accuracy: 0.6965
# Epoch 99/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4606 - accuracy: 0.6300
# Epoch 99: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4600 - accuracy: 0.6295 - val_loss: 6.4380 - val_accuracy: 0.6965
# Epoch 100/100
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4482 - accuracy: 0.6300
# Epoch 100: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 6.4486 - accuracy: 0.6295 - val_loss: 6.3397 - val_accuracy: 0.6965
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[140   0]
#  [ 61   0]]
