# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.8),

  tf.keras.layers.Dense(num_classes)
])

#tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
 #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Flatten(),
  #tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.Dropout(0.8),

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/80
# 118/118 [==============================] - ETA: 0s - loss: 1.5431 - accuracy: 0.4832
# Epoch 1: val_accuracy improved from -inf to 0.53305, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 22s 158ms/step - loss: 1.5431 - accuracy: 0.4832 - val_loss: 1.3055 - val_accuracy: 0.5330
# Epoch 2/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.3794 - accuracy: 0.5363
# Epoch 2: val_accuracy improved from 0.53305 to 0.53731, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 1.3782 - accuracy: 0.5368 - val_loss: 1.2707 - val_accuracy: 0.5373
# Epoch 3/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.3459 - accuracy: 0.5473
# Epoch 3: val_accuracy did not improve from 0.53731
# 118/118 [==============================] - 9s 74ms/step - loss: 1.3450 - accuracy: 0.5477 - val_loss: 1.2708 - val_accuracy: 0.5203
# Epoch 4/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.3283 - accuracy: 0.5435
# Epoch 4: val_accuracy improved from 0.53731 to 0.55117, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 86ms/step - loss: 1.3274 - accuracy: 0.5440 - val_loss: 1.2166 - val_accuracy: 0.5512
# Epoch 5/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.2893 - accuracy: 0.5585
# Epoch 5: val_accuracy improved from 0.55117 to 0.57676, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 9s 77ms/step - loss: 1.2884 - accuracy: 0.5589 - val_loss: 1.2156 - val_accuracy: 0.5768
# Epoch 6/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.2636 - accuracy: 0.5665
# Epoch 6: val_accuracy did not improve from 0.57676
# 118/118 [==============================] - 9s 74ms/step - loss: 1.2637 - accuracy: 0.5666 - val_loss: 1.2743 - val_accuracy: 0.5373
# Epoch 7/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.2500 - accuracy: 0.5769
# Epoch 7: val_accuracy improved from 0.57676 to 0.57783, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 1.2494 - accuracy: 0.5775 - val_loss: 1.1617 - val_accuracy: 0.5778
# Epoch 8/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1801 - accuracy: 0.6084
# Epoch 8: val_accuracy improved from 0.57783 to 0.59915, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 1.1799 - accuracy: 0.6087 - val_loss: 1.1331 - val_accuracy: 0.5991
# Epoch 9/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.2037 - accuracy: 0.5831
# Epoch 9: val_accuracy improved from 0.59915 to 0.61940, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 1.2031 - accuracy: 0.5836 - val_loss: 1.1337 - val_accuracy: 0.6194
# Epoch 10/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1615 - accuracy: 0.6159
# Epoch 10: val_accuracy did not improve from 0.61940
# 118/118 [==============================] - 9s 74ms/step - loss: 1.1609 - accuracy: 0.6164 - val_loss: 1.1150 - val_accuracy: 0.6173
# Epoch 11/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1408 - accuracy: 0.6127
# Epoch 11: val_accuracy did not improve from 0.61940
# 118/118 [==============================] - 9s 74ms/step - loss: 1.1404 - accuracy: 0.6129 - val_loss: 1.2080 - val_accuracy: 0.5874
# Epoch 12/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1453 - accuracy: 0.6090
# Epoch 12: val_accuracy did not improve from 0.61940
# 118/118 [==============================] - 9s 74ms/step - loss: 1.1463 - accuracy: 0.6092 - val_loss: 1.1772 - val_accuracy: 0.6066
# Epoch 13/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1227 - accuracy: 0.6157
# Epoch 13: val_accuracy improved from 0.61940 to 0.62260, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 86ms/step - loss: 1.1220 - accuracy: 0.6161 - val_loss: 1.1014 - val_accuracy: 0.6226
# Epoch 14/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0949 - accuracy: 0.6378
# Epoch 14: val_accuracy improved from 0.62260 to 0.65565, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 1.0944 - accuracy: 0.6383 - val_loss: 1.0454 - val_accuracy: 0.6557
# Epoch 15/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.1141 - accuracy: 0.6290
# Epoch 15: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.1134 - accuracy: 0.6295 - val_loss: 1.0674 - val_accuracy: 0.6322
# Epoch 16/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0706 - accuracy: 0.6392
# Epoch 16: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0700 - accuracy: 0.6396 - val_loss: 1.0378 - val_accuracy: 0.6439
# Epoch 17/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0739 - accuracy: 0.6362
# Epoch 17: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0743 - accuracy: 0.6367 - val_loss: 1.0443 - val_accuracy: 0.6397
# Epoch 18/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0726 - accuracy: 0.6343
# Epoch 18: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0728 - accuracy: 0.6345 - val_loss: 0.9836 - val_accuracy: 0.6557
# Epoch 19/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0567 - accuracy: 0.6378
# Epoch 19: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0562 - accuracy: 0.6380 - val_loss: 1.0852 - val_accuracy: 0.6173
# Epoch 20/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0118 - accuracy: 0.6637
# Epoch 20: val_accuracy did not improve from 0.65565
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0111 - accuracy: 0.6641 - val_loss: 1.0690 - val_accuracy: 0.6215
# Epoch 21/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0317 - accuracy: 0.6485
# Epoch 21: val_accuracy improved from 0.65565 to 0.67377, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 11s 90ms/step - loss: 1.0311 - accuracy: 0.6489 - val_loss: 0.9558 - val_accuracy: 0.6738
# Epoch 22/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0023 - accuracy: 0.6501
# Epoch 22: val_accuracy did not improve from 0.67377
# 118/118 [==============================] - 9s 74ms/step - loss: 1.0012 - accuracy: 0.6508 - val_loss: 0.9690 - val_accuracy: 0.6482
# Epoch 23/80
# 117/118 [============================>.] - ETA: 0s - loss: 1.0199 - accuracy: 0.6474
# Epoch 23: val_accuracy improved from 0.67377 to 0.69296, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 1.0189 - accuracy: 0.6481 - val_loss: 0.8908 - val_accuracy: 0.6930
# Epoch 24/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9973 - accuracy: 0.6611
# Epoch 24: val_accuracy did not improve from 0.69296
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9962 - accuracy: 0.6617 - val_loss: 0.9171 - val_accuracy: 0.6706
# Epoch 25/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9864 - accuracy: 0.6632
# Epoch 25: val_accuracy did not improve from 0.69296
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9859 - accuracy: 0.6633 - val_loss: 0.9261 - val_accuracy: 0.6780
# Epoch 26/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9695 - accuracy: 0.6677
# Epoch 26: val_accuracy did not improve from 0.69296
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9688 - accuracy: 0.6681 - val_loss: 0.8796 - val_accuracy: 0.6812
# Epoch 27/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9661 - accuracy: 0.6677
# Epoch 27: val_accuracy did not improve from 0.69296
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9654 - accuracy: 0.6681 - val_loss: 0.8913 - val_accuracy: 0.6780
# Epoch 28/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9655 - accuracy: 0.6632
# Epoch 28: val_accuracy improved from 0.69296 to 0.69510, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 86ms/step - loss: 0.9647 - accuracy: 0.6636 - val_loss: 0.8740 - val_accuracy: 0.6951
# Epoch 29/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9348 - accuracy: 0.6774
# Epoch 29: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9342 - accuracy: 0.6777 - val_loss: 0.9002 - val_accuracy: 0.6823
# Epoch 30/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9468 - accuracy: 0.6691
# Epoch 30: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9458 - accuracy: 0.6692 - val_loss: 0.8978 - val_accuracy: 0.6706
# Epoch 31/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9331 - accuracy: 0.6712
# Epoch 31: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9328 - accuracy: 0.6716 - val_loss: 0.8703 - val_accuracy: 0.6823
# Epoch 32/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9197 - accuracy: 0.6790
# Epoch 32: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9186 - accuracy: 0.6795 - val_loss: 0.9109 - val_accuracy: 0.6802
# Epoch 33/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9286 - accuracy: 0.6723
# Epoch 33: val_accuracy improved from 0.69510 to 0.70362, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.9277 - accuracy: 0.6729 - val_loss: 0.8227 - val_accuracy: 0.7036
# Epoch 34/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9278 - accuracy: 0.6774
# Epoch 34: val_accuracy did not improve from 0.70362
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9266 - accuracy: 0.6779 - val_loss: 0.9270 - val_accuracy: 0.6738
# Epoch 35/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9001 - accuracy: 0.6856
# Epoch 35: val_accuracy improved from 0.70362 to 0.71109, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.8991 - accuracy: 0.6862 - val_loss: 0.8069 - val_accuracy: 0.7111
# Epoch 36/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9282 - accuracy: 0.6806
# Epoch 36: val_accuracy did not improve from 0.71109
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9273 - accuracy: 0.6809 - val_loss: 0.8011 - val_accuracy: 0.7111
# Epoch 37/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.9053 - accuracy: 0.6800
# Epoch 37: val_accuracy did not improve from 0.71109
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9052 - accuracy: 0.6801 - val_loss: 0.8624 - val_accuracy: 0.7015
# Epoch 38/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8843 - accuracy: 0.6907
# Epoch 38: val_accuracy improved from 0.71109 to 0.71748, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 0.8833 - accuracy: 0.6910 - val_loss: 0.8019 - val_accuracy: 0.7175
# Epoch 39/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8991 - accuracy: 0.6800
# Epoch 39: val_accuracy did not improve from 0.71748
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8981 - accuracy: 0.6806 - val_loss: 0.7664 - val_accuracy: 0.7111
# Epoch 40/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8800 - accuracy: 0.6856
# Epoch 40: val_accuracy did not improve from 0.71748
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8791 - accuracy: 0.6859 - val_loss: 0.8086 - val_accuracy: 0.7036
# Epoch 41/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8984 - accuracy: 0.6760
# Epoch 41: val_accuracy did not improve from 0.71748
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8978 - accuracy: 0.6766 - val_loss: 0.8582 - val_accuracy: 0.7004
# Epoch 42/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8635 - accuracy: 0.6926
# Epoch 42: val_accuracy did not improve from 0.71748
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8628 - accuracy: 0.6931 - val_loss: 0.8223 - val_accuracy: 0.7058
# Epoch 43/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8581 - accuracy: 0.6934
# Epoch 43: val_accuracy improved from 0.71748 to 0.72495, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.8575 - accuracy: 0.6934 - val_loss: 0.8003 - val_accuracy: 0.7249
# Epoch 44/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8798 - accuracy: 0.6862
# Epoch 44: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8792 - accuracy: 0.6865 - val_loss: 0.8540 - val_accuracy: 0.7068
# Epoch 45/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8822 - accuracy: 0.6867
# Epoch 45: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8815 - accuracy: 0.6870 - val_loss: 0.7527 - val_accuracy: 0.7249
# Epoch 46/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8979 - accuracy: 0.6867
# Epoch 46: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8974 - accuracy: 0.6870 - val_loss: 0.8059 - val_accuracy: 0.7164
# Epoch 47/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8703 - accuracy: 0.6928
# Epoch 47: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8696 - accuracy: 0.6931 - val_loss: 0.7926 - val_accuracy: 0.7249
# Epoch 48/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8469 - accuracy: 0.6950
# Epoch 48: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8461 - accuracy: 0.6955 - val_loss: 0.7512 - val_accuracy: 0.7249
# Epoch 49/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8333 - accuracy: 0.7041
# Epoch 49: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8326 - accuracy: 0.7046 - val_loss: 0.8376 - val_accuracy: 0.7036
# Epoch 50/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8328 - accuracy: 0.7025
# Epoch 50: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8318 - accuracy: 0.7030 - val_loss: 0.7883 - val_accuracy: 0.7143
# Epoch 51/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8475 - accuracy: 0.6995
# Epoch 51: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8467 - accuracy: 0.6998 - val_loss: 0.7711 - val_accuracy: 0.7207
# Epoch 52/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8474 - accuracy: 0.6926
# Epoch 52: val_accuracy did not improve from 0.72495
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8468 - accuracy: 0.6929 - val_loss: 0.8734 - val_accuracy: 0.6823
# Epoch 53/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8313 - accuracy: 0.7019
# Epoch 53: val_accuracy improved from 0.72495 to 0.72601, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 87ms/step - loss: 0.8307 - accuracy: 0.7022 - val_loss: 0.7709 - val_accuracy: 0.7260
# Epoch 54/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8094 - accuracy: 0.7073
# Epoch 54: val_accuracy did not improve from 0.72601
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8090 - accuracy: 0.7072 - val_loss: 0.7705 - val_accuracy: 0.7122
# Epoch 55/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8333 - accuracy: 0.7009
# Epoch 55: val_accuracy improved from 0.72601 to 0.75373, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 82ms/step - loss: 0.8323 - accuracy: 0.7011 - val_loss: 0.6688 - val_accuracy: 0.7537
# Epoch 56/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8185 - accuracy: 0.7078
# Epoch 56: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8180 - accuracy: 0.7080 - val_loss: 0.8031 - val_accuracy: 0.7004
# Epoch 57/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8306 - accuracy: 0.7003
# Epoch 57: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8294 - accuracy: 0.7009 - val_loss: 0.6906 - val_accuracy: 0.7367
# Epoch 58/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7933 - accuracy: 0.7217
# Epoch 58: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7924 - accuracy: 0.7219 - val_loss: 0.7305 - val_accuracy: 0.7367
# Epoch 59/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8121 - accuracy: 0.7062
# Epoch 59: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8118 - accuracy: 0.7064 - val_loss: 0.7434 - val_accuracy: 0.7271
# Epoch 60/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7943 - accuracy: 0.7105
# Epoch 60: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7936 - accuracy: 0.7107 - val_loss: 0.6905 - val_accuracy: 0.7431
# Epoch 61/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7789 - accuracy: 0.7163
# Epoch 61: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7778 - accuracy: 0.7171 - val_loss: 0.9265 - val_accuracy: 0.6866
# Epoch 62/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7961 - accuracy: 0.7153
# Epoch 62: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7958 - accuracy: 0.7150 - val_loss: 0.8691 - val_accuracy: 0.7249
# Epoch 63/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7748 - accuracy: 0.7214
# Epoch 63: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7740 - accuracy: 0.7219 - val_loss: 0.8186 - val_accuracy: 0.7058
# Epoch 64/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8173 - accuracy: 0.7102
# Epoch 64: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8166 - accuracy: 0.7102 - val_loss: 0.7134 - val_accuracy: 0.7324
# Epoch 65/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7778 - accuracy: 0.7244
# Epoch 65: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7772 - accuracy: 0.7246 - val_loss: 0.7947 - val_accuracy: 0.7175
# Epoch 66/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7937 - accuracy: 0.7179
# Epoch 66: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7929 - accuracy: 0.7182 - val_loss: 0.7491 - val_accuracy: 0.7271
# Epoch 67/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7397 - accuracy: 0.7412
# Epoch 67: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7387 - accuracy: 0.7413 - val_loss: 0.6957 - val_accuracy: 0.7527
# Epoch 68/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7668 - accuracy: 0.7236
# Epoch 68: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7659 - accuracy: 0.7240 - val_loss: 0.8197 - val_accuracy: 0.7313
# Epoch 69/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.8040 - accuracy: 0.7137
# Epoch 69: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8032 - accuracy: 0.7142 - val_loss: 0.6967 - val_accuracy: 0.7431
# Epoch 70/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7744 - accuracy: 0.7083
# Epoch 70: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7738 - accuracy: 0.7088 - val_loss: 0.7617 - val_accuracy: 0.7281
# Epoch 71/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7785 - accuracy: 0.7115
# Epoch 71: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7774 - accuracy: 0.7120 - val_loss: 0.7616 - val_accuracy: 0.7473
# Epoch 72/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7587 - accuracy: 0.7268
# Epoch 72: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7576 - accuracy: 0.7270 - val_loss: 0.6851 - val_accuracy: 0.7409
# Epoch 73/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7716 - accuracy: 0.7217
# Epoch 73: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7705 - accuracy: 0.7222 - val_loss: 0.7199 - val_accuracy: 0.7431
# Epoch 74/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7530 - accuracy: 0.7209
# Epoch 74: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7522 - accuracy: 0.7214 - val_loss: 0.7352 - val_accuracy: 0.7420
# Epoch 75/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7413 - accuracy: 0.7334
# Epoch 75: val_accuracy did not improve from 0.75373
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7410 - accuracy: 0.7334 - val_loss: 0.7807 - val_accuracy: 0.7228
# Epoch 76/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7423 - accuracy: 0.7350
# Epoch 76: val_accuracy improved from 0.75373 to 0.77399, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V3.h5
# 118/118 [==============================] - 10s 85ms/step - loss: 0.7409 - accuracy: 0.7357 - val_loss: 0.6295 - val_accuracy: 0.7740
# Epoch 77/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7297 - accuracy: 0.7428
# Epoch 77: val_accuracy did not improve from 0.77399
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7287 - accuracy: 0.7432 - val_loss: 0.7345 - val_accuracy: 0.7345
# Epoch 78/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7078 - accuracy: 0.7436
# Epoch 78: val_accuracy did not improve from 0.77399
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7076 - accuracy: 0.7435 - val_loss: 0.7315 - val_accuracy: 0.7079
# Epoch 79/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7696 - accuracy: 0.7238
# Epoch 79: val_accuracy did not improve from 0.77399
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7692 - accuracy: 0.7240 - val_loss: 0.7108 - val_accuracy: 0.7431
# Epoch 80/80
# 117/118 [============================>.] - ETA: 0s - loss: 0.7359 - accuracy: 0.7356
# Epoch 80: val_accuracy did not improve from 0.77399
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7350 - accuracy: 0.7360 - val_loss: 0.6895 - val_accuracy: 0.7473
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 9,457,478
# Trainable params: 9,457,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (938, 6)
# (938,)
# (938,)
# [[401  11   0  24   0   9]
#  [ 34 100   0   2   0   2]
#  [ 17   0   4  19   0   0]
#  [ 24   0   1 146  20   3]
#  [  0   0   0  13  27   0]
#  [ 17   0   0  41   0  23]]
