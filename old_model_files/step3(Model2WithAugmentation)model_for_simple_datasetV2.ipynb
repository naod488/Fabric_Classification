# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.Dropout(0.8),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/s_model_Aug_NoOptV2.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')


hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 1.7723 - accuracy: 0.5688
# Epoch 1: val_accuracy improved from -inf to 0.70149, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 11s 197ms/step - loss: 1.7723 - accuracy: 0.5688 - val_loss: 0.6293 - val_accuracy: 0.7015
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6424 - accuracy: 0.6500
# Epoch 2: val_accuracy did not improve from 0.70149
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6410 - accuracy: 0.6518 - val_loss: 0.6149 - val_accuracy: 0.7015
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6341 - accuracy: 0.6662
# Epoch 3: val_accuracy did not improve from 0.70149
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6329 - accuracy: 0.6667 - val_loss: 0.6156 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6435 - accuracy: 0.6475
# Epoch 4: val_accuracy improved from 0.70149 to 0.71642, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.6413 - accuracy: 0.6506 - val_loss: 0.6122 - val_accuracy: 0.7164
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6902 - accuracy: 0.6388
# Epoch 5: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6894 - accuracy: 0.6419 - val_loss: 0.6533 - val_accuracy: 0.6965
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6555 - accuracy: 0.6237
# Epoch 6: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6525 - accuracy: 0.6270 - val_loss: 0.5743 - val_accuracy: 0.6965
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6550 - accuracy: 0.6275
# Epoch 7: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6524 - accuracy: 0.6295 - val_loss: 0.5997 - val_accuracy: 0.6965
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6448 - accuracy: 0.6450
# Epoch 8: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6425 - accuracy: 0.6481 - val_loss: 0.6178 - val_accuracy: 0.6965
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6597 - accuracy: 0.6075
# Epoch 9: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6580 - accuracy: 0.6097 - val_loss: 0.6061 - val_accuracy: 0.6965
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6547 - accuracy: 0.6263
# Epoch 10: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6534 - accuracy: 0.6295 - val_loss: 0.6340 - val_accuracy: 0.6965
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6607 - accuracy: 0.6237
# Epoch 11: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6576 - accuracy: 0.6270 - val_loss: 0.6016 - val_accuracy: 0.6965
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6366 - accuracy: 0.6263
# Epoch 12: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6347 - accuracy: 0.6295 - val_loss: 0.6147 - val_accuracy: 0.6965
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6398 - accuracy: 0.6263
# Epoch 13: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6377 - accuracy: 0.6295 - val_loss: 0.5980 - val_accuracy: 0.6965
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6411 - accuracy: 0.6263
# Epoch 14: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6400 - accuracy: 0.6295 - val_loss: 0.6227 - val_accuracy: 0.6965
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6303 - accuracy: 0.6250
# Epoch 15: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6284 - accuracy: 0.6283 - val_loss: 0.5918 - val_accuracy: 0.6965
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6429 - accuracy: 0.6225
# Epoch 16: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6414 - accuracy: 0.6258 - val_loss: 0.6033 - val_accuracy: 0.6965
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6546 - accuracy: 0.6263
# Epoch 17: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6537 - accuracy: 0.6295 - val_loss: 0.6364 - val_accuracy: 0.6965
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6361 - accuracy: 0.6263
# Epoch 18: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6339 - accuracy: 0.6295 - val_loss: 0.5784 - val_accuracy: 0.6965
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6588 - accuracy: 0.6313
# Epoch 19: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 128ms/step - loss: 0.6581 - accuracy: 0.6344 - val_loss: 0.6472 - val_accuracy: 0.6965
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6334 - accuracy: 0.6263
# Epoch 20: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 126ms/step - loss: 0.6318 - accuracy: 0.6295 - val_loss: 0.5779 - val_accuracy: 0.6965
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6220 - accuracy: 0.6263
# Epoch 21: val_accuracy did not improve from 0.71642
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6203 - accuracy: 0.6295 - val_loss: 0.5737 - val_accuracy: 0.6965
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6180 - accuracy: 0.6463
# Epoch 22: val_accuracy improved from 0.71642 to 0.72637, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.6165 - accuracy: 0.6493 - val_loss: 0.5692 - val_accuracy: 0.7264
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6133 - accuracy: 0.6787
# Epoch 23: val_accuracy did not improve from 0.72637
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6110 - accuracy: 0.6815 - val_loss: 0.5646 - val_accuracy: 0.7264
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6485 - accuracy: 0.6600
# Epoch 24: val_accuracy improved from 0.72637 to 0.73632, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.6459 - accuracy: 0.6629 - val_loss: 0.5535 - val_accuracy: 0.7363
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6162 - accuracy: 0.6525
# Epoch 25: val_accuracy did not improve from 0.73632
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6149 - accuracy: 0.6555 - val_loss: 0.6064 - val_accuracy: 0.7065
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5832 - accuracy: 0.6787
# Epoch 26: val_accuracy did not improve from 0.73632
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5806 - accuracy: 0.6815 - val_loss: 0.5276 - val_accuracy: 0.7363
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5959 - accuracy: 0.6725
# Epoch 27: val_accuracy improved from 0.73632 to 0.75124, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5952 - accuracy: 0.6741 - val_loss: 0.5826 - val_accuracy: 0.7512
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5942 - accuracy: 0.6825
# Epoch 28: val_accuracy improved from 0.75124 to 0.75622, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.5930 - accuracy: 0.6840 - val_loss: 0.5547 - val_accuracy: 0.7562
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5887 - accuracy: 0.6837
# Epoch 29: val_accuracy did not improve from 0.75622
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5863 - accuracy: 0.6865 - val_loss: 0.5336 - val_accuracy: 0.7363
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6110 - accuracy: 0.6737
# Epoch 30: val_accuracy did not improve from 0.75622
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6097 - accuracy: 0.6753 - val_loss: 0.5571 - val_accuracy: 0.7512
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6157 - accuracy: 0.6700
# Epoch 31: val_accuracy improved from 0.75622 to 0.78109, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.6142 - accuracy: 0.6729 - val_loss: 0.5728 - val_accuracy: 0.7811
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5970 - accuracy: 0.6812
# Epoch 32: val_accuracy did not improve from 0.78109
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5959 - accuracy: 0.6828 - val_loss: 0.5393 - val_accuracy: 0.7711
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5956 - accuracy: 0.6975
# Epoch 33: val_accuracy did not improve from 0.78109
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5942 - accuracy: 0.7001 - val_loss: 0.5299 - val_accuracy: 0.7811
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5919 - accuracy: 0.6975
# Epoch 34: val_accuracy did not improve from 0.78109
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5909 - accuracy: 0.6989 - val_loss: 0.5227 - val_accuracy: 0.7612
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5810 - accuracy: 0.7000
# Epoch 35: val_accuracy did not improve from 0.78109
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5793 - accuracy: 0.7026 - val_loss: 0.5140 - val_accuracy: 0.7711
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5855 - accuracy: 0.6938
# Epoch 36: val_accuracy did not improve from 0.78109
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5834 - accuracy: 0.6964 - val_loss: 0.5206 - val_accuracy: 0.7562
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5660 - accuracy: 0.7175
# Epoch 37: val_accuracy improved from 0.78109 to 0.79104, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5638 - accuracy: 0.7200 - val_loss: 0.4911 - val_accuracy: 0.7910
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5443 - accuracy: 0.7200
# Epoch 38: val_accuracy did not improve from 0.79104
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5412 - accuracy: 0.7224 - val_loss: 0.4878 - val_accuracy: 0.7562
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5750 - accuracy: 0.6900
# Epoch 39: val_accuracy did not improve from 0.79104
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5735 - accuracy: 0.6914 - val_loss: 0.4726 - val_accuracy: 0.7662
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5235 - accuracy: 0.7425
# Epoch 40: val_accuracy improved from 0.79104 to 0.79602, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5232 - accuracy: 0.7435 - val_loss: 0.4527 - val_accuracy: 0.7960
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6057 - accuracy: 0.6687
# Epoch 41: val_accuracy did not improve from 0.79602
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6038 - accuracy: 0.6716 - val_loss: 0.5285 - val_accuracy: 0.7861
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5958 - accuracy: 0.6825
# Epoch 42: val_accuracy did not improve from 0.79602
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5939 - accuracy: 0.6840 - val_loss: 0.5292 - val_accuracy: 0.7512
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5679 - accuracy: 0.7113
# Epoch 43: val_accuracy improved from 0.79602 to 0.82090, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5655 - accuracy: 0.7138 - val_loss: 0.5060 - val_accuracy: 0.8209
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5585 - accuracy: 0.7125
# Epoch 44: val_accuracy improved from 0.82090 to 0.83085, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5571 - accuracy: 0.7125 - val_loss: 0.4840 - val_accuracy: 0.8308
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5678 - accuracy: 0.7237
# Epoch 45: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5652 - accuracy: 0.7261 - val_loss: 0.4725 - val_accuracy: 0.8109
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5708 - accuracy: 0.6925
# Epoch 46: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5692 - accuracy: 0.6939 - val_loss: 0.5102 - val_accuracy: 0.7811
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5458 - accuracy: 0.7325
# Epoch 47: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 3s 125ms/step - loss: 0.5436 - accuracy: 0.7336 - val_loss: 0.4516 - val_accuracy: 0.8060
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5276 - accuracy: 0.7500
# Epoch 48: val_accuracy improved from 0.83085 to 0.83582, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5258 - accuracy: 0.7522 - val_loss: 0.4413 - val_accuracy: 0.8358
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5066 - accuracy: 0.7425
# Epoch 49: val_accuracy improved from 0.83582 to 0.84577, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 4s 141ms/step - loss: 0.5040 - accuracy: 0.7447 - val_loss: 0.4072 - val_accuracy: 0.8458
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4762 - accuracy: 0.7675
# Epoch 50: val_accuracy improved from 0.84577 to 0.85572, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.4756 - accuracy: 0.7683 - val_loss: 0.4217 - val_accuracy: 0.8557
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  dropout (Dropout)           (None, 96, 96, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[136   4]
#  [ 25  36]]
