# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  #tested 0.0005 and 0.00005 regularization
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),

  tf.keras.layers.Dense(num_classes)
])

#tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
 #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Flatten(),
  #tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.Dropout(0.8),

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 1.9739 - accuracy: 0.5096
# Epoch 1: val_accuracy improved from -inf to 0.54691, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 28s 183ms/step - loss: 1.9739 - accuracy: 0.5096 - val_loss: 1.5278 - val_accuracy: 0.5469
# Epoch 2/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.4093 - accuracy: 0.5726
# Epoch 2: val_accuracy improved from 0.54691 to 0.56930, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.4083 - accuracy: 0.5730 - val_loss: 1.3756 - val_accuracy: 0.5693
# Epoch 3/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3405 - accuracy: 0.5775
# Epoch 3: val_accuracy improved from 0.56930 to 0.58635, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.3398 - accuracy: 0.5783 - val_loss: 1.3390 - val_accuracy: 0.5864
# Epoch 4/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3037 - accuracy: 0.5881
# Epoch 4: val_accuracy did not improve from 0.58635
# 118/118 [==============================] - 15s 128ms/step - loss: 1.3030 - accuracy: 0.5887 - val_loss: 1.3500 - val_accuracy: 0.5736
# Epoch 5/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2892 - accuracy: 0.5954
# Epoch 5: val_accuracy did not improve from 0.58635
# 118/118 [==============================] - 15s 129ms/step - loss: 1.2885 - accuracy: 0.5959 - val_loss: 1.3322 - val_accuracy: 0.5832
# Epoch 6/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2772 - accuracy: 0.5975
# Epoch 6: val_accuracy improved from 0.58635 to 0.58849, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.2762 - accuracy: 0.5983 - val_loss: 1.3206 - val_accuracy: 0.5885
# Epoch 7/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2769 - accuracy: 0.5908
# Epoch 7: val_accuracy improved from 0.58849 to 0.60874, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.2757 - accuracy: 0.5911 - val_loss: 1.2913 - val_accuracy: 0.6087
# Epoch 8/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2767 - accuracy: 0.5913
# Epoch 8: val_accuracy improved from 0.60874 to 0.62154, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 17s 142ms/step - loss: 1.2759 - accuracy: 0.5922 - val_loss: 1.2706 - val_accuracy: 0.6215
# Epoch 9/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2590 - accuracy: 0.6095
# Epoch 9: val_accuracy did not improve from 0.62154
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2582 - accuracy: 0.6103 - val_loss: 1.2566 - val_accuracy: 0.6183
# Epoch 10/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2374 - accuracy: 0.6127
# Epoch 10: val_accuracy did not improve from 0.62154
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2366 - accuracy: 0.6132 - val_loss: 1.2730 - val_accuracy: 0.6098
# Epoch 11/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2284 - accuracy: 0.6146
# Epoch 11: val_accuracy did not improve from 0.62154
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2276 - accuracy: 0.6151 - val_loss: 1.2706 - val_accuracy: 0.5991
# Epoch 12/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2018 - accuracy: 0.6298
# Epoch 12: val_accuracy improved from 0.62154 to 0.62687, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.2010 - accuracy: 0.6303 - val_loss: 1.2246 - val_accuracy: 0.6269
# Epoch 13/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2065 - accuracy: 0.6253
# Epoch 13: val_accuracy did not improve from 0.62687
# 118/118 [==============================] - 15s 130ms/step - loss: 1.2060 - accuracy: 0.6255 - val_loss: 1.2503 - val_accuracy: 0.6151
# Epoch 14/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1757 - accuracy: 0.6434
# Epoch 14: val_accuracy improved from 0.62687 to 0.63646, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 1.1750 - accuracy: 0.6436 - val_loss: 1.1968 - val_accuracy: 0.6365
# Epoch 15/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1639 - accuracy: 0.6424
# Epoch 15: val_accuracy improved from 0.63646 to 0.63859, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 1.1633 - accuracy: 0.6428 - val_loss: 1.1757 - val_accuracy: 0.6386
# Epoch 16/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1603 - accuracy: 0.6509
# Epoch 16: val_accuracy improved from 0.63859 to 0.64072, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 1.1597 - accuracy: 0.6510 - val_loss: 1.1810 - val_accuracy: 0.6407
# Epoch 17/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1577 - accuracy: 0.6546
# Epoch 17: val_accuracy did not improve from 0.64072
# 118/118 [==============================] - 15s 130ms/step - loss: 1.1570 - accuracy: 0.6548 - val_loss: 1.2051 - val_accuracy: 0.6407
# Epoch 18/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1379 - accuracy: 0.6603
# Epoch 18: val_accuracy improved from 0.64072 to 0.66098, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 1.1375 - accuracy: 0.6604 - val_loss: 1.1751 - val_accuracy: 0.6610
# Epoch 19/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1147 - accuracy: 0.6648
# Epoch 19: val_accuracy improved from 0.66098 to 0.66631, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.1143 - accuracy: 0.6649 - val_loss: 1.1326 - val_accuracy: 0.6663
# Epoch 20/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1010 - accuracy: 0.6717
# Epoch 20: val_accuracy did not improve from 0.66631
# 118/118 [==============================] - 15s 130ms/step - loss: 1.1009 - accuracy: 0.6721 - val_loss: 1.1604 - val_accuracy: 0.6503
# Epoch 21/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0969 - accuracy: 0.6752
# Epoch 21: val_accuracy improved from 0.66631 to 0.67271, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.0963 - accuracy: 0.6755 - val_loss: 1.1242 - val_accuracy: 0.6727
# Epoch 22/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0803 - accuracy: 0.6749
# Epoch 22: val_accuracy did not improve from 0.67271
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0797 - accuracy: 0.6753 - val_loss: 1.1226 - val_accuracy: 0.6525
# Epoch 23/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0903 - accuracy: 0.6765
# Epoch 23: val_accuracy did not improve from 0.67271
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0899 - accuracy: 0.6769 - val_loss: 1.1771 - val_accuracy: 0.6343
# Epoch 24/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0743 - accuracy: 0.6792
# Epoch 24: val_accuracy improved from 0.67271 to 0.67484, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 1.0735 - accuracy: 0.6795 - val_loss: 1.1089 - val_accuracy: 0.6748
# Epoch 25/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0484 - accuracy: 0.6896
# Epoch 25: val_accuracy did not improve from 0.67484
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0479 - accuracy: 0.6897 - val_loss: 1.1550 - val_accuracy: 0.6471
# Epoch 26/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0332 - accuracy: 0.6907
# Epoch 26: val_accuracy did not improve from 0.67484
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0332 - accuracy: 0.6907 - val_loss: 1.1176 - val_accuracy: 0.6706
# Epoch 27/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0402 - accuracy: 0.6931
# Epoch 27: val_accuracy did not improve from 0.67484
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0393 - accuracy: 0.6937 - val_loss: 1.1331 - val_accuracy: 0.6546
# Epoch 28/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0312 - accuracy: 0.6942
# Epoch 28: val_accuracy improved from 0.67484 to 0.68124, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 1.0303 - accuracy: 0.6947 - val_loss: 1.0938 - val_accuracy: 0.6812
# Epoch 29/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0279 - accuracy: 0.6985
# Epoch 29: val_accuracy did not improve from 0.68124
# 118/118 [==============================] - 15s 129ms/step - loss: 1.0275 - accuracy: 0.6987 - val_loss: 1.1337 - val_accuracy: 0.6727
# Epoch 30/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0427 - accuracy: 0.6923
# Epoch 30: val_accuracy improved from 0.68124 to 0.69510, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 1.0419 - accuracy: 0.6931 - val_loss: 1.0477 - val_accuracy: 0.6951
# Epoch 31/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0163 - accuracy: 0.6974
# Epoch 31: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 130ms/step - loss: 1.0155 - accuracy: 0.6979 - val_loss: 1.0921 - val_accuracy: 0.6823
# Epoch 32/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9966 - accuracy: 0.7043
# Epoch 32: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9959 - accuracy: 0.7048 - val_loss: 1.0993 - val_accuracy: 0.6706
# Epoch 33/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0009 - accuracy: 0.7086
# Epoch 33: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 1.0003 - accuracy: 0.7088 - val_loss: 1.1236 - val_accuracy: 0.6557
# Epoch 34/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9942 - accuracy: 0.7083
# Epoch 34: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9932 - accuracy: 0.7091 - val_loss: 1.0477 - val_accuracy: 0.6930
# Epoch 35/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9806 - accuracy: 0.7113
# Epoch 35: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9798 - accuracy: 0.7118 - val_loss: 1.1447 - val_accuracy: 0.6525
# Epoch 36/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9828 - accuracy: 0.7099
# Epoch 36: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9823 - accuracy: 0.7102 - val_loss: 1.0890 - val_accuracy: 0.6930
# Epoch 37/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9564 - accuracy: 0.7204
# Epoch 37: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9564 - accuracy: 0.7206 - val_loss: 1.1004 - val_accuracy: 0.6780
# Epoch 38/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9589 - accuracy: 0.7174
# Epoch 38: val_accuracy did not improve from 0.69510
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9582 - accuracy: 0.7179 - val_loss: 1.0764 - val_accuracy: 0.6887
# Epoch 39/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9602 - accuracy: 0.7196
# Epoch 39: val_accuracy improved from 0.69510 to 0.71855, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 0.9593 - accuracy: 0.7200 - val_loss: 0.9736 - val_accuracy: 0.7186
# Epoch 40/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9618 - accuracy: 0.7177
# Epoch 40: val_accuracy did not improve from 0.71855
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9608 - accuracy: 0.7182 - val_loss: 0.9657 - val_accuracy: 0.7090
# Epoch 41/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9326 - accuracy: 0.7292
# Epoch 41: val_accuracy did not improve from 0.71855
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9317 - accuracy: 0.7299 - val_loss: 1.0218 - val_accuracy: 0.7090
# Epoch 42/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9461 - accuracy: 0.7204
# Epoch 42: val_accuracy did not improve from 0.71855
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9452 - accuracy: 0.7208 - val_loss: 1.0107 - val_accuracy: 0.7026
# Epoch 43/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9443 - accuracy: 0.7212
# Epoch 43: val_accuracy improved from 0.71855 to 0.72068, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.9434 - accuracy: 0.7219 - val_loss: 0.9921 - val_accuracy: 0.7207
# Epoch 44/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9230 - accuracy: 0.7308
# Epoch 44: val_accuracy did not improve from 0.72068
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9226 - accuracy: 0.7310 - val_loss: 1.0392 - val_accuracy: 0.6876
# Epoch 45/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9228 - accuracy: 0.7281
# Epoch 45: val_accuracy did not improve from 0.72068
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9219 - accuracy: 0.7286 - val_loss: 1.0084 - val_accuracy: 0.7015
# Epoch 46/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9311 - accuracy: 0.7369
# Epoch 46: val_accuracy did not improve from 0.72068
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9302 - accuracy: 0.7376 - val_loss: 0.9911 - val_accuracy: 0.6994
# Epoch 47/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9192 - accuracy: 0.7345
# Epoch 47: val_accuracy did not improve from 0.72068
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9182 - accuracy: 0.7349 - val_loss: 0.9769 - val_accuracy: 0.7026
# Epoch 48/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9078 - accuracy: 0.7321
# Epoch 48: val_accuracy improved from 0.72068 to 0.72495, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.9069 - accuracy: 0.7328 - val_loss: 0.9402 - val_accuracy: 0.7249
# Epoch 49/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9139 - accuracy: 0.7281
# Epoch 49: val_accuracy improved from 0.72495 to 0.74200, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V4.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 0.9130 - accuracy: 0.7288 - val_loss: 0.9172 - val_accuracy: 0.7420
# Epoch 50/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9084 - accuracy: 0.7353
# Epoch 50: val_accuracy did not improve from 0.74200
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9073 - accuracy: 0.7360 - val_loss: 0.9432 - val_accuracy: 0.7122
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 9,457,478
# Trainable params: 9,457,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (938, 6)
# (938,)
# (938,)
# [[379  23   2  33   0   8]
#  [ 22 112   0   1   0   3]
#  [ 14   1  12   8   3   2]
#  [ 41   2   5 123  20   3]
#  [  3   0   0  11  26   0]
#  [ 41   2   0  22   0  16]]
