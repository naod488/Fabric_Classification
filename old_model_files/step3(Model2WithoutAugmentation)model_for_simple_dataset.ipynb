# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
#path = "C:/Users/Startklar/Documents/Computer Science/Uni Year 3/Term 2/Individual Project/Farbic classification/Fabrics_simple"
data_dir = pathlib.Path(path)

subfiles = "/*/*.png"

image_count = len(list(data_dir.glob('*'+subfiles)))
print(str(image_count) + "\n")

Denim = list(data_dir.glob('Denim'+subfiles))
Wool = list(data_dir.glob('Wool'+subfiles))

fabrics = {'Denim' : Denim,
           'Wool' : Wool}

farbic_names = []
fabric_counts = []
for fabric in list(fabrics.keys()):
    farbic_names.append(fabric)
    fabric_counts.append(len(fabrics[fabric]))
    print(f"{fabric} : {len(fabrics[fabric])}")

fabric_dict = {
    'Fabric' : farbic_names,
    'Count' : fabric_counts
}
                  
import pandas as pd
import matplotlib.pyplot as plt

fabric_df = pd.DataFrame(fabric_dict)

plt.figure(figsize=(9,4))
plt.bar(x=fabric_df['Fabric'],
        height=fabric_df['Count'])
plt.xticks(rotation=60)
# Out:
# 2.8.0
# /device:GPU:0
# Thu Mar 17 11:37:11 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    32W / 250W |    375MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# 1008
#
# Denim : 648
# Wool : 360
# ([0, 1], <a list of 2 Text major ticklabel objects>)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
#X = (32, 400, 400, 3) 32images, 400*400, color channels (r,g,b)
#Y = (32,)
# Out:
# (32, 400, 400, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = 's_model_NoAug_NoOptv2.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.8086 - accuracy: 0.6109
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 121s 4s/step - loss: 0.8086 - accuracy: 0.6109 - val_loss: 0.6404 - val_accuracy: 0.6965
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6450 - accuracy: 0.6375
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 2s 70ms/step - loss: 0.6455 - accuracy: 0.6357 - val_loss: 0.5729 - val_accuracy: 0.6965
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6122 - accuracy: 0.6475
# Epoch 3: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 2s 70ms/step - loss: 0.6128 - accuracy: 0.6456 - val_loss: 0.5991 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5829 - accuracy: 0.6562
# Epoch 4: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 2s 70ms/step - loss: 0.5840 - accuracy: 0.6543 - val_loss: 0.5461 - val_accuracy: 0.6965
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5141 - accuracy: 0.7337
# Epoch 5: val_accuracy improved from 0.69652 to 0.86070, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5127 - accuracy: 0.7361 - val_loss: 0.5035 - val_accuracy: 0.8607
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3221 - accuracy: 0.8775
# Epoch 6: val_accuracy improved from 0.86070 to 0.87065, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3200 - accuracy: 0.8786 - val_loss: 0.3707 - val_accuracy: 0.8706
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1526 - accuracy: 0.9525
# Epoch 7: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 70ms/step - loss: 0.1515 - accuracy: 0.9529 - val_loss: 0.8055 - val_accuracy: 0.6318
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0845 - accuracy: 0.9762
# Epoch 8: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0838 - accuracy: 0.9765 - val_loss: 0.3797 - val_accuracy: 0.8209
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0604 - accuracy: 0.9837
# Epoch 9: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0599 - accuracy: 0.9839 - val_loss: 0.5464 - val_accuracy: 0.7960
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0513 - accuracy: 0.9862
# Epoch 10: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0509 - accuracy: 0.9864 - val_loss: 0.8297 - val_accuracy: 0.7065
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0401 - accuracy: 0.9900
# Epoch 11: val_accuracy did not improve from 0.87065
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0398 - accuracy: 0.9901 - val_loss: 0.3214 - val_accuracy: 0.8607
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0275 - accuracy: 0.9962
# Epoch 12: val_accuracy improved from 0.87065 to 0.91542, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0272 - accuracy: 0.9963 - val_loss: 0.2741 - val_accuracy: 0.9154
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1333 - accuracy: 0.9700
# Epoch 13: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.1327 - accuracy: 0.9703 - val_loss: 0.3543 - val_accuracy: 0.8209
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0557 - accuracy: 0.9862
# Epoch 14: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0552 - accuracy: 0.9864 - val_loss: 0.2816 - val_accuracy: 0.9104
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0516 - accuracy: 0.9912
# Epoch 15: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0511 - accuracy: 0.9913 - val_loss: 0.4054 - val_accuracy: 0.8706
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0807 - accuracy: 0.9700
# Epoch 16: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0802 - accuracy: 0.9703 - val_loss: 0.3158 - val_accuracy: 0.8557
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0245 - accuracy: 0.9987
# Epoch 17: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0243 - accuracy: 0.9988 - val_loss: 0.4592 - val_accuracy: 0.8806
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0277 - accuracy: 0.9887
# Epoch 18: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 70ms/step - loss: 0.0275 - accuracy: 0.9888 - val_loss: 0.6251 - val_accuracy: 0.8109
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0203 - accuracy: 0.9962
# Epoch 19: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 74ms/step - loss: 0.0201 - accuracy: 0.9963 - val_loss: 0.3049 - val_accuracy: 0.9055
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 20: val_accuracy improved from 0.91542 to 0.93035, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9303
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.4601e-04 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 5.4131e-04 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9303
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.6116e-04 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 4.5724e-04 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.9055
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.7539e-04 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 2.7305e-04 - accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9104
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.2264e-04 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 2.2074e-04 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9104
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.8573e-04 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 1.8415e-04 - accuracy: 1.0000 - val_loss: 0.3098 - val_accuracy: 0.9204
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.5913e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 1.5778e-04 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9204
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.3730e-04 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 1.3613e-04 - accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.9254
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.1769e-04 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 1.1669e-04 - accuracy: 1.0000 - val_loss: 0.3025 - val_accuracy: 0.9303
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.0015e-04 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 70ms/step - loss: 9.9295e-05 - accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.9254
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 8.5533e-05 - accuracy: 1.0000
# Epoch 30: val_accuracy improved from 0.93035 to 0.93532, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 79ms/step - loss: 8.4805e-05 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9353
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 7.4293e-05 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 7.3661e-05 - accuracy: 1.0000 - val_loss: 0.2983 - val_accuracy: 0.9353
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 6.4984e-05 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 6.4431e-05 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9353
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.7232e-05 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 5.6745e-05 - accuracy: 1.0000 - val_loss: 0.2957 - val_accuracy: 0.9353
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 5.0917e-05 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 5.0484e-05 - accuracy: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9353
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.5683e-05 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 4.5294e-05 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9353
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 4.1307e-05 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.93532
# 26/26 [==============================] - 2s 70ms/step - loss: 4.0956e-05 - accuracy: 1.0000 - val_loss: 0.2932 - val_accuracy: 0.9353
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.7362e-05 - accuracy: 1.0000
# Epoch 37: val_accuracy improved from 0.93532 to 0.94030, saving model to s_model_NoAug_NoOptv2.h5
# 26/26 [==============================] - 2s 79ms/step - loss: 3.7044e-05 - accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9403
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.4075e-05 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 3.3785e-05 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9403
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 3.1292e-05 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 3.1027e-05 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9353
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.8704e-05 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 2.8460e-05 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.9353
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.6571e-05 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 2.6345e-05 - accuracy: 1.0000 - val_loss: 0.2918 - val_accuracy: 0.9353
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.4713e-05 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 2.4504e-05 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9353
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.2926e-05 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 2.2731e-05 - accuracy: 1.0000 - val_loss: 0.2924 - val_accuracy: 0.9353
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 2.1420e-05 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 2.1239e-05 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.9353
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.9981e-05 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.9812e-05 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.9353
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.8705e-05 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.8547e-05 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.9353
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.7604e-05 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.7455e-05 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.9353
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.6507e-05 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.6367e-05 - accuracy: 1.0000 - val_loss: 0.2940 - val_accuracy: 0.9353
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.5529e-05 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.5398e-05 - accuracy: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.9353
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 1.4667e-05 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 70ms/step - loss: 1.4544e-05 - accuracy: 1.0000 - val_loss: 0.2946 - val_accuracy: 0.9353
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[135   5]
#  [  8  53]]

# %%
#based of https://keras.io/examples/vision/image_classification_from_scratch/
imgSize = (img_height, img_width)
img = tf.keras.preprocessing.image.load_img(
    "/content/drive/MyDrive/fabric_classification/Fabrics_simple/Wool/7/im_1.png", target_size=imgSize
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

pred = model.predict(img_array)
print(np.round(pred[0:1], 2))
print(pred)
pred_val = np.argmax(pred,axis=1)
print(class_names)
print(f"This image is {pred_val}.")
# Out:
# [[-4.28  5.34]]
# [[-4.282528   5.3375688]]
# ['Denim', 'Wool']
# This image is [1].
