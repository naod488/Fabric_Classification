# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

print(tf.__version__)
import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
#path = "C:/Users/Startklar/Documents/Computer Science/Uni Year 3/Term 2/Individual Project/Farbic classification/Fabrics_simple"
data_dir = pathlib.Path(path)

subfiles = "/*/*.png"

image_count = len(list(data_dir.glob('*'+subfiles)))
print(str(image_count) + "\n")

Denim = list(data_dir.glob('Denim'+subfiles))
Wool = list(data_dir.glob('Wool'+subfiles))

fabrics = {'Denim' : Denim,
           'Wool' : Wool}

farbic_names = []
fabric_counts = []
for fabric in list(fabrics.keys()):
    farbic_names.append(fabric)
    fabric_counts.append(len(fabrics[fabric]))
    print(f"{fabric} : {len(fabrics[fabric])}")

fabric_dict = {
    'Fabric' : farbic_names,
    'Count' : fabric_counts
}
                  
import pandas as pd
import matplotlib.pyplot as plt

fabric_df = pd.DataFrame(fabric_dict)

plt.figure(figsize=(9,4))
plt.bar(x=fabric_df['Fabric'],
        height=fabric_df['Count'])
plt.xticks(rotation=60)
# Out:
# 2.8.0
# 1008
#
# Denim : 648
# Wool : 360
# ([0, 1], <a list of 2 Text major ticklabel objects>)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
#X = (32, 400, 400, 3) 32images, 400*400, color channels (r,g,b)
#Y = (32,)
# Out:
# (32, 400, 400, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/base_model_Aug_NoOpt.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
with tf.device('/gpu:0'):
    hist = model.fit(train_ds, 
                    validation_data = val_ds, 
                    epochs = 60, 
                    verbose = 1, 
                    callbacks = [checkpoint])

model.summary()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()
# Out:
# Epoch 1/60
# 26/26 [==============================] - ETA: 0s - loss: 20.1907 - accuracy: 0.5601
# Epoch 1: val_accuracy improved from -inf to 0.30348, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 102s 4s/step - loss: 20.1907 - accuracy: 0.5601 - val_loss: 7.6222 - val_accuracy: 0.3035
# Epoch 2/60
# 26/26 [==============================] - ETA: 0s - loss: 2.3442 - accuracy: 0.5713
# Epoch 2: val_accuracy improved from 0.30348 to 0.73134, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 403ms/step - loss: 2.3442 - accuracy: 0.5713 - val_loss: 1.4124 - val_accuracy: 0.7313
# Epoch 3/60
# 26/26 [==============================] - ETA: 0s - loss: 1.0626 - accuracy: 0.6022
# Epoch 3: val_accuracy did not improve from 0.73134
# 26/26 [==============================] - 2s 78ms/step - loss: 1.0626 - accuracy: 0.6022 - val_loss: 1.1036 - val_accuracy: 0.3035
# Epoch 4/60
# 26/26 [==============================] - ETA: 0s - loss: 0.6212 - accuracy: 0.6964
# Epoch 4: val_accuracy improved from 0.73134 to 0.83582, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 408ms/step - loss: 0.6212 - accuracy: 0.6964 - val_loss: 0.4692 - val_accuracy: 0.8358
# Epoch 5/60
# 26/26 [==============================] - ETA: 0s - loss: 0.6434 - accuracy: 0.7088
# Epoch 5: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.6434 - accuracy: 0.7088 - val_loss: 0.5114 - val_accuracy: 0.7711
# Epoch 6/60
# 26/26 [==============================] - ETA: 0s - loss: 0.6506 - accuracy: 0.7162
# Epoch 6: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.6506 - accuracy: 0.7162 - val_loss: 0.8142 - val_accuracy: 0.5075
# Epoch 7/60
# 26/26 [==============================] - ETA: 0s - loss: 0.5974 - accuracy: 0.7299
# Epoch 7: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.5974 - accuracy: 0.7299 - val_loss: 0.8177 - val_accuracy: 0.5075
# Epoch 8/60
# 26/26 [==============================] - ETA: 0s - loss: 0.5687 - accuracy: 0.7299
# Epoch 8: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.5687 - accuracy: 0.7299 - val_loss: 0.7547 - val_accuracy: 0.5124
# Epoch 9/60
# 26/26 [==============================] - ETA: 0s - loss: 0.5323 - accuracy: 0.7423
# Epoch 9: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.5323 - accuracy: 0.7423 - val_loss: 0.4254 - val_accuracy: 0.8159
# Epoch 10/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.7708
# Epoch 10: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4769 - accuracy: 0.7708 - val_loss: 0.5282 - val_accuracy: 0.7662
# Epoch 11/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4532 - accuracy: 0.7757
# Epoch 11: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4532 - accuracy: 0.7757 - val_loss: 0.5862 - val_accuracy: 0.7214
# Epoch 12/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4792 - accuracy: 0.7831
# Epoch 12: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4792 - accuracy: 0.7831 - val_loss: 0.7866 - val_accuracy: 0.5522
# Epoch 13/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.7881
# Epoch 13: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 80ms/step - loss: 0.4729 - accuracy: 0.7881 - val_loss: 0.5589 - val_accuracy: 0.7114
# Epoch 14/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.7745
# Epoch 14: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4649 - accuracy: 0.7745 - val_loss: 0.4059 - val_accuracy: 0.8109
# Epoch 15/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4277 - accuracy: 0.8055
# Epoch 15: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.4277 - accuracy: 0.8055 - val_loss: 0.6006 - val_accuracy: 0.6866
# Epoch 16/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4147 - accuracy: 0.8116
# Epoch 16: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 78ms/step - loss: 0.4147 - accuracy: 0.8116 - val_loss: 0.5474 - val_accuracy: 0.7463
# Epoch 17/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4297 - accuracy: 0.7943
# Epoch 17: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4297 - accuracy: 0.7943 - val_loss: 0.4023 - val_accuracy: 0.8358
# Epoch 18/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3994 - accuracy: 0.8253
# Epoch 18: val_accuracy did not improve from 0.83582
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3994 - accuracy: 0.8253 - val_loss: 0.4904 - val_accuracy: 0.7711
# Epoch 19/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4782 - accuracy: 0.7831
# Epoch 19: val_accuracy improved from 0.83582 to 0.84577, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 11s 420ms/step - loss: 0.4782 - accuracy: 0.7831 - val_loss: 0.3627 - val_accuracy: 0.8458
# Epoch 20/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4236 - accuracy: 0.8203
# Epoch 20: val_accuracy did not improve from 0.84577
# 26/26 [==============================] - 2s 78ms/step - loss: 0.4236 - accuracy: 0.8203 - val_loss: 0.4045 - val_accuracy: 0.8408
# Epoch 21/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.8017
# Epoch 21: val_accuracy did not improve from 0.84577
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4542 - accuracy: 0.8017 - val_loss: 0.4008 - val_accuracy: 0.8408
# Epoch 22/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4072 - accuracy: 0.8129
# Epoch 22: val_accuracy improved from 0.84577 to 0.85075, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 11s 417ms/step - loss: 0.4072 - accuracy: 0.8129 - val_loss: 0.3895 - val_accuracy: 0.8507
# Epoch 23/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.8178
# Epoch 23: val_accuracy improved from 0.85075 to 0.87562, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 410ms/step - loss: 0.4359 - accuracy: 0.8178 - val_loss: 0.3459 - val_accuracy: 0.8756
# Epoch 24/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8203
# Epoch 24: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 79ms/step - loss: 0.4084 - accuracy: 0.8203 - val_loss: 0.3460 - val_accuracy: 0.8607
# Epoch 25/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3480 - accuracy: 0.8439
# Epoch 25: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3480 - accuracy: 0.8439 - val_loss: 0.3710 - val_accuracy: 0.8159
# Epoch 26/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8538
# Epoch 26: val_accuracy did not improve from 0.87562
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3470 - accuracy: 0.8538 - val_loss: 0.7037 - val_accuracy: 0.5920
# Epoch 27/60
# 26/26 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.7993
# Epoch 27: val_accuracy improved from 0.87562 to 0.90050, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 404ms/step - loss: 0.4096 - accuracy: 0.7993 - val_loss: 0.3214 - val_accuracy: 0.9005
# Epoch 28/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.8290
# Epoch 28: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3916 - accuracy: 0.8290 - val_loss: 0.3220 - val_accuracy: 0.8905
# Epoch 29/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3486 - accuracy: 0.8563
# Epoch 29: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3486 - accuracy: 0.8563 - val_loss: 0.3096 - val_accuracy: 0.8856
# Epoch 30/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3506 - accuracy: 0.8426
# Epoch 30: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3506 - accuracy: 0.8426 - val_loss: 0.3091 - val_accuracy: 0.8856
# Epoch 31/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3635 - accuracy: 0.8451
# Epoch 31: val_accuracy did not improve from 0.90050
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3635 - accuracy: 0.8451 - val_loss: 0.2871 - val_accuracy: 0.9005
# Epoch 32/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.8550
# Epoch 32: val_accuracy improved from 0.90050 to 0.90547, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 409ms/step - loss: 0.3287 - accuracy: 0.8550 - val_loss: 0.2895 - val_accuracy: 0.9055
# Epoch 33/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8414
# Epoch 33: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3793 - accuracy: 0.8414 - val_loss: 0.3125 - val_accuracy: 0.8905
# Epoch 34/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.8625
# Epoch 34: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3467 - accuracy: 0.8625 - val_loss: 0.2979 - val_accuracy: 0.8955
# Epoch 35/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8538
# Epoch 35: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3292 - accuracy: 0.8538 - val_loss: 0.2830 - val_accuracy: 0.8856
# Epoch 36/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8699
# Epoch 36: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3217 - accuracy: 0.8699 - val_loss: 0.3863 - val_accuracy: 0.7960
# Epoch 37/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3177 - accuracy: 0.8612
# Epoch 37: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3177 - accuracy: 0.8612 - val_loss: 0.8682 - val_accuracy: 0.5522
# Epoch 38/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3803 - accuracy: 0.8253
# Epoch 38: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3803 - accuracy: 0.8253 - val_loss: 0.3349 - val_accuracy: 0.8607
# Epoch 39/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.8575
# Epoch 39: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3546 - accuracy: 0.8575 - val_loss: 0.2836 - val_accuracy: 0.8856
# Epoch 40/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8637
# Epoch 40: val_accuracy improved from 0.90547 to 0.91542, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 406ms/step - loss: 0.3011 - accuracy: 0.8637 - val_loss: 0.2486 - val_accuracy: 0.9154
# Epoch 41/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3202 - accuracy: 0.8550
# Epoch 41: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 80ms/step - loss: 0.3202 - accuracy: 0.8550 - val_loss: 0.4009 - val_accuracy: 0.7960
# Epoch 42/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.8798
# Epoch 42: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3028 - accuracy: 0.8798 - val_loss: 0.2730 - val_accuracy: 0.9055
# Epoch 43/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.8748
# Epoch 43: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2872 - accuracy: 0.8748 - val_loss: 0.5961 - val_accuracy: 0.6667
# Epoch 44/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.8513
# Epoch 44: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 78ms/step - loss: 0.3475 - accuracy: 0.8513 - val_loss: 0.2948 - val_accuracy: 0.8955
# Epoch 45/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8649
# Epoch 45: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3325 - accuracy: 0.8649 - val_loss: 0.3270 - val_accuracy: 0.8706
# Epoch 46/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.8414
# Epoch 46: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3544 - accuracy: 0.8414 - val_loss: 0.2953 - val_accuracy: 0.8657
# Epoch 47/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3842 - accuracy: 0.8389
# Epoch 47: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3842 - accuracy: 0.8389 - val_loss: 0.2782 - val_accuracy: 0.9005
# Epoch 48/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.8773
# Epoch 48: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2979 - accuracy: 0.8773 - val_loss: 0.3244 - val_accuracy: 0.8706
# Epoch 49/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.8674
# Epoch 49: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3087 - accuracy: 0.8674 - val_loss: 0.2675 - val_accuracy: 0.8955
# Epoch 50/60
# 26/26 [==============================] - ETA: 0s - loss: 0.3118 - accuracy: 0.8748
# Epoch 50: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.3118 - accuracy: 0.8748 - val_loss: 0.2884 - val_accuracy: 0.8706
# Epoch 51/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.8810
# Epoch 51: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2948 - accuracy: 0.8810 - val_loss: 0.2574 - val_accuracy: 0.8905
# Epoch 52/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8910
# Epoch 52: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 78ms/step - loss: 0.2701 - accuracy: 0.8910 - val_loss: 0.2397 - val_accuracy: 0.9005
# Epoch 53/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8798
# Epoch 53: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2749 - accuracy: 0.8798 - val_loss: 0.3403 - val_accuracy: 0.8458
# Epoch 54/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2377 - accuracy: 0.9108
# Epoch 54: val_accuracy improved from 0.91542 to 0.92537, saving model to /base_model_Aug_NoOpt.h5
# 26/26 [==============================] - 10s 409ms/step - loss: 0.2377 - accuracy: 0.9108 - val_loss: 0.2099 - val_accuracy: 0.9254
# Epoch 55/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.8996
# Epoch 55: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2483 - accuracy: 0.8996 - val_loss: 0.2002 - val_accuracy: 0.9154
# Epoch 56/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8724
# Epoch 56: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2866 - accuracy: 0.8724 - val_loss: 0.2223 - val_accuracy: 0.9154
# Epoch 57/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2517 - accuracy: 0.8947
# Epoch 57: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2517 - accuracy: 0.8947 - val_loss: 0.2018 - val_accuracy: 0.9104
# Epoch 58/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9009
# Epoch 58: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 80ms/step - loss: 0.2355 - accuracy: 0.9009 - val_loss: 0.2601 - val_accuracy: 0.8905
# Epoch 59/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.8625
# Epoch 59: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2789 - accuracy: 0.8625 - val_loss: 0.2557 - val_accuracy: 0.8557
# Epoch 60/60
# 26/26 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8798
# Epoch 60: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 79ms/step - loss: 0.2858 - accuracy: 0.8798 - val_loss: 0.2360 - val_accuracy: 0.9204
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  flatten (Flatten)           (None, 1267232)           0
#
#  dense (Dense)               (None, 128)               162205824
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 162,206,978
# Trainable params: 162,206,978
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[136   4]
#  [ 12  49]]

# %%
#based of https://keras.io/examples/vision/image_classification_from_scratch/
imgSize = (img_height, img_width)
img = tf.keras.preprocessing.image.load_img(
    ""/content/drive/MyDrive/fabric_classification/Fabrics_simple/Wool/7/im_1.png", target_size=imgSize/Fabrics_simple/Wool/7/im_1.png", target_size=imgSize
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

pred = model.predict(img_array)
print(np.round(pred[0:1], 2))
print(pred)
pred_val = np.argmax(pred,axis=1)
print(class_names)
print(f"This image is {pred_val}.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-635ff99651c7> in <module>()
#       2 imgSize = (img_height, img_width)
#       3 img = tf.keras.preprocessing.image.load_img(
# ----> 4     "C:/Users/Startklar/Documents/Computer Science/Uni Year 3/Term 2/Individual Project/Farbic classification/Fabrics_simple/Wool/7/im_1.png", target_size=imgSize
#       5 )
#       6 img_array = tf.keras.preprocessing.image.img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Startklar/Documents/Computer Science/Uni Year 3/Term 2/Individual Project/Farbic classification/Fabrics_simple/Wool/7/im_1.png'
