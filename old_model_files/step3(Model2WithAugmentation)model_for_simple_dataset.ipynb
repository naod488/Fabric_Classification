# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

print(tf.__version__)
import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
#path = "C:/Users/Startklar/Documents/Computer Science/Uni Year 3/Term 2/Individual Project/Farbic classification/Fabrics_simple"
data_dir = pathlib.Path(path)

subfiles = "/*/*.png"

image_count = len(list(data_dir.glob('*'+subfiles)))
print(str(image_count) + "\n")

Denim = list(data_dir.glob('Denim'+subfiles))
Wool = list(data_dir.glob('Wool'+subfiles))

fabrics = {'Denim' : Denim,
           'Wool' : Wool}

farbic_names = []
fabric_counts = []
for fabric in list(fabrics.keys()):
    farbic_names.append(fabric)
    fabric_counts.append(len(fabrics[fabric]))
    print(f"{fabric} : {len(fabrics[fabric])}")

fabric_dict = {
    'Fabric' : farbic_names,
    'Count' : fabric_counts
}
                  
import pandas as pd
import matplotlib.pyplot as plt

fabric_df = pd.DataFrame(fabric_dict)

plt.figure(figsize=(9,4))
plt.bar(x=fabric_df['Fabric'],
        height=fabric_df['Count'])
plt.xticks(rotation=60)
# Out:
# 2.8.0
# 1008
#
# Denim : 648
# Wool : 360
# ([0, 1], <a list of 2 Text major ticklabel objects>)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
#X = (32, 400, 400, 3) 32images, 400*400, color channels (r,g,b)
#Y = (32,)
# Out:
# (32, 400, 400, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/s_model_Aug_NoOpt.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
with tf.device('/gpu:0'):
    hist = model.fit(train_ds, 
                    validation_data = val_ds, 
                    epochs = 50, 
                    verbose = 1, 
                    callbacks = [checkpoint])

model.summary()

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 1.1451 - accuracy: 0.6369
# Epoch 1: val_accuracy improved from -inf to 0.71144, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 90s 3s/step - loss: 1.1451 - accuracy: 0.6369 - val_loss: 0.6096 - val_accuracy: 0.7114
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6325 - accuracy: 0.6637
# Epoch 2: val_accuracy improved from 0.71144 to 0.77114, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 131ms/step - loss: 0.6326 - accuracy: 0.6642 - val_loss: 0.6448 - val_accuracy: 0.7711
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6342 - accuracy: 0.6450
# Epoch 3: val_accuracy did not improve from 0.77114
# 26/26 [==============================] - 3s 122ms/step - loss: 0.6344 - accuracy: 0.6444 - val_loss: 0.6277 - val_accuracy: 0.7264
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6047 - accuracy: 0.6625
# Epoch 4: val_accuracy did not improve from 0.77114
# 26/26 [==============================] - 3s 122ms/step - loss: 0.6051 - accuracy: 0.6629 - val_loss: 0.5770 - val_accuracy: 0.7562
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5694 - accuracy: 0.6913
# Epoch 5: val_accuracy did not improve from 0.77114
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5707 - accuracy: 0.6914 - val_loss: 0.5015 - val_accuracy: 0.7413
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5614 - accuracy: 0.7163
# Epoch 6: val_accuracy improved from 0.77114 to 0.81095, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.5624 - accuracy: 0.7162 - val_loss: 0.5425 - val_accuracy: 0.8109
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5279 - accuracy: 0.7362
# Epoch 7: val_accuracy did not improve from 0.81095
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5306 - accuracy: 0.7348 - val_loss: 0.5331 - val_accuracy: 0.8060
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4935 - accuracy: 0.7738
# Epoch 8: val_accuracy did not improve from 0.81095
# 26/26 [==============================] - 3s 123ms/step - loss: 0.4965 - accuracy: 0.7720 - val_loss: 0.6511 - val_accuracy: 0.6070
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4828 - accuracy: 0.7812
# Epoch 9: val_accuracy did not improve from 0.81095
# 26/26 [==============================] - 3s 122ms/step - loss: 0.4840 - accuracy: 0.7794 - val_loss: 0.6444 - val_accuracy: 0.6169
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4250 - accuracy: 0.8100
# Epoch 10: val_accuracy improved from 0.81095 to 0.84080, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.4299 - accuracy: 0.8079 - val_loss: 0.3812 - val_accuracy: 0.8408
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4873 - accuracy: 0.8025
# Epoch 11: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 123ms/step - loss: 0.4932 - accuracy: 0.8017 - val_loss: 0.4575 - val_accuracy: 0.7960
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5661 - accuracy: 0.6988
# Epoch 12: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 122ms/step - loss: 0.5676 - accuracy: 0.6964 - val_loss: 0.5900 - val_accuracy: 0.6468
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4710 - accuracy: 0.7800
# Epoch 13: val_accuracy improved from 0.84080 to 0.84577, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.4743 - accuracy: 0.7782 - val_loss: 0.3731 - val_accuracy: 0.8458
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3966 - accuracy: 0.8475
# Epoch 14: val_accuracy improved from 0.84577 to 0.88557, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.3981 - accuracy: 0.8451 - val_loss: 0.3463 - val_accuracy: 0.8856
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4093 - accuracy: 0.8250
# Epoch 15: val_accuracy did not improve from 0.88557
# 26/26 [==============================] - 3s 122ms/step - loss: 0.4104 - accuracy: 0.8240 - val_loss: 0.3607 - val_accuracy: 0.8856
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3479 - accuracy: 0.8612
# Epoch 16: val_accuracy improved from 0.88557 to 0.89055, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 132ms/step - loss: 0.3514 - accuracy: 0.8587 - val_loss: 0.2780 - val_accuracy: 0.8905
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2976 - accuracy: 0.8662
# Epoch 17: val_accuracy did not improve from 0.89055
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2990 - accuracy: 0.8649 - val_loss: 0.2601 - val_accuracy: 0.8905
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2697 - accuracy: 0.8800
# Epoch 18: val_accuracy improved from 0.89055 to 0.91542, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2721 - accuracy: 0.8773 - val_loss: 0.2333 - val_accuracy: 0.9154
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2772 - accuracy: 0.8838
# Epoch 19: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2792 - accuracy: 0.8823 - val_loss: 0.2492 - val_accuracy: 0.8905
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2959 - accuracy: 0.8750
# Epoch 20: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2966 - accuracy: 0.8748 - val_loss: 0.2784 - val_accuracy: 0.8955
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2577 - accuracy: 0.9000
# Epoch 21: val_accuracy improved from 0.91542 to 0.92040, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.2592 - accuracy: 0.8984 - val_loss: 0.2021 - val_accuracy: 0.9204
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2584 - accuracy: 0.8925
# Epoch 22: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2601 - accuracy: 0.8910 - val_loss: 0.2227 - val_accuracy: 0.8955
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2476 - accuracy: 0.8963
# Epoch 23: val_accuracy improved from 0.92040 to 0.92537, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2492 - accuracy: 0.8959 - val_loss: 0.1926 - val_accuracy: 0.9254
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2438 - accuracy: 0.9062
# Epoch 24: val_accuracy improved from 0.92537 to 0.94527, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 133ms/step - loss: 0.2459 - accuracy: 0.9058 - val_loss: 0.1788 - val_accuracy: 0.9453
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2341 - accuracy: 0.9075
# Epoch 25: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2356 - accuracy: 0.9071 - val_loss: 0.1803 - val_accuracy: 0.9254
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2306 - accuracy: 0.9150
# Epoch 26: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2319 - accuracy: 0.9145 - val_loss: 0.2061 - val_accuracy: 0.9055
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2668 - accuracy: 0.8813
# Epoch 27: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2671 - accuracy: 0.8810 - val_loss: 0.2008 - val_accuracy: 0.9353
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2461 - accuracy: 0.9025
# Epoch 28: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2483 - accuracy: 0.8996 - val_loss: 0.2284 - val_accuracy: 0.9005
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2824 - accuracy: 0.8737
# Epoch 29: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2828 - accuracy: 0.8736 - val_loss: 0.2500 - val_accuracy: 0.8905
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2617 - accuracy: 0.8863
# Epoch 30: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2623 - accuracy: 0.8860 - val_loss: 0.1728 - val_accuracy: 0.9303
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2137 - accuracy: 0.9150
# Epoch 31: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2153 - accuracy: 0.9145 - val_loss: 0.1977 - val_accuracy: 0.9055
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2061 - accuracy: 0.9087
# Epoch 32: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2069 - accuracy: 0.9083 - val_loss: 0.1764 - val_accuracy: 0.9254
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2078 - accuracy: 0.9100
# Epoch 33: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2088 - accuracy: 0.9083 - val_loss: 0.1664 - val_accuracy: 0.9254
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2008 - accuracy: 0.9150
# Epoch 34: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2019 - accuracy: 0.9145 - val_loss: 0.2307 - val_accuracy: 0.8905
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2351 - accuracy: 0.9062
# Epoch 35: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2350 - accuracy: 0.9058 - val_loss: 0.1744 - val_accuracy: 0.9303
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2171 - accuracy: 0.9212
# Epoch 36: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2183 - accuracy: 0.9195 - val_loss: 0.2037 - val_accuracy: 0.8905
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2408 - accuracy: 0.8925
# Epoch 37: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2408 - accuracy: 0.8922 - val_loss: 0.2743 - val_accuracy: 0.8955
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1911 - accuracy: 0.9250
# Epoch 38: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.1927 - accuracy: 0.9244 - val_loss: 0.1913 - val_accuracy: 0.9154
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2010 - accuracy: 0.9150
# Epoch 39: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 123ms/step - loss: 0.2010 - accuracy: 0.9145 - val_loss: 0.1679 - val_accuracy: 0.9353
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1902 - accuracy: 0.9200
# Epoch 40: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1907 - accuracy: 0.9195 - val_loss: 0.1405 - val_accuracy: 0.9403
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1582 - accuracy: 0.9425
# Epoch 41: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1615 - accuracy: 0.9405 - val_loss: 0.1836 - val_accuracy: 0.9005
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2300 - accuracy: 0.9125
# Epoch 42: val_accuracy did not improve from 0.94527
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2297 - accuracy: 0.9133 - val_loss: 0.2084 - val_accuracy: 0.9204
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2066 - accuracy: 0.9337
# Epoch 43: val_accuracy improved from 0.94527 to 0.95025, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.2071 - accuracy: 0.9331 - val_loss: 0.1559 - val_accuracy: 0.9502
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2193 - accuracy: 0.9125
# Epoch 44: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2205 - accuracy: 0.9120 - val_loss: 0.1474 - val_accuracy: 0.9453
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1883 - accuracy: 0.9187
# Epoch 45: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1887 - accuracy: 0.9182 - val_loss: 0.1913 - val_accuracy: 0.9154
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1880 - accuracy: 0.9212
# Epoch 46: val_accuracy improved from 0.95025 to 0.96020, saving model to /s_model_Aug_NoOpt.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.1890 - accuracy: 0.9195 - val_loss: 0.1389 - val_accuracy: 0.9602
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2104 - accuracy: 0.9225
# Epoch 47: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2109 - accuracy: 0.9232 - val_loss: 0.3272 - val_accuracy: 0.8507
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1611 - accuracy: 0.9450
# Epoch 48: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1621 - accuracy: 0.9442 - val_loss: 0.1668 - val_accuracy: 0.9353
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1770 - accuracy: 0.9250
# Epoch 49: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1779 - accuracy: 0.9244 - val_loss: 0.1747 - val_accuracy: 0.9254
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1651 - accuracy: 0.9375
# Epoch 50: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1653 - accuracy: 0.9368 - val_loss: 0.1858 - val_accuracy: 0.9055
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[135   5]
#  [ 14  47]]

# %%
#based of https://keras.io/examples/vision/image_classification_from_scratch/
imgSize = (img_height, img_width)
img = tf.keras.preprocessing.image.load_img(
    "/content/drive/MyDrive/fabric_classification/Fabrics_simple/Wool/7/im_1.png", target_size=imgSize
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

pred = model.predict(img_array)
print(np.round(pred[0:1], 2))
print(pred)
pred_val = np.argmax(pred,axis=1)
print(class_names)
print(f"This image is {pred_val}.")
# Out:
# [[-3.8  9.1]]
# [[-3.7963433  9.100934 ]]
# ['Denim', 'Wool']
# This image is [1].
