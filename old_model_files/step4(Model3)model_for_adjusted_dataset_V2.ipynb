# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),

  tf.keras.layers.Dense(num_classes)
])

#tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
 #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.MaxPooling2D(),
  #tf.keras.layers.Flatten(),
  #tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(0.00005)),
  #tf.keras.layers.Dropout(0.8),

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 1.5164 - accuracy: 0.4867
# Epoch 1: val_accuracy improved from -inf to 0.54691, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 22s 162ms/step - loss: 1.5164 - accuracy: 0.4867 - val_loss: 1.2774 - val_accuracy: 0.5469
# Epoch 2/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2097 - accuracy: 0.5756
# Epoch 2: val_accuracy improved from 0.54691 to 0.55650, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 1.2088 - accuracy: 0.5759 - val_loss: 1.1945 - val_accuracy: 0.5565
# Epoch 3/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1231 - accuracy: 0.6122
# Epoch 3: val_accuracy improved from 0.55650 to 0.60128, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 1.1229 - accuracy: 0.6124 - val_loss: 1.1858 - val_accuracy: 0.6013
# Epoch 4/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0804 - accuracy: 0.6285
# Epoch 4: val_accuracy did not improve from 0.60128
# 118/118 [==============================] - 9s 75ms/step - loss: 1.0800 - accuracy: 0.6287 - val_loss: 1.1268 - val_accuracy: 0.6013
# Epoch 5/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0164 - accuracy: 0.6477
# Epoch 5: val_accuracy improved from 0.60128 to 0.63113, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 1.0161 - accuracy: 0.6478 - val_loss: 1.0755 - val_accuracy: 0.6311
# Epoch 6/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9830 - accuracy: 0.6656
# Epoch 6: val_accuracy improved from 0.63113 to 0.63966, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 0.9833 - accuracy: 0.6652 - val_loss: 1.0598 - val_accuracy: 0.6397
# Epoch 7/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9463 - accuracy: 0.6699
# Epoch 7: val_accuracy improved from 0.63966 to 0.67591, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 0.9464 - accuracy: 0.6702 - val_loss: 0.9483 - val_accuracy: 0.6759
# Epoch 8/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9622 - accuracy: 0.6627
# Epoch 8: val_accuracy did not improve from 0.67591
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9615 - accuracy: 0.6630 - val_loss: 0.9873 - val_accuracy: 0.6461
# Epoch 9/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9261 - accuracy: 0.6749
# Epoch 9: val_accuracy did not improve from 0.67591
# 118/118 [==============================] - 9s 74ms/step - loss: 0.9259 - accuracy: 0.6750 - val_loss: 0.9321 - val_accuracy: 0.6748
# Epoch 10/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8976 - accuracy: 0.6851
# Epoch 10: val_accuracy did not improve from 0.67591
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8976 - accuracy: 0.6851 - val_loss: 0.9255 - val_accuracy: 0.6652
# Epoch 11/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8966 - accuracy: 0.6896
# Epoch 11: val_accuracy improved from 0.67591 to 0.68337, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.8962 - accuracy: 0.6902 - val_loss: 0.8816 - val_accuracy: 0.6834
# Epoch 12/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8726 - accuracy: 0.6955
# Epoch 12: val_accuracy did not improve from 0.68337
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8722 - accuracy: 0.6958 - val_loss: 0.8878 - val_accuracy: 0.6791
# Epoch 13/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8662 - accuracy: 0.6923
# Epoch 13: val_accuracy improved from 0.68337 to 0.68977, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 0.8655 - accuracy: 0.6926 - val_loss: 0.8688 - val_accuracy: 0.6898
# Epoch 14/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8347 - accuracy: 0.7003
# Epoch 14: val_accuracy did not improve from 0.68977
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8345 - accuracy: 0.7003 - val_loss: 0.8859 - val_accuracy: 0.6770
# Epoch 15/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8286 - accuracy: 0.7035
# Epoch 15: val_accuracy did not improve from 0.68977
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8280 - accuracy: 0.7038 - val_loss: 0.9079 - val_accuracy: 0.6663
# Epoch 16/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8428 - accuracy: 0.6971
# Epoch 16: val_accuracy did not improve from 0.68977
# 118/118 [==============================] - 9s 74ms/step - loss: 0.8418 - accuracy: 0.6977 - val_loss: 0.9064 - val_accuracy: 0.6663
# Epoch 17/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7999 - accuracy: 0.7142
# Epoch 17: val_accuracy improved from 0.68977 to 0.69403, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 0.7992 - accuracy: 0.7147 - val_loss: 0.8277 - val_accuracy: 0.6940
# Epoch 18/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7994 - accuracy: 0.7099
# Epoch 18: val_accuracy improved from 0.69403 to 0.71855, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 0.7984 - accuracy: 0.7104 - val_loss: 0.7583 - val_accuracy: 0.7186
# Epoch 19/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7638 - accuracy: 0.7214
# Epoch 19: val_accuracy did not improve from 0.71855
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7631 - accuracy: 0.7219 - val_loss: 0.7818 - val_accuracy: 0.7122
# Epoch 20/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7464 - accuracy: 0.7260
# Epoch 20: val_accuracy improved from 0.71855 to 0.72388, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.7463 - accuracy: 0.7262 - val_loss: 0.8078 - val_accuracy: 0.7239
# Epoch 21/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7395 - accuracy: 0.7348
# Epoch 21: val_accuracy did not improve from 0.72388
# 118/118 [==============================] - 9s 73ms/step - loss: 0.7385 - accuracy: 0.7352 - val_loss: 0.7314 - val_accuracy: 0.7217
# Epoch 22/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7378 - accuracy: 0.7308
# Epoch 22: val_accuracy improved from 0.72388 to 0.73561, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.7370 - accuracy: 0.7310 - val_loss: 0.7240 - val_accuracy: 0.7356
# Epoch 23/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6943 - accuracy: 0.7527
# Epoch 23: val_accuracy did not improve from 0.73561
# 118/118 [==============================] - 9s 74ms/step - loss: 0.6931 - accuracy: 0.7533 - val_loss: 0.8168 - val_accuracy: 0.6994
# Epoch 24/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7073 - accuracy: 0.7393
# Epoch 24: val_accuracy did not improve from 0.73561
# 118/118 [==============================] - 9s 74ms/step - loss: 0.7069 - accuracy: 0.7397 - val_loss: 0.8950 - val_accuracy: 0.6898
# Epoch 25/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7218 - accuracy: 0.7407
# Epoch 25: val_accuracy improved from 0.73561 to 0.74307, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 84ms/step - loss: 0.7206 - accuracy: 0.7411 - val_loss: 0.6893 - val_accuracy: 0.7431
# Epoch 26/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6732 - accuracy: 0.7548
# Epoch 26: val_accuracy improved from 0.74307 to 0.74947, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 0.6728 - accuracy: 0.7552 - val_loss: 0.6798 - val_accuracy: 0.7495
# Epoch 27/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6602 - accuracy: 0.7588
# Epoch 27: val_accuracy did not improve from 0.74947
# 118/118 [==============================] - 9s 74ms/step - loss: 0.6597 - accuracy: 0.7592 - val_loss: 0.7721 - val_accuracy: 0.7122
# Epoch 28/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6423 - accuracy: 0.7631
# Epoch 28: val_accuracy improved from 0.74947 to 0.75267, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 85ms/step - loss: 0.6414 - accuracy: 0.7635 - val_loss: 0.6657 - val_accuracy: 0.7527
# Epoch 29/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6361 - accuracy: 0.7690
# Epoch 29: val_accuracy did not improve from 0.75267
# 118/118 [==============================] - 9s 74ms/step - loss: 0.6350 - accuracy: 0.7696 - val_loss: 0.7184 - val_accuracy: 0.7441
# Epoch 30/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6496 - accuracy: 0.7607
# Epoch 30: val_accuracy improved from 0.75267 to 0.75906, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 87ms/step - loss: 0.6487 - accuracy: 0.7611 - val_loss: 0.6425 - val_accuracy: 0.7591
# Epoch 31/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6036 - accuracy: 0.7735
# Epoch 31: val_accuracy did not improve from 0.75906
# 118/118 [==============================] - 9s 74ms/step - loss: 0.6035 - accuracy: 0.7738 - val_loss: 0.7048 - val_accuracy: 0.7452
# Epoch 32/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.7695
# Epoch 32: val_accuracy improved from 0.75906 to 0.76439, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.6209 - accuracy: 0.7698 - val_loss: 0.6438 - val_accuracy: 0.7644
# Epoch 33/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5834 - accuracy: 0.7794
# Epoch 33: val_accuracy improved from 0.76439 to 0.77505, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 77ms/step - loss: 0.5822 - accuracy: 0.7800 - val_loss: 0.6275 - val_accuracy: 0.7751
# Epoch 34/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5874 - accuracy: 0.7818
# Epoch 34: val_accuracy did not improve from 0.77505
# 118/118 [==============================] - 9s 74ms/step - loss: 0.5871 - accuracy: 0.7821 - val_loss: 0.6458 - val_accuracy: 0.7719
# Epoch 35/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5826 - accuracy: 0.7815
# Epoch 35: val_accuracy did not improve from 0.77505
# 118/118 [==============================] - 9s 74ms/step - loss: 0.5819 - accuracy: 0.7816 - val_loss: 0.6860 - val_accuracy: 0.7591
# Epoch 36/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5574 - accuracy: 0.7957
# Epoch 36: val_accuracy did not improve from 0.77505
# 118/118 [==============================] - 9s 74ms/step - loss: 0.5569 - accuracy: 0.7960 - val_loss: 0.6541 - val_accuracy: 0.7708
# Epoch 37/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7999
# Epoch 37: val_accuracy did not improve from 0.77505
# 118/118 [==============================] - 9s 74ms/step - loss: 0.5368 - accuracy: 0.8002 - val_loss: 0.7523 - val_accuracy: 0.7431
# Epoch 38/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5229 - accuracy: 0.8093
# Epoch 38: val_accuracy improved from 0.77505 to 0.78145, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.5219 - accuracy: 0.8095 - val_loss: 0.5986 - val_accuracy: 0.7814
# Epoch 39/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5324 - accuracy: 0.8026
# Epoch 39: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 9s 74ms/step - loss: 0.5317 - accuracy: 0.8029 - val_loss: 0.6737 - val_accuracy: 0.7484
# Epoch 40/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5359 - accuracy: 0.8024
# Epoch 40: val_accuracy improved from 0.78145 to 0.79211, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.5347 - accuracy: 0.8029 - val_loss: 0.5993 - val_accuracy: 0.7921
# Epoch 41/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4925 - accuracy: 0.8232
# Epoch 41: val_accuracy did not improve from 0.79211
# 118/118 [==============================] - 9s 74ms/step - loss: 0.4915 - accuracy: 0.8237 - val_loss: 0.5887 - val_accuracy: 0.7921
# Epoch 42/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4816 - accuracy: 0.8205
# Epoch 42: val_accuracy did not improve from 0.79211
# 118/118 [==============================] - 9s 74ms/step - loss: 0.4806 - accuracy: 0.8210 - val_loss: 0.6462 - val_accuracy: 0.7846
# Epoch 43/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4971 - accuracy: 0.8152
# Epoch 43: val_accuracy did not improve from 0.79211
# 118/118 [==============================] - 9s 73ms/step - loss: 0.4966 - accuracy: 0.8154 - val_loss: 0.6337 - val_accuracy: 0.7708
# Epoch 44/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4667 - accuracy: 0.8304
# Epoch 44: val_accuracy did not improve from 0.79211
# 118/118 [==============================] - 9s 73ms/step - loss: 0.4659 - accuracy: 0.8308 - val_loss: 0.6930 - val_accuracy: 0.7708
# Epoch 45/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4637 - accuracy: 0.8296
# Epoch 45: val_accuracy improved from 0.79211 to 0.79638, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.4628 - accuracy: 0.8300 - val_loss: 0.5529 - val_accuracy: 0.7964
# Epoch 46/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4546 - accuracy: 0.8315
# Epoch 46: val_accuracy improved from 0.79638 to 0.79957, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 10s 83ms/step - loss: 0.4539 - accuracy: 0.8316 - val_loss: 0.5416 - val_accuracy: 0.7996
# Epoch 47/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4631 - accuracy: 0.8267
# Epoch 47: val_accuracy improved from 0.79957 to 0.80171, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V2.h5
# 118/118 [==============================] - 9s 76ms/step - loss: 0.4622 - accuracy: 0.8271 - val_loss: 0.5699 - val_accuracy: 0.8017
# Epoch 48/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4413 - accuracy: 0.8376
# Epoch 48: val_accuracy did not improve from 0.80171
# 118/118 [==============================] - 9s 74ms/step - loss: 0.4404 - accuracy: 0.8380 - val_loss: 0.5683 - val_accuracy: 0.7910
# Epoch 49/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4469 - accuracy: 0.8339
# Epoch 49: val_accuracy did not improve from 0.80171
# 118/118 [==============================] - 9s 73ms/step - loss: 0.4459 - accuracy: 0.8343 - val_loss: 0.5888 - val_accuracy: 0.7708
# Epoch 50/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.4398 - accuracy: 0.8379
# Epoch 50: val_accuracy did not improve from 0.80171
# 118/118 [==============================] - 9s 74ms/step - loss: 0.4390 - accuracy: 0.8383 - val_loss: 0.6269 - val_accuracy: 0.7804
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 9,457,478
# Trainable params: 9,457,478
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (938, 6)
# (938,)
# (938,)
# [[368  14   1  35   1  26]
#  [  8 113   0   1   0  16]
#  [  7   1  21  10   1   0]
#  [ 16   0   1 149  19   9]
#  [  0   0   1  11  28   0]
#  [  9   0   0  19   0  53]]
