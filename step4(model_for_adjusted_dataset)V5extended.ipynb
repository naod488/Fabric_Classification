# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.6),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/content/drive/MyDrive/fabric_classification/a_model_Aug_V5extended.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')
hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 100, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/100
# 118/118 [==============================] - ETA: 0s - loss: 1.4660 - accuracy: 0.4987
# Epoch 1: val_accuracy improved from -inf to 0.53092, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 386s 3s/step - loss: 1.4660 - accuracy: 0.4987 - val_loss: 1.4562 - val_accuracy: 0.5309
# Epoch 2/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.3491 - accuracy: 0.5283
# Epoch 2: val_accuracy did not improve from 0.53092
# 118/118 [==============================] - 15s 127ms/step - loss: 1.3483 - accuracy: 0.5288 - val_loss: 1.2716 - val_accuracy: 0.5213
# Epoch 3/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.2958 - accuracy: 0.5561
# Epoch 3: val_accuracy improved from 0.53092 to 0.55650, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 134ms/step - loss: 1.2953 - accuracy: 0.5565 - val_loss: 1.2300 - val_accuracy: 0.5565
# Epoch 4/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.2603 - accuracy: 0.5598
# Epoch 4: val_accuracy did not improve from 0.55650
# 118/118 [==============================] - 15s 128ms/step - loss: 1.2596 - accuracy: 0.5605 - val_loss: 1.2529 - val_accuracy: 0.5469
# Epoch 5/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.2244 - accuracy: 0.5807
# Epoch 5: val_accuracy improved from 0.55650 to 0.61727, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 134ms/step - loss: 1.2241 - accuracy: 0.5810 - val_loss: 1.1468 - val_accuracy: 0.6173
# Epoch 6/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.1812 - accuracy: 0.5863
# Epoch 6: val_accuracy did not improve from 0.61727
# 118/118 [==============================] - 15s 130ms/step - loss: 1.1799 - accuracy: 0.5868 - val_loss: 1.1248 - val_accuracy: 0.6130
# Epoch 7/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.1537 - accuracy: 0.5988
# Epoch 7: val_accuracy did not improve from 0.61727
# 118/118 [==============================] - 15s 130ms/step - loss: 1.1529 - accuracy: 0.5991 - val_loss: 1.1904 - val_accuracy: 0.6034
# Epoch 8/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.1199 - accuracy: 0.6231
# Epoch 8: val_accuracy did not improve from 0.61727
# 118/118 [==============================] - 15s 129ms/step - loss: 1.1200 - accuracy: 0.6231 - val_loss: 1.1797 - val_accuracy: 0.5906
# Epoch 9/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.0759 - accuracy: 0.6309
# Epoch 9: val_accuracy improved from 0.61727 to 0.63753, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 1.0754 - accuracy: 0.6313 - val_loss: 1.0518 - val_accuracy: 0.6375
# Epoch 10/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.0560 - accuracy: 0.6389
# Epoch 10: val_accuracy improved from 0.63753 to 0.64606, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 1.0551 - accuracy: 0.6396 - val_loss: 1.0373 - val_accuracy: 0.6461
# Epoch 11/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.0339 - accuracy: 0.6480
# Epoch 11: val_accuracy improved from 0.64606 to 0.66098, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 17s 141ms/step - loss: 1.0335 - accuracy: 0.6484 - val_loss: 0.9786 - val_accuracy: 0.6610
# Epoch 12/100
# 117/118 [============================>.] - ETA: 0s - loss: 1.0092 - accuracy: 0.6501
# Epoch 12: val_accuracy did not improve from 0.66098
# 118/118 [==============================] - 15s 129ms/step - loss: 1.0092 - accuracy: 0.6505 - val_loss: 1.0363 - val_accuracy: 0.6301
# Epoch 13/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9860 - accuracy: 0.6627
# Epoch 13: val_accuracy improved from 0.66098 to 0.67591, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.9853 - accuracy: 0.6633 - val_loss: 0.9387 - val_accuracy: 0.6759
# Epoch 14/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9766 - accuracy: 0.6595
# Epoch 14: val_accuracy improved from 0.67591 to 0.69190, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.9755 - accuracy: 0.6601 - val_loss: 0.8959 - val_accuracy: 0.6919
# Epoch 15/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9369 - accuracy: 0.6760
# Epoch 15: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9359 - accuracy: 0.6766 - val_loss: 0.9007 - val_accuracy: 0.6802
# Epoch 16/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9320 - accuracy: 0.6717
# Epoch 16: val_accuracy improved from 0.69190 to 0.69296, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.9314 - accuracy: 0.6723 - val_loss: 0.8832 - val_accuracy: 0.6930
# Epoch 17/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9193 - accuracy: 0.6757
# Epoch 17: val_accuracy improved from 0.69296 to 0.69936, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 0.9182 - accuracy: 0.6763 - val_loss: 0.8407 - val_accuracy: 0.6994
# Epoch 18/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.9080 - accuracy: 0.6800
# Epoch 18: val_accuracy did not improve from 0.69936
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9071 - accuracy: 0.6803 - val_loss: 0.8935 - val_accuracy: 0.6919
# Epoch 19/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8836 - accuracy: 0.6838
# Epoch 19: val_accuracy did not improve from 0.69936
# 118/118 [==============================] - 15s 129ms/step - loss: 0.8826 - accuracy: 0.6841 - val_loss: 0.8289 - val_accuracy: 0.6898
# Epoch 20/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8717 - accuracy: 0.6872
# Epoch 20: val_accuracy improved from 0.69936 to 0.72921, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.8708 - accuracy: 0.6875 - val_loss: 0.7840 - val_accuracy: 0.7292
# Epoch 21/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8589 - accuracy: 0.6910
# Epoch 21: val_accuracy did not improve from 0.72921
# 118/118 [==============================] - 15s 129ms/step - loss: 0.8581 - accuracy: 0.6913 - val_loss: 0.8059 - val_accuracy: 0.7100
# Epoch 22/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8395 - accuracy: 0.7011
# Epoch 22: val_accuracy did not improve from 0.72921
# 118/118 [==============================] - 15s 129ms/step - loss: 0.8379 - accuracy: 0.7019 - val_loss: 0.7746 - val_accuracy: 0.7271
# Epoch 23/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8293 - accuracy: 0.7033
# Epoch 23: val_accuracy did not improve from 0.72921
# 118/118 [==============================] - 15s 129ms/step - loss: 0.8286 - accuracy: 0.7038 - val_loss: 0.8092 - val_accuracy: 0.7186
# Epoch 24/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8256 - accuracy: 0.7033
# Epoch 24: val_accuracy did not improve from 0.72921
# 118/118 [==============================] - 15s 129ms/step - loss: 0.8249 - accuracy: 0.7035 - val_loss: 0.7633 - val_accuracy: 0.7228
# Epoch 25/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.8106 - accuracy: 0.7091
# Epoch 25: val_accuracy improved from 0.72921 to 0.75586, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.8090 - accuracy: 0.7099 - val_loss: 0.7223 - val_accuracy: 0.7559
# Epoch 26/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7708 - accuracy: 0.7158
# Epoch 26: val_accuracy did not improve from 0.75586
# 118/118 [==============================] - 15s 129ms/step - loss: 0.7696 - accuracy: 0.7163 - val_loss: 0.7368 - val_accuracy: 0.7463
# Epoch 27/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7860 - accuracy: 0.7198
# Epoch 27: val_accuracy did not improve from 0.75586
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7855 - accuracy: 0.7198 - val_loss: 0.7517 - val_accuracy: 0.7345
# Epoch 28/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7638 - accuracy: 0.7233
# Epoch 28: val_accuracy did not improve from 0.75586
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7631 - accuracy: 0.7235 - val_loss: 0.7157 - val_accuracy: 0.7377
# Epoch 29/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7743 - accuracy: 0.7225
# Epoch 29: val_accuracy improved from 0.75586 to 0.76013, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 0.7729 - accuracy: 0.7232 - val_loss: 0.6911 - val_accuracy: 0.7601
# Epoch 30/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.7396
# Epoch 30: val_accuracy did not improve from 0.76013
# 118/118 [==============================] - 15s 129ms/step - loss: 0.7110 - accuracy: 0.7400 - val_loss: 0.7484 - val_accuracy: 0.7281
# Epoch 31/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7229 - accuracy: 0.7452
# Epoch 31: val_accuracy did not improve from 0.76013
# 118/118 [==============================] - 15s 129ms/step - loss: 0.7217 - accuracy: 0.7456 - val_loss: 0.6987 - val_accuracy: 0.7548
# Epoch 32/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7165 - accuracy: 0.7385
# Epoch 32: val_accuracy did not improve from 0.76013
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7153 - accuracy: 0.7392 - val_loss: 0.7025 - val_accuracy: 0.7441
# Epoch 33/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.7417
# Epoch 33: val_accuracy did not improve from 0.76013
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7052 - accuracy: 0.7424 - val_loss: 0.6716 - val_accuracy: 0.7580
# Epoch 34/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7034 - accuracy: 0.7447
# Epoch 34: val_accuracy did not improve from 0.76013
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7023 - accuracy: 0.7451 - val_loss: 0.7557 - val_accuracy: 0.7217
# Epoch 35/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.7110 - accuracy: 0.7377
# Epoch 35: val_accuracy improved from 0.76013 to 0.76119, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.7098 - accuracy: 0.7381 - val_loss: 0.6891 - val_accuracy: 0.7612
# Epoch 36/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6750 - accuracy: 0.7561
# Epoch 36: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 129ms/step - loss: 0.6737 - accuracy: 0.7565 - val_loss: 0.6562 - val_accuracy: 0.7612
# Epoch 37/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6783 - accuracy: 0.7561
# Epoch 37: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6777 - accuracy: 0.7563 - val_loss: 0.7161 - val_accuracy: 0.7388
# Epoch 38/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6764 - accuracy: 0.7577
# Epoch 38: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6754 - accuracy: 0.7581 - val_loss: 0.7207 - val_accuracy: 0.7228
# Epoch 39/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6733 - accuracy: 0.7615
# Epoch 39: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6719 - accuracy: 0.7621 - val_loss: 0.6650 - val_accuracy: 0.7569
# Epoch 40/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6651 - accuracy: 0.7591
# Epoch 40: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 129ms/step - loss: 0.6642 - accuracy: 0.7597 - val_loss: 0.6574 - val_accuracy: 0.7612
# Epoch 41/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6643 - accuracy: 0.7583
# Epoch 41: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 129ms/step - loss: 0.6635 - accuracy: 0.7587 - val_loss: 0.7041 - val_accuracy: 0.7281
# Epoch 42/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6267 - accuracy: 0.7730
# Epoch 42: val_accuracy improved from 0.76119 to 0.77185, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 0.6255 - accuracy: 0.7736 - val_loss: 0.6591 - val_accuracy: 0.7719
# Epoch 43/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6286 - accuracy: 0.7676
# Epoch 43: val_accuracy did not improve from 0.77185
# 118/118 [==============================] - 15s 129ms/step - loss: 0.6276 - accuracy: 0.7680 - val_loss: 0.6582 - val_accuracy: 0.7612
# Epoch 44/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6060 - accuracy: 0.7847
# Epoch 44: val_accuracy improved from 0.77185 to 0.77932, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.6055 - accuracy: 0.7848 - val_loss: 0.6447 - val_accuracy: 0.7793
# Epoch 45/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6095 - accuracy: 0.7812
# Epoch 45: val_accuracy improved from 0.77932 to 0.78145, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 140ms/step - loss: 0.6084 - accuracy: 0.7818 - val_loss: 0.5961 - val_accuracy: 0.7814
# Epoch 46/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6002 - accuracy: 0.7837
# Epoch 46: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5993 - accuracy: 0.7842 - val_loss: 0.7461 - val_accuracy: 0.7196
# Epoch 47/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6592 - accuracy: 0.7583
# Epoch 47: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6582 - accuracy: 0.7589 - val_loss: 0.6933 - val_accuracy: 0.7559
# Epoch 48/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6306 - accuracy: 0.7716
# Epoch 48: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 15s 129ms/step - loss: 0.6302 - accuracy: 0.7717 - val_loss: 0.6355 - val_accuracy: 0.7527
# Epoch 49/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.6280 - accuracy: 0.7767
# Epoch 49: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6273 - accuracy: 0.7770 - val_loss: 0.6806 - val_accuracy: 0.7356
# Epoch 50/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5716 - accuracy: 0.7919
# Epoch 50: val_accuracy did not improve from 0.78145
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5705 - accuracy: 0.7925 - val_loss: 0.6084 - val_accuracy: 0.7804
# Epoch 51/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5776 - accuracy: 0.7946
# Epoch 51: val_accuracy improved from 0.78145 to 0.80597, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.5771 - accuracy: 0.7949 - val_loss: 0.5532 - val_accuracy: 0.8060
# Epoch 52/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5869 - accuracy: 0.7935
# Epoch 52: val_accuracy did not improve from 0.80597
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5857 - accuracy: 0.7938 - val_loss: 0.6176 - val_accuracy: 0.7878
# Epoch 53/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7871
# Epoch 53: val_accuracy did not improve from 0.80597
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5678 - accuracy: 0.7877 - val_loss: 0.5840 - val_accuracy: 0.7729
# Epoch 54/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5611 - accuracy: 0.7949
# Epoch 54: val_accuracy improved from 0.80597 to 0.80810, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.5604 - accuracy: 0.7949 - val_loss: 0.5259 - val_accuracy: 0.8081
# Epoch 55/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5645 - accuracy: 0.7935
# Epoch 55: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5635 - accuracy: 0.7941 - val_loss: 0.6107 - val_accuracy: 0.7783
# Epoch 56/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.8034
# Epoch 56: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 129ms/step - loss: 0.5433 - accuracy: 0.8039 - val_loss: 0.6484 - val_accuracy: 0.7772
# Epoch 57/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5270 - accuracy: 0.8045
# Epoch 57: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5260 - accuracy: 0.8050 - val_loss: 0.5901 - val_accuracy: 0.7974
# Epoch 58/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5325 - accuracy: 0.8152
# Epoch 58: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5315 - accuracy: 0.8157 - val_loss: 0.5833 - val_accuracy: 0.7878
# Epoch 59/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5566 - accuracy: 0.7882
# Epoch 59: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5555 - accuracy: 0.7888 - val_loss: 0.5950 - val_accuracy: 0.7825
# Epoch 60/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.8053
# Epoch 60: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5406 - accuracy: 0.8058 - val_loss: 0.5606 - val_accuracy: 0.7932
# Epoch 61/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5245 - accuracy: 0.8098
# Epoch 61: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 129ms/step - loss: 0.5236 - accuracy: 0.8101 - val_loss: 0.5471 - val_accuracy: 0.7964
# Epoch 62/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5282 - accuracy: 0.8072
# Epoch 62: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 129ms/step - loss: 0.5269 - accuracy: 0.8077 - val_loss: 0.5691 - val_accuracy: 0.8049
# Epoch 63/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5232 - accuracy: 0.8165
# Epoch 63: val_accuracy did not improve from 0.80810
# 118/118 [==============================] - 15s 129ms/step - loss: 0.5226 - accuracy: 0.8167 - val_loss: 0.6306 - val_accuracy: 0.7623
# Epoch 64/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5202 - accuracy: 0.8114
# Epoch 64: val_accuracy improved from 0.80810 to 0.81450, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 0.5199 - accuracy: 0.8114 - val_loss: 0.5335 - val_accuracy: 0.8145
# Epoch 65/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5271 - accuracy: 0.8085
# Epoch 65: val_accuracy did not improve from 0.81450
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5266 - accuracy: 0.8087 - val_loss: 0.5902 - val_accuracy: 0.7825
# Epoch 66/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5309 - accuracy: 0.8072
# Epoch 66: val_accuracy did not improve from 0.81450
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5301 - accuracy: 0.8074 - val_loss: 0.6740 - val_accuracy: 0.7548
# Epoch 67/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4989 - accuracy: 0.8117
# Epoch 67: val_accuracy did not improve from 0.81450
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4983 - accuracy: 0.8119 - val_loss: 0.5546 - val_accuracy: 0.7974
# Epoch 68/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4946 - accuracy: 0.8194
# Epoch 68: val_accuracy did not improve from 0.81450
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4935 - accuracy: 0.8199 - val_loss: 0.5107 - val_accuracy: 0.8070
# Epoch 69/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5005 - accuracy: 0.8189
# Epoch 69: val_accuracy did not improve from 0.81450
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4995 - accuracy: 0.8194 - val_loss: 0.6068 - val_accuracy: 0.7729
# Epoch 70/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.8090
# Epoch 70: val_accuracy improved from 0.81450 to 0.81876, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.5169 - accuracy: 0.8090 - val_loss: 0.4966 - val_accuracy: 0.8188
# Epoch 71/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4841 - accuracy: 0.8275
# Epoch 71: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4832 - accuracy: 0.8279 - val_loss: 0.5687 - val_accuracy: 0.7868
# Epoch 72/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.8243
# Epoch 72: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4955 - accuracy: 0.8245 - val_loss: 0.5661 - val_accuracy: 0.7793
# Epoch 73/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4622 - accuracy: 0.8432
# Epoch 73: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4612 - accuracy: 0.8436 - val_loss: 0.6058 - val_accuracy: 0.7793
# Epoch 74/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4890 - accuracy: 0.8216
# Epoch 74: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4878 - accuracy: 0.8221 - val_loss: 0.6227 - val_accuracy: 0.7676
# Epoch 75/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4393 - accuracy: 0.8397
# Epoch 75: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4385 - accuracy: 0.8402 - val_loss: 0.5223 - val_accuracy: 0.7974
# Epoch 76/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4405 - accuracy: 0.8403
# Epoch 76: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4397 - accuracy: 0.8407 - val_loss: 0.5236 - val_accuracy: 0.8134
# Epoch 77/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4712 - accuracy: 0.8307
# Epoch 77: val_accuracy did not improve from 0.81876
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4706 - accuracy: 0.8308 - val_loss: 0.5219 - val_accuracy: 0.8081
# Epoch 78/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4635 - accuracy: 0.8331
# Epoch 78: val_accuracy improved from 0.81876 to 0.83582, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 0.4625 - accuracy: 0.8335 - val_loss: 0.4418 - val_accuracy: 0.8358
# Epoch 79/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4614 - accuracy: 0.8301
# Epoch 79: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 131ms/step - loss: 0.4603 - accuracy: 0.8306 - val_loss: 0.5477 - val_accuracy: 0.7868
# Epoch 80/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4482 - accuracy: 0.8368
# Epoch 80: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4472 - accuracy: 0.8372 - val_loss: 0.5960 - val_accuracy: 0.7868
# Epoch 81/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4431 - accuracy: 0.8400
# Epoch 81: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4423 - accuracy: 0.8404 - val_loss: 0.5527 - val_accuracy: 0.7580
# Epoch 82/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4161 - accuracy: 0.8526
# Epoch 82: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4152 - accuracy: 0.8530 - val_loss: 0.4799 - val_accuracy: 0.8198
# Epoch 83/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4615 - accuracy: 0.8349
# Epoch 83: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4611 - accuracy: 0.8351 - val_loss: 0.5518 - val_accuracy: 0.7878
# Epoch 84/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4271 - accuracy: 0.8478
# Epoch 84: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4265 - accuracy: 0.8482 - val_loss: 0.5071 - val_accuracy: 0.8070
# Epoch 85/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4307 - accuracy: 0.8427
# Epoch 85: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4301 - accuracy: 0.8428 - val_loss: 0.5037 - val_accuracy: 0.7932
# Epoch 86/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4253 - accuracy: 0.8451
# Epoch 86: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4244 - accuracy: 0.8455 - val_loss: 0.6617 - val_accuracy: 0.7559
# Epoch 87/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4543 - accuracy: 0.8459
# Epoch 87: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4533 - accuracy: 0.8463 - val_loss: 0.6517 - val_accuracy: 0.7452
# Epoch 88/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4100 - accuracy: 0.8438
# Epoch 88: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4091 - accuracy: 0.8442 - val_loss: 0.4694 - val_accuracy: 0.8326
# Epoch 89/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4275 - accuracy: 0.8456
# Epoch 89: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4269 - accuracy: 0.8458 - val_loss: 0.5936 - val_accuracy: 0.7836
# Epoch 90/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4436 - accuracy: 0.8462
# Epoch 90: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4430 - accuracy: 0.8463 - val_loss: 0.5603 - val_accuracy: 0.7889
# Epoch 91/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4389 - accuracy: 0.8384
# Epoch 91: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4381 - accuracy: 0.8388 - val_loss: 0.4929 - val_accuracy: 0.8241
# Epoch 92/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4075 - accuracy: 0.8544
# Epoch 92: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4066 - accuracy: 0.8548 - val_loss: 0.4891 - val_accuracy: 0.8230
# Epoch 93/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4008 - accuracy: 0.8630
# Epoch 93: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4001 - accuracy: 0.8633 - val_loss: 0.4754 - val_accuracy: 0.8262
# Epoch 94/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.3860 - accuracy: 0.8542
# Epoch 94: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.3853 - accuracy: 0.8546 - val_loss: 0.5385 - val_accuracy: 0.7964
# Epoch 95/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4371 - accuracy: 0.8440
# Epoch 95: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 130ms/step - loss: 0.4361 - accuracy: 0.8444 - val_loss: 0.5115 - val_accuracy: 0.7900
# Epoch 96/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4057 - accuracy: 0.8542
# Epoch 96: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4050 - accuracy: 0.8546 - val_loss: 0.5304 - val_accuracy: 0.8038
# Epoch 97/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4051 - accuracy: 0.8568
# Epoch 97: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4048 - accuracy: 0.8570 - val_loss: 0.5785 - val_accuracy: 0.7633
# Epoch 98/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4002 - accuracy: 0.8536
# Epoch 98: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.3996 - accuracy: 0.8538 - val_loss: 0.6178 - val_accuracy: 0.7687
# Epoch 99/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4550 - accuracy: 0.8339
# Epoch 99: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4541 - accuracy: 0.8343 - val_loss: 0.4949 - val_accuracy: 0.8273
# Epoch 100/100
# 117/118 [============================>.] - ETA: 0s - loss: 0.4115 - accuracy: 0.8483
# Epoch 100: val_accuracy did not improve from 0.83582
# 118/118 [==============================] - 15s 129ms/step - loss: 0.4106 - accuracy: 0.8487 - val_loss: 0.5169 - val_accuracy: 0.8028
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 4,380,230
# Trainable params: 4,380,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (938, 6)
# (938,)
# (938,)
# [[412   2   0  27   0   4]
#  [ 70  65   0   0   0   3]
#  [  5   0  23  11   0   1]
#  [ 16   0   0 171   4   3]
#  [  1   0   0   8  31   0]
#  [  8   0   0  22   0  51]]
