# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

print(tf.__version__)

import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
data_dir = pathlib.Path(path)
# Out:
# 2.8.0

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-1-NoAug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 17.7346 - accuracy: 0.5316
# Epoch 1: val_accuracy improved from -inf to 0.70149, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 249s 7s/step - loss: 17.7346 - accuracy: 0.5316 - val_loss: 0.9419 - val_accuracy: 0.7015
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 1.5080 - accuracy: 0.6183
# Epoch 2: val_accuracy improved from 0.70149 to 0.73632, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 417ms/step - loss: 1.5080 - accuracy: 0.6183 - val_loss: 0.8381 - val_accuracy: 0.7363
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.7819 - accuracy: 0.7299
# Epoch 3: val_accuracy improved from 0.73632 to 0.74627, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 419ms/step - loss: 0.7819 - accuracy: 0.7299 - val_loss: 0.8726 - val_accuracy: 0.7463
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.7398
# Epoch 4: val_accuracy improved from 0.74627 to 0.85572, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 419ms/step - loss: 0.6683 - accuracy: 0.7398 - val_loss: 0.3178 - val_accuracy: 0.8557
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.3363 - accuracy: 0.8625
# Epoch 5: val_accuracy did not improve from 0.85572
# 26/26 [==============================] - 2s 82ms/step - loss: 0.3363 - accuracy: 0.8625 - val_loss: 0.6754 - val_accuracy: 0.6070
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.4352 - accuracy: 0.8327
# Epoch 6: val_accuracy improved from 0.85572 to 0.94030, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 419ms/step - loss: 0.4352 - accuracy: 0.8327 - val_loss: 0.2534 - val_accuracy: 0.9403
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9368
# Epoch 7: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 77ms/step - loss: 0.1575 - accuracy: 0.9368 - val_loss: 1.0957 - val_accuracy: 0.5075
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2438 - accuracy: 0.8947
# Epoch 8: val_accuracy did not improve from 0.94030
# 26/26 [==============================] - 2s 78ms/step - loss: 0.2438 - accuracy: 0.8947 - val_loss: 0.9071 - val_accuracy: 0.5721
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.8699
# Epoch 9: val_accuracy improved from 0.94030 to 0.95025, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 430ms/step - loss: 0.2860 - accuracy: 0.8699 - val_loss: 0.1594 - val_accuracy: 0.9502
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9653
# Epoch 10: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0972 - accuracy: 0.9653 - val_loss: 0.1554 - val_accuracy: 0.9254
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9888
# Epoch 11: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0531 - accuracy: 0.9888 - val_loss: 0.1842 - val_accuracy: 0.9055
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9888
# Epoch 12: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0560 - accuracy: 0.9888 - val_loss: 0.3315 - val_accuracy: 0.8209
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9901
# Epoch 13: val_accuracy did not improve from 0.95025
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0577 - accuracy: 0.9901 - val_loss: 0.1535 - val_accuracy: 0.9204
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0262 - accuracy: 0.9963
# Epoch 14: val_accuracy improved from 0.95025 to 0.96020, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 421ms/step - loss: 0.0262 - accuracy: 0.9963 - val_loss: 0.1074 - val_accuracy: 0.9602
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 1.0000
# Epoch 15: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9602
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.96020
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9602
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 17: val_accuracy improved from 0.96020 to 0.96517, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 434ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 0.9652
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.96517
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9652
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.96517
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9652
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.96517
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9652
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.96517
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9652
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.96517
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9652
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 23: val_accuracy improved from 0.96517 to 0.97015, saving model to /content/drive/MyDrive/fabric_classification/Model-1-NoAug-fs.h5
# 26/26 [==============================] - 11s 433ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0805 - val_accuracy: 0.9701
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9701
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9652
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9652
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9652
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0805 - val_accuracy: 0.9652
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9602
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9602
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 31: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9602
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 32: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9552
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 33: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9552
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9502
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9502
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9502
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 37: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9502
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9502
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9453
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9453
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9403
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 42: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9403
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 9.6985e-04 - accuracy: 1.0000
# Epoch 43: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 9.6985e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9403
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 9.2023e-04 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 9.2023e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9403
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 8.7336e-04 - accuracy: 1.0000
# Epoch 45: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 8.7336e-04 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9403
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 8.2914e-04 - accuracy: 1.0000
# Epoch 46: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 8.2914e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9403
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 7.8742e-04 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 7.8742e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9403
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 7.4809e-04 - accuracy: 1.0000
# Epoch 48: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 7.4809e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9403
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 7.1185e-04 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 77ms/step - loss: 7.1185e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9403
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 6.7837e-04 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 0.97015
# 26/26 [==============================] - 2s 78ms/step - loss: 6.7837e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9403
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  flatten (Flatten)           (None, 1267232)           0
#
#  dense (Dense)               (None, 128)               162205824
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 162,206,978
# Trainable params: 162,206,978
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[140   0]
#  [ 12  49]]
# 0
