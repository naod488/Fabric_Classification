# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 4692 files belonging to 6 classes.
# Using 3754 files for training.
# Found 4692 files belonging to 6 classes.
# Using 938 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(0.5)
    ]
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

norm = 0.0
dropout_val = 0.6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'), kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'), kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'), kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'), kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.Dropout(dropout_val),
  tf.keras.layers.Dense(64, activation='relu'), kernel_regularizer=tf.keras.regularizers.l1(norm)),
  
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-4a-Aug-fa")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 1.4444 - accuracy: 0.5011
# Epoch 1: val_accuracy improved from -inf to 0.47441, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 27s 176ms/step - loss: 1.4444 - accuracy: 0.5011 - val_loss: 1.3648 - val_accuracy: 0.4744
# Epoch 2/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3483 - accuracy: 0.5294
# Epoch 2: val_accuracy improved from 0.47441 to 0.55330, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.3474 - accuracy: 0.5298 - val_loss: 1.2487 - val_accuracy: 0.5533
# Epoch 3/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.3046 - accuracy: 0.5457
# Epoch 3: val_accuracy did not improve from 0.55330
# 118/118 [==============================] - 15s 128ms/step - loss: 1.3035 - accuracy: 0.5461 - val_loss: 1.2323 - val_accuracy: 0.5501
# Epoch 4/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.2615 - accuracy: 0.5628
# Epoch 4: val_accuracy improved from 0.55330 to 0.56503, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 135ms/step - loss: 1.2603 - accuracy: 0.5631 - val_loss: 1.1823 - val_accuracy: 0.5650
# Epoch 5/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1995 - accuracy: 0.5764
# Epoch 5: val_accuracy did not improve from 0.56503
# 118/118 [==============================] - 15s 127ms/step - loss: 1.1988 - accuracy: 0.5767 - val_loss: 1.2897 - val_accuracy: 0.5426
# Epoch 6/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.1647 - accuracy: 0.6026
# Epoch 6: val_accuracy improved from 0.56503 to 0.62473, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 1.1638 - accuracy: 0.6034 - val_loss: 1.0707 - val_accuracy: 0.6247
# Epoch 7/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0964 - accuracy: 0.6295
# Epoch 7: val_accuracy improved from 0.62473 to 0.64712, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.0957 - accuracy: 0.6300 - val_loss: 1.0352 - val_accuracy: 0.6471
# Epoch 8/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0823 - accuracy: 0.6378
# Epoch 8: val_accuracy did not improve from 0.64712
# 118/118 [==============================] - 15s 128ms/step - loss: 1.0822 - accuracy: 0.6380 - val_loss: 1.0827 - val_accuracy: 0.6205
# Epoch 9/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0740 - accuracy: 0.6330
# Epoch 9: val_accuracy did not improve from 0.64712
# 118/118 [==============================] - 15s 128ms/step - loss: 1.0734 - accuracy: 0.6332 - val_loss: 1.0488 - val_accuracy: 0.6397
# Epoch 10/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0268 - accuracy: 0.6525
# Epoch 10: val_accuracy improved from 0.64712 to 0.66418, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 136ms/step - loss: 1.0262 - accuracy: 0.6526 - val_loss: 0.9919 - val_accuracy: 0.6642
# Epoch 11/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0371 - accuracy: 0.6490
# Epoch 11: val_accuracy improved from 0.66418 to 0.69190, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 1.0364 - accuracy: 0.6494 - val_loss: 0.9550 - val_accuracy: 0.6919
# Epoch 12/50
# 117/118 [============================>.] - ETA: 0s - loss: 1.0004 - accuracy: 0.6608
# Epoch 12: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 129ms/step - loss: 1.0002 - accuracy: 0.6612 - val_loss: 0.9403 - val_accuracy: 0.6716
# Epoch 13/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9857 - accuracy: 0.6648
# Epoch 13: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9858 - accuracy: 0.6646 - val_loss: 0.9375 - val_accuracy: 0.6812
# Epoch 14/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9738 - accuracy: 0.6680
# Epoch 14: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9732 - accuracy: 0.6686 - val_loss: 0.9686 - val_accuracy: 0.6461
# Epoch 15/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9719 - accuracy: 0.6704
# Epoch 15: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 129ms/step - loss: 0.9711 - accuracy: 0.6708 - val_loss: 0.9542 - val_accuracy: 0.6663
# Epoch 16/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9255 - accuracy: 0.6816
# Epoch 16: val_accuracy did not improve from 0.69190
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9248 - accuracy: 0.6819 - val_loss: 0.9071 - val_accuracy: 0.6887
# Epoch 17/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9229 - accuracy: 0.6840
# Epoch 17: val_accuracy improved from 0.69190 to 0.71109, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.9233 - accuracy: 0.6838 - val_loss: 0.8445 - val_accuracy: 0.7111
# Epoch 18/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9304 - accuracy: 0.6731
# Epoch 18: val_accuracy did not improve from 0.71109
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9298 - accuracy: 0.6734 - val_loss: 0.8920 - val_accuracy: 0.6812
# Epoch 19/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9048 - accuracy: 0.6819
# Epoch 19: val_accuracy did not improve from 0.71109
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9039 - accuracy: 0.6822 - val_loss: 0.8447 - val_accuracy: 0.7015
# Epoch 20/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.9029 - accuracy: 0.6864
# Epoch 20: val_accuracy did not improve from 0.71109
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9022 - accuracy: 0.6867 - val_loss: 0.8939 - val_accuracy: 0.6770
# Epoch 21/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8807 - accuracy: 0.6886
# Epoch 21: val_accuracy improved from 0.71109 to 0.71322, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.8801 - accuracy: 0.6891 - val_loss: 0.8253 - val_accuracy: 0.7132
# Epoch 22/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8669 - accuracy: 0.7022
# Epoch 22: val_accuracy did not improve from 0.71322
# 118/118 [==============================] - 15s 130ms/step - loss: 0.8659 - accuracy: 0.7027 - val_loss: 0.8008 - val_accuracy: 0.7122
# Epoch 23/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8367 - accuracy: 0.7086
# Epoch 23: val_accuracy did not improve from 0.71322
# 118/118 [==============================] - 15s 130ms/step - loss: 0.8364 - accuracy: 0.7086 - val_loss: 1.0636 - val_accuracy: 0.6397
# Epoch 24/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8508 - accuracy: 0.6960
# Epoch 24: val_accuracy improved from 0.71322 to 0.71535, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.8497 - accuracy: 0.6966 - val_loss: 0.7748 - val_accuracy: 0.7154
# Epoch 25/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8280 - accuracy: 0.7065
# Epoch 25: val_accuracy improved from 0.71535 to 0.71855, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 0.8270 - accuracy: 0.7070 - val_loss: 0.7864 - val_accuracy: 0.7186
# Epoch 26/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8061 - accuracy: 0.7086
# Epoch 26: val_accuracy improved from 0.71855 to 0.76119, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 0.8055 - accuracy: 0.7088 - val_loss: 0.7111 - val_accuracy: 0.7612
# Epoch 27/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7982 - accuracy: 0.7169
# Epoch 27: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7971 - accuracy: 0.7171 - val_loss: 0.7574 - val_accuracy: 0.7249
# Epoch 28/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.8009 - accuracy: 0.7142
# Epoch 28: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7996 - accuracy: 0.7147 - val_loss: 0.7912 - val_accuracy: 0.7015
# Epoch 29/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7677 - accuracy: 0.7238
# Epoch 29: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7664 - accuracy: 0.7246 - val_loss: 0.7479 - val_accuracy: 0.7335
# Epoch 30/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7849 - accuracy: 0.7188
# Epoch 30: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7836 - accuracy: 0.7192 - val_loss: 0.7303 - val_accuracy: 0.7335
# Epoch 31/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7589 - accuracy: 0.7276
# Epoch 31: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7587 - accuracy: 0.7278 - val_loss: 0.7086 - val_accuracy: 0.7484
# Epoch 32/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7298 - accuracy: 0.7401
# Epoch 32: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7290 - accuracy: 0.7405 - val_loss: 0.7027 - val_accuracy: 0.7388
# Epoch 33/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7397 - accuracy: 0.7305
# Epoch 33: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7388 - accuracy: 0.7310 - val_loss: 0.7466 - val_accuracy: 0.7324
# Epoch 34/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7540 - accuracy: 0.7225
# Epoch 34: val_accuracy did not improve from 0.76119
# 118/118 [==============================] - 15s 130ms/step - loss: 0.7526 - accuracy: 0.7232 - val_loss: 0.6808 - val_accuracy: 0.7484
# Epoch 35/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7219 - accuracy: 0.7334
# Epoch 35: val_accuracy improved from 0.76119 to 0.76652, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.7208 - accuracy: 0.7339 - val_loss: 0.6456 - val_accuracy: 0.7665
# Epoch 36/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.7101 - accuracy: 0.7409
# Epoch 36: val_accuracy improved from 0.76652 to 0.77292, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.7094 - accuracy: 0.7411 - val_loss: 0.6484 - val_accuracy: 0.7729
# Epoch 37/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6927 - accuracy: 0.7404
# Epoch 37: val_accuracy did not improve from 0.77292
# 118/118 [==============================] - 15s 131ms/step - loss: 0.6914 - accuracy: 0.7411 - val_loss: 0.6619 - val_accuracy: 0.7548
# Epoch 38/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6815 - accuracy: 0.7489
# Epoch 38: val_accuracy did not improve from 0.77292
# 118/118 [==============================] - 15s 131ms/step - loss: 0.6809 - accuracy: 0.7493 - val_loss: 0.6470 - val_accuracy: 0.7633
# Epoch 39/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6770 - accuracy: 0.7503
# Epoch 39: val_accuracy did not improve from 0.77292
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6758 - accuracy: 0.7509 - val_loss: 0.6413 - val_accuracy: 0.7697
# Epoch 40/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6618 - accuracy: 0.7551
# Epoch 40: val_accuracy did not improve from 0.77292
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6615 - accuracy: 0.7552 - val_loss: 0.6403 - val_accuracy: 0.7687
# Epoch 41/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6736 - accuracy: 0.7588
# Epoch 41: val_accuracy did not improve from 0.77292
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6727 - accuracy: 0.7592 - val_loss: 0.6357 - val_accuracy: 0.7548
# Epoch 42/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6577 - accuracy: 0.7634
# Epoch 42: val_accuracy improved from 0.77292 to 0.77825, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 138ms/step - loss: 0.6568 - accuracy: 0.7640 - val_loss: 0.5979 - val_accuracy: 0.7783
# Epoch 43/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6199 - accuracy: 0.7698
# Epoch 43: val_accuracy improved from 0.77825 to 0.78358, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 139ms/step - loss: 0.6194 - accuracy: 0.7698 - val_loss: 0.6491 - val_accuracy: 0.7836
# Epoch 44/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6322 - accuracy: 0.7708
# Epoch 44: val_accuracy did not improve from 0.78358
# 118/118 [==============================] - 15s 131ms/step - loss: 0.6315 - accuracy: 0.7712 - val_loss: 0.6152 - val_accuracy: 0.7783
# Epoch 45/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6260 - accuracy: 0.7692
# Epoch 45: val_accuracy did not improve from 0.78358
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6255 - accuracy: 0.7696 - val_loss: 0.5909 - val_accuracy: 0.7761
# Epoch 46/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6287 - accuracy: 0.7647
# Epoch 46: val_accuracy did not improve from 0.78358
# 118/118 [==============================] - 15s 130ms/step - loss: 0.6299 - accuracy: 0.7645 - val_loss: 0.5546 - val_accuracy: 0.7836
# Epoch 47/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.6153 - accuracy: 0.7756
# Epoch 47: val_accuracy improved from 0.78358 to 0.79318, saving model to /content/drive/MyDrive/fabric_classification/a_model_Aug_V5.h5
# 118/118 [==============================] - 16s 137ms/step - loss: 0.6144 - accuracy: 0.7762 - val_loss: 0.5657 - val_accuracy: 0.7932
# Epoch 48/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5979 - accuracy: 0.7740
# Epoch 48: val_accuracy did not improve from 0.79318
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5969 - accuracy: 0.7746 - val_loss: 0.6028 - val_accuracy: 0.7719
# Epoch 49/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5707 - accuracy: 0.7895
# Epoch 49: val_accuracy did not improve from 0.79318
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5702 - accuracy: 0.7896 - val_loss: 0.5897 - val_accuracy: 0.7932
# Epoch 50/50
# 117/118 [============================>.] - ETA: 0s - loss: 0.5706 - accuracy: 0.7863
# Epoch 50: val_accuracy did not improve from 0.79318
# 118/118 [==============================] - 15s 130ms/step - loss: 0.5704 - accuracy: 0.7861 - val_loss: 0.5577 - val_accuracy: 0.7921
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 4,380,230
# Trainable params: 4,380,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (938, 6)
# (938,)
# (938,)
# [[381  15   0  37   0  12]
#  [  9 123   0   1   0   5]
#  [  1   0  24  15   0   0]
#  [ 24   0   0 151  14   5]
#  [  0   0   0  13  24   3]
#  [ 18   0   0  23   0  40]]
