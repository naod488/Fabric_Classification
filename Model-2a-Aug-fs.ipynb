# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to import first execute this command in the bash
# cp drive/MyDrive/fabric_classification/Fabric_Classification/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re

print(tf.__version__)
import pathlib

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"
data_dir = pathlib.Path(path)
# Out:
# 2.8.0

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(0.5)
    ]
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/fabric_classification/", "Model-2a-Aug-fs")

hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.8148 - accuracy: 0.6059
# Epoch 1: val_accuracy improved from -inf to 0.74627, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 168s 4s/step - loss: 0.8148 - accuracy: 0.6059 - val_loss: 0.5312 - val_accuracy: 0.7463
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6401 - accuracy: 0.6712
# Epoch 2: val_accuracy improved from 0.74627 to 0.75622, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 85ms/step - loss: 0.6379 - accuracy: 0.6729 - val_loss: 0.4954 - val_accuracy: 0.7562
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5804 - accuracy: 0.7113
# Epoch 3: val_accuracy improved from 0.75622 to 0.78607, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.5781 - accuracy: 0.7138 - val_loss: 0.4897 - val_accuracy: 0.7861
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6063 - accuracy: 0.6950
# Epoch 4: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.6061 - accuracy: 0.6939 - val_loss: 0.5455 - val_accuracy: 0.7164
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5791 - accuracy: 0.6963
# Epoch 5: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.5793 - accuracy: 0.6952 - val_loss: 0.5394 - val_accuracy: 0.7065
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6164 - accuracy: 0.6562
# Epoch 6: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.6156 - accuracy: 0.6568 - val_loss: 0.5001 - val_accuracy: 0.7761
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6212 - accuracy: 0.6687
# Epoch 7: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.6208 - accuracy: 0.6679 - val_loss: 0.5364 - val_accuracy: 0.7015
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5907 - accuracy: 0.6875
# Epoch 8: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.5901 - accuracy: 0.6877 - val_loss: 0.4967 - val_accuracy: 0.7612
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6013 - accuracy: 0.6675
# Epoch 9: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.6016 - accuracy: 0.6667 - val_loss: 0.5449 - val_accuracy: 0.7015
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5689 - accuracy: 0.6787
# Epoch 10: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.5676 - accuracy: 0.6778 - val_loss: 0.4882 - val_accuracy: 0.7861
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5083 - accuracy: 0.7588
# Epoch 11: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.5050 - accuracy: 0.7608 - val_loss: 0.7500 - val_accuracy: 0.6368
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6071 - accuracy: 0.6913
# Epoch 12: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 73ms/step - loss: 0.6056 - accuracy: 0.6914 - val_loss: 0.4658 - val_accuracy: 0.7164
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5145 - accuracy: 0.7513
# Epoch 13: val_accuracy did not improve from 0.78607
# 26/26 [==============================] - 2s 74ms/step - loss: 0.5119 - accuracy: 0.7522 - val_loss: 0.5307 - val_accuracy: 0.7711
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5166 - accuracy: 0.7563
# Epoch 14: val_accuracy improved from 0.78607 to 0.83085, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 3s 128ms/step - loss: 0.5152 - accuracy: 0.7559 - val_loss: 0.3623 - val_accuracy: 0.8308
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6030 - accuracy: 0.6675
# Epoch 15: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 73ms/step - loss: 0.6023 - accuracy: 0.6679 - val_loss: 0.4844 - val_accuracy: 0.7811
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5284 - accuracy: 0.7425
# Epoch 16: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 74ms/step - loss: 0.5281 - accuracy: 0.7423 - val_loss: 0.4434 - val_accuracy: 0.8010
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4358 - accuracy: 0.7937
# Epoch 17: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 74ms/step - loss: 0.4334 - accuracy: 0.7955 - val_loss: 0.4988 - val_accuracy: 0.7463
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5309 - accuracy: 0.7588
# Epoch 18: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 75ms/step - loss: 0.5289 - accuracy: 0.7596 - val_loss: 0.3765 - val_accuracy: 0.8259
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4450 - accuracy: 0.7825
# Epoch 19: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 73ms/step - loss: 0.4429 - accuracy: 0.7844 - val_loss: 0.3743 - val_accuracy: 0.8010
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5083 - accuracy: 0.7600
# Epoch 20: val_accuracy did not improve from 0.83085
# 26/26 [==============================] - 2s 74ms/step - loss: 0.5065 - accuracy: 0.7621 - val_loss: 0.3923 - val_accuracy: 0.8109
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4336 - accuracy: 0.8100
# Epoch 21: val_accuracy improved from 0.83085 to 0.84577, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 3s 128ms/step - loss: 0.4324 - accuracy: 0.8104 - val_loss: 0.3339 - val_accuracy: 0.8458
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3967 - accuracy: 0.8263
# Epoch 22: val_accuracy improved from 0.84577 to 0.85075, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.3943 - accuracy: 0.8278 - val_loss: 0.3053 - val_accuracy: 0.8507
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4023 - accuracy: 0.8300
# Epoch 23: val_accuracy improved from 0.85075 to 0.86070, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.3999 - accuracy: 0.8315 - val_loss: 0.2911 - val_accuracy: 0.8607
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3337 - accuracy: 0.8450
# Epoch 24: val_accuracy improved from 0.86070 to 0.89055, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.3315 - accuracy: 0.8463 - val_loss: 0.2783 - val_accuracy: 0.8905
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3218 - accuracy: 0.8637
# Epoch 25: val_accuracy improved from 0.89055 to 0.90547, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.3200 - accuracy: 0.8649 - val_loss: 0.2273 - val_accuracy: 0.9055
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2973 - accuracy: 0.8763
# Epoch 26: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2954 - accuracy: 0.8773 - val_loss: 0.3576 - val_accuracy: 0.8657
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2971 - accuracy: 0.8788
# Epoch 27: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 74ms/step - loss: 0.2957 - accuracy: 0.8798 - val_loss: 0.2640 - val_accuracy: 0.9055
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2645 - accuracy: 0.8888
# Epoch 28: val_accuracy did not improve from 0.90547
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2628 - accuracy: 0.8897 - val_loss: 0.3604 - val_accuracy: 0.8607
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2486 - accuracy: 0.8950
# Epoch 29: val_accuracy improved from 0.90547 to 0.92040, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.2472 - accuracy: 0.8959 - val_loss: 0.2150 - val_accuracy: 0.9204
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2347 - accuracy: 0.8988
# Epoch 30: val_accuracy did not improve from 0.92040
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2330 - accuracy: 0.8996 - val_loss: 0.3028 - val_accuracy: 0.9104
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2450 - accuracy: 0.9000
# Epoch 31: val_accuracy improved from 0.92040 to 0.92537, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 2s 84ms/step - loss: 0.2444 - accuracy: 0.8996 - val_loss: 0.1957 - val_accuracy: 0.9254
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2288 - accuracy: 0.9000
# Epoch 32: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 74ms/step - loss: 0.2270 - accuracy: 0.9009 - val_loss: 0.2475 - val_accuracy: 0.8905
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2463 - accuracy: 0.9075
# Epoch 33: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2444 - accuracy: 0.9083 - val_loss: 1.2140 - val_accuracy: 0.7264
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2390 - accuracy: 0.9013
# Epoch 34: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2376 - accuracy: 0.9021 - val_loss: 0.3122 - val_accuracy: 0.8756
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1863 - accuracy: 0.9312
# Epoch 35: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 74ms/step - loss: 0.1854 - accuracy: 0.9318 - val_loss: 0.4017 - val_accuracy: 0.8507
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2148 - accuracy: 0.9137
# Epoch 36: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 74ms/step - loss: 0.2135 - accuracy: 0.9145 - val_loss: 0.1444 - val_accuracy: 0.9254
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1817 - accuracy: 0.9150
# Epoch 37: val_accuracy did not improve from 0.92537
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1807 - accuracy: 0.9157 - val_loss: 0.1689 - val_accuracy: 0.9254
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1742 - accuracy: 0.9187
# Epoch 38: val_accuracy improved from 0.92537 to 0.93035, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 3s 127ms/step - loss: 0.1734 - accuracy: 0.9195 - val_loss: 0.1680 - val_accuracy: 0.9303
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2498 - accuracy: 0.8913
# Epoch 39: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 74ms/step - loss: 0.2480 - accuracy: 0.8922 - val_loss: 0.1855 - val_accuracy: 0.9154
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2673 - accuracy: 0.8950
# Epoch 40: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2657 - accuracy: 0.8959 - val_loss: 0.2387 - val_accuracy: 0.9005
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2021 - accuracy: 0.9112
# Epoch 41: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2010 - accuracy: 0.9120 - val_loss: 0.1885 - val_accuracy: 0.9204
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2135 - accuracy: 0.9275
# Epoch 42: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2119 - accuracy: 0.9281 - val_loss: 0.2877 - val_accuracy: 0.8806
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1950 - accuracy: 0.9175
# Epoch 43: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 74ms/step - loss: 0.1938 - accuracy: 0.9182 - val_loss: 0.7578 - val_accuracy: 0.7662
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1729 - accuracy: 0.9225
# Epoch 44: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 74ms/step - loss: 0.1721 - accuracy: 0.9232 - val_loss: 0.2491 - val_accuracy: 0.8905
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1729 - accuracy: 0.9312
# Epoch 45: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1725 - accuracy: 0.9306 - val_loss: 0.1458 - val_accuracy: 0.9303
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1563 - accuracy: 0.9337
# Epoch 46: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1553 - accuracy: 0.9343 - val_loss: 0.6392 - val_accuracy: 0.8159
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2009 - accuracy: 0.9175
# Epoch 47: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1994 - accuracy: 0.9182 - val_loss: 0.1573 - val_accuracy: 0.9154
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1668 - accuracy: 0.9300
# Epoch 48: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1657 - accuracy: 0.9306 - val_loss: 0.3017 - val_accuracy: 0.8856
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1260 - accuracy: 0.9488
# Epoch 49: val_accuracy did not improve from 0.93035
# 26/26 [==============================] - 2s 73ms/step - loss: 0.1253 - accuracy: 0.9492 - val_loss: 0.3976 - val_accuracy: 0.8557
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.1445 - accuracy: 0.9475
# Epoch 50: val_accuracy improved from 0.93035 to 0.96517, saving model to /content/drive/MyDrive/fabric_classification/Model-2a-Aug-fs.h5
# 26/26 [==============================] - 3s 124ms/step - loss: 0.1443 - accuracy: 0.9467 - val_loss: 0.1120 - val_accuracy: 0.9652
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
my_utils.generate_cm(model, val_ds, class_names)
# Out:
# (201, 2)
# [[139   1]
#  [  6  55]]
# 0
