# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/fabric_classification/Fabrics_simple"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
batch_size = 32
img_height = 400
img_width = 400
img_size = (img_height, img_width)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1008 files belonging to 2 classes.
# Using 807 files for training.
# Found 1008 files belonging to 2 classes.
# Using 201 files for validation.
# ['Denim', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        #tf.keras.layers.RandomFlip("horizontal"),
        #tf.keras.layers.RandomFlip("vertical"),
        tf.keras.layers.RandomRotation(0.5)
    ]
)

#visualize the effect of the augmentations on a sample image
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

#apply augmentation to the training data
#augmented_train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 2

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

#based on https://towardsdatascience.com/ai-for-textiles-convolutional-neural-network-based-fabric-structure-classifier-c0db5433501d
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath = '/s_model_Aug_NoOptV2.h5', monitor='val_accuracy', 
                             verbose=1, save_best_only=True, mode='max')


hist = model.fit(
    train_ds, 
    validation_data = val_ds, 
    epochs = 50, 
    verbose = 1, 
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.8978 - accuracy: 0.6283
# Epoch 1: val_accuracy improved from -inf to 0.69652, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 11s 199ms/step - loss: 0.8978 - accuracy: 0.6283 - val_loss: 0.5530 - val_accuracy: 0.6965
# Epoch 2/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6567 - accuracy: 0.6263
# Epoch 2: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6554 - accuracy: 0.6295 - val_loss: 0.6145 - val_accuracy: 0.6965
# Epoch 3/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6782 - accuracy: 0.6000
# Epoch 3: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6759 - accuracy: 0.6035 - val_loss: 0.6111 - val_accuracy: 0.6965
# Epoch 4/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6607 - accuracy: 0.6263
# Epoch 4: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6584 - accuracy: 0.6295 - val_loss: 0.5997 - val_accuracy: 0.6965
# Epoch 5/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6652 - accuracy: 0.6263
# Epoch 5: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6642 - accuracy: 0.6295 - val_loss: 0.6340 - val_accuracy: 0.6965
# Epoch 6/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6459 - accuracy: 0.6263
# Epoch 6: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6440 - accuracy: 0.6295 - val_loss: 0.5615 - val_accuracy: 0.6965
# Epoch 7/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6427 - accuracy: 0.6313
# Epoch 7: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6410 - accuracy: 0.6344 - val_loss: 0.6046 - val_accuracy: 0.6965
# Epoch 8/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6427 - accuracy: 0.6325
# Epoch 8: val_accuracy did not improve from 0.69652
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6412 - accuracy: 0.6357 - val_loss: 0.6051 - val_accuracy: 0.6965
# Epoch 9/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6122 - accuracy: 0.6488
# Epoch 9: val_accuracy improved from 0.69652 to 0.71144, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 4s 136ms/step - loss: 0.6135 - accuracy: 0.6493 - val_loss: 0.5683 - val_accuracy: 0.7114
# Epoch 10/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6494 - accuracy: 0.6313
# Epoch 10: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6480 - accuracy: 0.6344 - val_loss: 0.6069 - val_accuracy: 0.7015
# Epoch 11/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6273 - accuracy: 0.6450
# Epoch 11: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 126ms/step - loss: 0.6257 - accuracy: 0.6481 - val_loss: 0.5849 - val_accuracy: 0.6965
# Epoch 12/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6405 - accuracy: 0.6263
# Epoch 12: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6393 - accuracy: 0.6295 - val_loss: 0.6136 - val_accuracy: 0.6965
# Epoch 13/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6190 - accuracy: 0.6338
# Epoch 13: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6166 - accuracy: 0.6369 - val_loss: 0.5749 - val_accuracy: 0.7065
# Epoch 14/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6398 - accuracy: 0.6525
# Epoch 14: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 128ms/step - loss: 0.6392 - accuracy: 0.6555 - val_loss: 0.6476 - val_accuracy: 0.6965
# Epoch 15/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6611 - accuracy: 0.6263
# Epoch 15: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 125ms/step - loss: 0.6592 - accuracy: 0.6295 - val_loss: 0.5906 - val_accuracy: 0.6965
# Epoch 16/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.6079 - accuracy: 0.6425
# Epoch 16: val_accuracy did not improve from 0.71144
# 26/26 [==============================] - 3s 124ms/step - loss: 0.6045 - accuracy: 0.6456 - val_loss: 0.5229 - val_accuracy: 0.7065
# Epoch 17/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5480 - accuracy: 0.6775
# Epoch 17: val_accuracy improved from 0.71144 to 0.73134, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.5445 - accuracy: 0.6803 - val_loss: 0.5274 - val_accuracy: 0.7313
# Epoch 18/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5214 - accuracy: 0.7150
# Epoch 18: val_accuracy did not improve from 0.73134
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5186 - accuracy: 0.7175 - val_loss: 0.6023 - val_accuracy: 0.7164
# Epoch 19/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4800 - accuracy: 0.7362
# Epoch 19: val_accuracy improved from 0.73134 to 0.77612, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.4782 - accuracy: 0.7373 - val_loss: 0.4556 - val_accuracy: 0.7761
# Epoch 20/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5439 - accuracy: 0.7200
# Epoch 20: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5423 - accuracy: 0.7224 - val_loss: 0.6152 - val_accuracy: 0.7264
# Epoch 21/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5862 - accuracy: 0.7038
# Epoch 21: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5828 - accuracy: 0.7063 - val_loss: 0.6056 - val_accuracy: 0.7214
# Epoch 22/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5218 - accuracy: 0.7088
# Epoch 22: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5189 - accuracy: 0.7113 - val_loss: 0.4534 - val_accuracy: 0.7562
# Epoch 23/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5273 - accuracy: 0.7075
# Epoch 23: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5256 - accuracy: 0.7100 - val_loss: 0.6463 - val_accuracy: 0.6915
# Epoch 24/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.5035 - accuracy: 0.7300
# Epoch 24: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.5004 - accuracy: 0.7323 - val_loss: 0.4737 - val_accuracy: 0.7363
# Epoch 25/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4506 - accuracy: 0.7387
# Epoch 25: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.4474 - accuracy: 0.7410 - val_loss: 0.5167 - val_accuracy: 0.7413
# Epoch 26/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4371 - accuracy: 0.7638
# Epoch 26: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 123ms/step - loss: 0.4339 - accuracy: 0.7658 - val_loss: 0.5451 - val_accuracy: 0.7761
# Epoch 27/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4577 - accuracy: 0.7850
# Epoch 27: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.4549 - accuracy: 0.7869 - val_loss: 0.6656 - val_accuracy: 0.7015
# Epoch 28/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4140 - accuracy: 0.7900
# Epoch 28: val_accuracy did not improve from 0.77612
# 26/26 [==============================] - 3s 124ms/step - loss: 0.4114 - accuracy: 0.7918 - val_loss: 0.5707 - val_accuracy: 0.7363
# Epoch 29/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3752 - accuracy: 0.8213
# Epoch 29: val_accuracy improved from 0.77612 to 0.79104, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.3736 - accuracy: 0.8228 - val_loss: 0.5421 - val_accuracy: 0.7910
# Epoch 30/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.4433 - accuracy: 0.7900
# Epoch 30: val_accuracy improved from 0.79104 to 0.81592, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.4418 - accuracy: 0.7918 - val_loss: 0.4034 - val_accuracy: 0.8159
# Epoch 31/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3921 - accuracy: 0.8175
# Epoch 31: val_accuracy did not improve from 0.81592
# 26/26 [==============================] - 3s 125ms/step - loss: 0.3900 - accuracy: 0.8191 - val_loss: 0.5372 - val_accuracy: 0.8010
# Epoch 32/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3255 - accuracy: 0.8587
# Epoch 32: val_accuracy improved from 0.81592 to 0.83582, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.3231 - accuracy: 0.8600 - val_loss: 0.3663 - val_accuracy: 0.8358
# Epoch 33/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3212 - accuracy: 0.8525
# Epoch 33: val_accuracy improved from 0.83582 to 0.84080, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.3210 - accuracy: 0.8525 - val_loss: 0.3012 - val_accuracy: 0.8408
# Epoch 34/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3902 - accuracy: 0.8400
# Epoch 34: val_accuracy did not improve from 0.84080
# 26/26 [==============================] - 3s 124ms/step - loss: 0.3896 - accuracy: 0.8401 - val_loss: 0.4838 - val_accuracy: 0.8060
# Epoch 35/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3468 - accuracy: 0.8375
# Epoch 35: val_accuracy improved from 0.84080 to 0.85572, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.3450 - accuracy: 0.8389 - val_loss: 0.3567 - val_accuracy: 0.8557
# Epoch 36/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3348 - accuracy: 0.8537
# Epoch 36: val_accuracy did not improve from 0.85572
# 26/26 [==============================] - 3s 124ms/step - loss: 0.3335 - accuracy: 0.8550 - val_loss: 0.4944 - val_accuracy: 0.7811
# Epoch 37/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3129 - accuracy: 0.8763
# Epoch 37: val_accuracy did not improve from 0.85572
# 26/26 [==============================] - 3s 124ms/step - loss: 0.3110 - accuracy: 0.8773 - val_loss: 0.3391 - val_accuracy: 0.8408
# Epoch 38/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3009 - accuracy: 0.8763
# Epoch 38: val_accuracy did not improve from 0.85572
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2989 - accuracy: 0.8773 - val_loss: 0.3362 - val_accuracy: 0.8557
# Epoch 39/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2521 - accuracy: 0.9000
# Epoch 39: val_accuracy improved from 0.85572 to 0.88060, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 135ms/step - loss: 0.2511 - accuracy: 0.9009 - val_loss: 0.2471 - val_accuracy: 0.8806
# Epoch 40/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2784 - accuracy: 0.8925
# Epoch 40: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 3s 125ms/step - loss: 0.2768 - accuracy: 0.8934 - val_loss: 0.2812 - val_accuracy: 0.8806
# Epoch 41/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2838 - accuracy: 0.8825
# Epoch 41: val_accuracy did not improve from 0.88060
# 26/26 [==============================] - 3s 125ms/step - loss: 0.2821 - accuracy: 0.8835 - val_loss: 0.2454 - val_accuracy: 0.8756
# Epoch 42/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2703 - accuracy: 0.8863
# Epoch 42: val_accuracy improved from 0.88060 to 0.91542, saving model to /s_model_Aug_NoOptV2.h5
# 26/26 [==============================] - 3s 134ms/step - loss: 0.2684 - accuracy: 0.8872 - val_loss: 0.2949 - val_accuracy: 0.9154
# Epoch 43/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2786 - accuracy: 0.8875
# Epoch 43: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2769 - accuracy: 0.8885 - val_loss: 0.2854 - val_accuracy: 0.9005
# Epoch 44/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2392 - accuracy: 0.9087
# Epoch 44: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2378 - accuracy: 0.9095 - val_loss: 0.1984 - val_accuracy: 0.9005
# Epoch 45/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.3060 - accuracy: 0.8712
# Epoch 45: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.3036 - accuracy: 0.8724 - val_loss: 0.4442 - val_accuracy: 0.8209
# Epoch 46/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2707 - accuracy: 0.8838
# Epoch 46: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2689 - accuracy: 0.8848 - val_loss: 0.4370 - val_accuracy: 0.8607
# Epoch 47/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2467 - accuracy: 0.8950
# Epoch 47: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2456 - accuracy: 0.8959 - val_loss: 0.4309 - val_accuracy: 0.8557
# Epoch 48/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2866 - accuracy: 0.8775
# Epoch 48: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2852 - accuracy: 0.8786 - val_loss: 0.2597 - val_accuracy: 0.9005
# Epoch 49/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2915 - accuracy: 0.8737
# Epoch 49: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2896 - accuracy: 0.8748 - val_loss: 0.3009 - val_accuracy: 0.8657
# Epoch 50/50
# 25/26 [===========================>..] - ETA: 0s - loss: 0.2266 - accuracy: 0.9025
# Epoch 50: val_accuracy did not improve from 0.91542
# 26/26 [==============================] - 3s 124ms/step - loss: 0.2256 - accuracy: 0.9033 - val_loss: 0.4083 - val_accuracy: 0.8756
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 199, 199, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 98, 98, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 128)               9437312
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 9,456,962
# Trainable params: 9,456,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_loss'], label='val loss')
plt.title("Loss vs Val_Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.plot(hist.history['accuracy'], label = 'acc')
plt.plot(hist.history['val_accuracy'], label='val acc')
plt.title("acc vs Val_acc")
plt.xlabel("Epochs")
plt.ylabel("acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(val_ds)#X
predicted_categories = tf.argmax(y_pred, axis=1)#X
true_categories = tf.concat([y for x, y in val_ds], axis=0)#y

print(y_pred.shape)
print(predicted_categories.shape)
print(true_categories.shape)

cm = confusion_matrix(true_categories, predicted_categories)
print(cm)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(cm)
plt.title('Confusion matrix of the classifier')
fig.colorbar(cax)
ax.set_xticklabels([''] + class_names)
ax.set_yticklabels([''] + class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# (201, 2)
# (201,)
# (201,)
# [[120  20]
#  [  5  56]]
